# %% [markdown]
# # Traffic SignBoard Detection - SSD ResNet50 V1 FPN 640x640 (RetinaNet50):

# %% [markdown]
# ## 1. DOWNLOAD THE PRETRAINED MODELS FROM THE TENSOFLOW MODEL ZOO

# %%
import os

# DATA_DIR = os.path.join(os.getcwd(), 'data')
MODELS_DIR = os.path.join('pre-trained-model')
for dir in [MODELS_DIR]:
    if not os.path.exists(dir):
        os.mkdir(dir)

# %%
main_directory = 'models'
subfolder_name = 'ssd_resnet50_v1_fpn_640x640_retinanet50'

main_directory_path = os.path.join(os.getcwd(), main_directory)
subfolder_path = os.path.join(main_directory_path, subfolder_name)

if not os.path.exists(subfolder_path):
    os.makedirs(subfolder_path)

# %%
import tarfile
import urllib.request
import os

# Download and extract model
MODEL_DATE = '20200711'
MODEL_NAME = 'ssd_resnet50_v1_fpn_640x640_coco17_tpu-8'
MODEL_TAR_FILENAME = MODEL_NAME + '.tar.gz'
MODELS_DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/'
MODEL_DOWNLOAD_LINK = MODELS_DOWNLOAD_BASE + MODEL_DATE + '/' + MODEL_TAR_FILENAME
PATH_TO_MODEL_TAR = os.path.join(MODELS_DIR, MODEL_TAR_FILENAME)
PATH_TO_CKPT = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'checkpoint/'))
PATH_TO_CFG = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'pipeline.config'))
if not os.path.exists(PATH_TO_CKPT):
    print('Downloading model. This may take a while... ', end='')
    urllib.request.urlretrieve(MODEL_DOWNLOAD_LINK, PATH_TO_MODEL_TAR)
    tar_file = tarfile.open(PATH_TO_MODEL_TAR)
    tar_file.extractall(MODELS_DIR)
    tar_file.close()
    os.remove(PATH_TO_MODEL_TAR)
    print('Done')

# %% [markdown]
# ## 2. SETUP PATHS:

# %%
WORKSPACE_PATH = '../training_helper_directory'
SCRIPT_PATH = WORKSPACE_PATH + '/scripts'
ANNOTATION_PATH = WORKSPACE_PATH + '/annotations'

IMAGE_PATH = '../Dataset/"PASCAL VOC Format Dataset"'

CUSTOM_MODEL_NAME = '/ssd_resnet50_v1_fpn_640x640_retinanet50'
MODEL_PATH = './models' + CUSTOM_MODEL_NAME

PRETRAINED_PATH = './pre-trained-model/' + MODEL_NAME
CONFIG_PATH = MODEL_PATH + '/pipeline.config'

EXPORT_PATH = '../exported-models/my-model'

# %% [markdown]
# ## 3. CREATE TF RECORDS:

# %%
# # Create train data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}

# # Create test data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}

# %% [markdown]
# ## 4. COPY MODEL CONFIG FILE TO TRANING FOLDER:

# %%
SOURCE_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\SSD ResNet50 V1 FPN 640x640 (RetinaNet50)\pre-trained-model\ssd_resnet50_v1_fpn_640x640_coco17_tpu-8\pipeline.config"
DESTINATION_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\SSD ResNet50 V1 FPN 640x640 (RetinaNet50)\models\ssd_resnet50_v1_fpn_640x640_retinanet50"

# %%
# !copy "{SOURCE_PATH}" "{DESTINATION_PATH}"
# Out:
#         1 file(s) copied.

# %% [markdown]
# ## 5. UPDATING CONFIG FOR TRANSFER LEARNING:

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_resnet50_v1_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 0.00039999998989515007
#          }
#        }
#        initializer {
#          truncated_normal_initializer {
#            mean: 0.0
#            stddev: 0.029999999329447746
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 0.00039999998989515007
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 256
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 64
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.03999999910593033
#          total_steps: 25000
#          warmup_learning_rate: 0.013333000242710114
#          warmup_steps: 2000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 25000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  use_bfloat16: true
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = 56

pipeline_config.train_config.batch_size = 2
pipeline_config.train_config.num_steps = 25000

pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_PATH + '/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection" 
pipeline_config.train_config.use_bfloat16 = False

pipeline_config.train_input_reader.label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH+ '/train.record'] 

pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:
    f.write(config_text)

# %% [markdown]
# ## 6. TRAIN THE MODEL:

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.getcwd()
# Out:
# 'd:\\Traffic SignBoard Recognition using Deep Learning\\SSD ResNet50 V1 FPN 640x640 (RetinaNet50)'

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'}
# Out:
# 2024-03-08 03:55:55.347244: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-08 03:55:55.896959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0308 03:55:57.859101 22600 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0308 03:55:57.867861 22600 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0308 03:55:57.868860 22600 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0308 03:55:57.888861 22600 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# I0308 03:55:57.903865 22600 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# I0308 03:55:57.903865 22600 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0308 03:55:57.903865 22600 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0308 03:55:57.903865 22600 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0308 03:55:57.906373 22600 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0308 03:55:57.927381 22600 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0308 03:56:03.289209 22600 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0308 03:56:05.683428 22600 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0308 03:56:06.958010 22600 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0308 03:56:13.141562 25172 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0308 03:56:20.331915  2824 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-08 03:56:25.288840: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-08 03:56:26.979041: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:26.979428: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:27.038863: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:27.039236: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:27.322132: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:27.322595: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:27.672947: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:27.673323: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:28.011599: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 03:56:28.012010: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.576933 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.577933 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.578932 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.579923 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.581920 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.581920 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.583917 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.583917 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.584917 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 03:56:31.585917 22600 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0308 03:56:32.381648  7992 deprecation.py:554] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0308 03:56:33.110606  7992 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0308 03:56:38.183788 14908 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0308 03:56:42.649208 20748 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0308 03:56:47.584928 11940 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# INFO:tensorflow:Step 100 per-step time 1.641s
# I0308 03:59:16.232977 22600 model_lib_v2.py:705] Step 100 per-step time 1.641s
# INFO:tensorflow:{'Loss/classification_loss': 0.9006619,
#  'Loss/localization_loss': 0.15837157,
#  'Loss/regularization_loss': 0.28580758,
#  'Loss/total_loss': 1.344841,
#  'learning_rate': 0.014666351}
# I0308 03:59:16.236976 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.9006619,
#  'Loss/localization_loss': 0.15837157,
#  'Loss/regularization_loss': 0.28580758,
#  'Loss/total_loss': 1.344841,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 1.190s
# I0308 04:01:15.221835 22600 model_lib_v2.py:705] Step 200 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.77052027,
#  'Loss/localization_loss': 0.44915313,
#  'Loss/regularization_loss': 0.34713048,
#  'Loss/total_loss': 1.5668039,
#  'learning_rate': 0.0159997}
# I0308 04:01:15.221835 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.77052027,
#  'Loss/localization_loss': 0.44915313,
#  'Loss/regularization_loss': 0.34713048,
#  'Loss/total_loss': 1.5668039,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 1.190s
# I0308 04:03:14.220220 22600 model_lib_v2.py:705] Step 300 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.77247584,
#  'Loss/localization_loss': 0.20974778,
#  'Loss/regularization_loss': 0.3560254,
#  'Loss/total_loss': 1.338249,
#  'learning_rate': 0.01733305}
# I0308 04:03:14.220220 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.77247584,
#  'Loss/localization_loss': 0.20974778,
#  'Loss/regularization_loss': 0.3560254,
#  'Loss/total_loss': 1.338249,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 1.191s
# I0308 04:05:13.285375 22600 model_lib_v2.py:705] Step 400 per-step time 1.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.8904711,
#  'Loss/localization_loss': 0.3237273,
#  'Loss/regularization_loss': 0.35937867,
#  'Loss/total_loss': 1.5735772,
#  'learning_rate': 0.0186664}
# I0308 04:05:13.285375 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.8904711,
#  'Loss/localization_loss': 0.3237273,
#  'Loss/regularization_loss': 0.35937867,
#  'Loss/total_loss': 1.5735772,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 1.190s
# I0308 04:07:12.281076 22600 model_lib_v2.py:705] Step 500 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 1.1310002,
#  'Loss/localization_loss': 0.30193672,
#  'Loss/regularization_loss': 0.35820574,
#  'Loss/total_loss': 1.7911426,
#  'learning_rate': 0.01999975}
# I0308 04:07:12.281076 22600 model_lib_v2.py:708] {'Loss/classification_loss': 1.1310002,
#  'Loss/localization_loss': 0.30193672,
#  'Loss/regularization_loss': 0.35820574,
#  'Loss/total_loss': 1.7911426,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 1.190s
# I0308 04:09:11.311569 22600 model_lib_v2.py:705] Step 600 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.8752156,
#  'Loss/localization_loss': 0.6204791,
#  'Loss/regularization_loss': 0.35769582,
#  'Loss/total_loss': 1.8533905,
#  'learning_rate': 0.0213331}
# I0308 04:09:11.311569 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.8752156,
#  'Loss/localization_loss': 0.6204791,
#  'Loss/regularization_loss': 0.35769582,
#  'Loss/total_loss': 1.8533905,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 1.190s
# I0308 04:11:10.341856 22600 model_lib_v2.py:705] Step 700 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.5089692,
#  'Loss/localization_loss': 0.13833801,
#  'Loss/regularization_loss': 0.35596177,
#  'Loss/total_loss': 1.003269,
#  'learning_rate': 0.02266645}
# I0308 04:11:10.341856 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5089692,
#  'Loss/localization_loss': 0.13833801,
#  'Loss/regularization_loss': 0.35596177,
#  'Loss/total_loss': 1.003269,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 1.208s
# I0308 04:13:11.153342 22600 model_lib_v2.py:705] Step 800 per-step time 1.208s
# INFO:tensorflow:{'Loss/classification_loss': 0.6178899,
#  'Loss/localization_loss': 0.36842266,
#  'Loss/regularization_loss': 0.35335284,
#  'Loss/total_loss': 1.3396654,
#  'learning_rate': 0.023999799}
# I0308 04:13:11.153342 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.6178899,
#  'Loss/localization_loss': 0.36842266,
#  'Loss/regularization_loss': 0.35335284,
#  'Loss/total_loss': 1.3396654,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 1.191s
# I0308 04:15:10.212831 22600 model_lib_v2.py:705] Step 900 per-step time 1.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.4974636,
#  'Loss/localization_loss': 0.055837,
#  'Loss/regularization_loss': 0.3508793,
#  'Loss/total_loss': 0.9041799,
#  'learning_rate': 0.025333151}
# I0308 04:15:10.212831 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.4974636,
#  'Loss/localization_loss': 0.055837,
#  'Loss/regularization_loss': 0.3508793,
#  'Loss/total_loss': 0.9041799,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 1.190s
# I0308 04:17:09.192541 22600 model_lib_v2.py:705] Step 1000 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.6357685,
#  'Loss/localization_loss': 0.09884727,
#  'Loss/regularization_loss': 0.34734684,
#  'Loss/total_loss': 1.0819626,
#  'learning_rate': 0.0266665}
# I0308 04:17:09.192541 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.6357685,
#  'Loss/localization_loss': 0.09884727,
#  'Loss/regularization_loss': 0.34734684,
#  'Loss/total_loss': 1.0819626,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 1.200s
# I0308 04:19:09.179153 22600 model_lib_v2.py:705] Step 1100 per-step time 1.200s
# INFO:tensorflow:{'Loss/classification_loss': 0.67358905,
#  'Loss/localization_loss': 0.12205021,
#  'Loss/regularization_loss': 0.34501117,
#  'Loss/total_loss': 1.1406504,
#  'learning_rate': 0.02799985}
# I0308 04:19:09.179153 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.67358905,
#  'Loss/localization_loss': 0.12205021,
#  'Loss/regularization_loss': 0.34501117,
#  'Loss/total_loss': 1.1406504,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 1.190s
# I0308 04:21:08.158588 22600 model_lib_v2.py:705] Step 1200 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.8252,
#  'Loss/localization_loss': 0.2869685,
#  'Loss/regularization_loss': 0.34210125,
#  'Loss/total_loss': 1.4542698,
#  'learning_rate': 0.0293332}
# I0308 04:21:08.158588 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.8252,
#  'Loss/localization_loss': 0.2869685,
#  'Loss/regularization_loss': 0.34210125,
#  'Loss/total_loss': 1.4542698,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 1.190s
# I0308 04:23:07.108412 22600 model_lib_v2.py:705] Step 1300 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.7005687,
#  'Loss/localization_loss': 0.043775048,
#  'Loss/regularization_loss': 0.33801717,
#  'Loss/total_loss': 1.082361,
#  'learning_rate': 0.03066655}
# I0308 04:23:07.108412 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.7005687,
#  'Loss/localization_loss': 0.043775048,
#  'Loss/regularization_loss': 0.33801717,
#  'Loss/total_loss': 1.082361,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 1.192s
# I0308 04:25:06.268951 22600 model_lib_v2.py:705] Step 1400 per-step time 1.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.4307139,
#  'Loss/localization_loss': 0.042840272,
#  'Loss/regularization_loss': 0.33573025,
#  'Loss/total_loss': 0.80928445,
#  'learning_rate': 0.0319999}
# I0308 04:25:06.268951 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.4307139,
#  'Loss/localization_loss': 0.042840272,
#  'Loss/regularization_loss': 0.33573025,
#  'Loss/total_loss': 0.80928445,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 1.191s
# I0308 04:27:05.403625 22600 model_lib_v2.py:705] Step 1500 per-step time 1.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.50533503,
#  'Loss/localization_loss': 0.26950723,
#  'Loss/regularization_loss': 0.3347289,
#  'Loss/total_loss': 1.1095712,
#  'learning_rate': 0.03333325}
# I0308 04:27:05.403625 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.50533503,
#  'Loss/localization_loss': 0.26950723,
#  'Loss/regularization_loss': 0.3347289,
#  'Loss/total_loss': 1.1095712,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 1.191s
# I0308 04:29:04.499704 22600 model_lib_v2.py:705] Step 1600 per-step time 1.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.5354989,
#  'Loss/localization_loss': 0.060147256,
#  'Loss/regularization_loss': 0.33391443,
#  'Loss/total_loss': 0.92956066,
#  'learning_rate': 0.034666598}
# I0308 04:29:04.500703 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5354989,
#  'Loss/localization_loss': 0.060147256,
#  'Loss/regularization_loss': 0.33391443,
#  'Loss/total_loss': 0.92956066,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 1.190s
# I0308 04:31:03.516041 22600 model_lib_v2.py:705] Step 1700 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.6681594,
#  'Loss/localization_loss': 0.26179484,
#  'Loss/regularization_loss': 0.3323816,
#  'Loss/total_loss': 1.2623358,
#  'learning_rate': 0.03599995}
# I0308 04:31:03.516041 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.6681594,
#  'Loss/localization_loss': 0.26179484,
#  'Loss/regularization_loss': 0.3323816,
#  'Loss/total_loss': 1.2623358,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 1.191s
# I0308 04:33:02.572992 22600 model_lib_v2.py:705] Step 1800 per-step time 1.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.49839354,
#  'Loss/localization_loss': 0.050272327,
#  'Loss/regularization_loss': 0.33048767,
#  'Loss/total_loss': 0.87915355,
#  'learning_rate': 0.037333302}
# I0308 04:33:02.572992 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.49839354,
#  'Loss/localization_loss': 0.050272327,
#  'Loss/regularization_loss': 0.33048767,
#  'Loss/total_loss': 0.87915355,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 1.191s
# I0308 04:35:01.669615 22600 model_lib_v2.py:705] Step 1900 per-step time 1.191s
# INFO:tensorflow:{'Loss/classification_loss': 0.38392457,
#  'Loss/localization_loss': 0.06657259,
#  'Loss/regularization_loss': 0.3287284,
#  'Loss/total_loss': 0.7792256,
#  'learning_rate': 0.03866665}
# I0308 04:35:01.669615 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.38392457,
#  'Loss/localization_loss': 0.06657259,
#  'Loss/regularization_loss': 0.3287284,
#  'Loss/total_loss': 0.7792256,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 1.190s
# I0308 04:37:00.716295 22600 model_lib_v2.py:705] Step 2000 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 1.0390912,
#  'Loss/localization_loss': 0.6491602,
#  'Loss/regularization_loss': 0.32619852,
#  'Loss/total_loss': 2.0144498,
#  'learning_rate': 0.04}
# I0308 04:37:00.716295 22600 model_lib_v2.py:708] {'Loss/classification_loss': 1.0390912,
#  'Loss/localization_loss': 0.6491602,
#  'Loss/regularization_loss': 0.32619852,
#  'Loss/total_loss': 2.0144498,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 1.214s
# I0308 04:39:02.086857 22600 model_lib_v2.py:705] Step 2100 per-step time 1.214s
# INFO:tensorflow:{'Loss/classification_loss': 1.2125727,
#  'Loss/localization_loss': 0.675913,
#  'Loss/regularization_loss': 0.32440102,
#  'Loss/total_loss': 2.2128868,
#  'learning_rate': 0.039998136}
# I0308 04:39:02.086857 22600 model_lib_v2.py:708] {'Loss/classification_loss': 1.2125727,
#  'Loss/localization_loss': 0.675913,
#  'Loss/regularization_loss': 0.32440102,
#  'Loss/total_loss': 2.2128868,
#  'learning_rate': 0.039998136}
# INFO:tensorflow:Step 2200 per-step time 1.190s
# I0308 04:41:01.138843 22600 model_lib_v2.py:705] Step 2200 per-step time 1.190s
# INFO:tensorflow:{'Loss/classification_loss': 0.4017698,
#  'Loss/localization_loss': 0.059718702,
#  'Loss/regularization_loss': 0.3244364,
#  'Loss/total_loss': 0.7859249,
#  'learning_rate': 0.039992537}
# I0308 04:41:01.139842 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.4017698,
#  'Loss/localization_loss': 0.059718702,
#  'Loss/regularization_loss': 0.3244364,
#  'Loss/total_loss': 0.7859249,
#  'learning_rate': 0.039992537}
# INFO:tensorflow:Step 2300 per-step time 1.131s
# I0308 04:42:54.276797 22600 model_lib_v2.py:705] Step 2300 per-step time 1.131s
# INFO:tensorflow:{'Loss/classification_loss': 0.6517869,
#  'Loss/localization_loss': 0.26783934,
#  'Loss/regularization_loss': 0.32083106,
#  'Loss/total_loss': 1.2404573,
#  'learning_rate': 0.03998321}
# I0308 04:42:54.276797 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.6517869,
#  'Loss/localization_loss': 0.26783934,
#  'Loss/regularization_loss': 0.32083106,
#  'Loss/total_loss': 1.2404573,
#  'learning_rate': 0.03998321}
# INFO:tensorflow:Step 2400 per-step time 0.976s
# I0308 04:44:31.886672 22600 model_lib_v2.py:705] Step 2400 per-step time 0.976s
# INFO:tensorflow:{'Loss/classification_loss': 0.57861215,
#  'Loss/localization_loss': 0.08239765,
#  'Loss/regularization_loss': 0.4073246,
#  'Loss/total_loss': 1.0683345,
#  'learning_rate': 0.039970152}
# I0308 04:44:31.886672 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.57861215,
#  'Loss/localization_loss': 0.08239765,
#  'Loss/regularization_loss': 0.4073246,
#  'Loss/total_loss': 1.0683345,
#  'learning_rate': 0.039970152}
# INFO:tensorflow:Step 2500 per-step time 0.848s
# I0308 04:45:56.681018 22600 model_lib_v2.py:705] Step 2500 per-step time 0.848s
# INFO:tensorflow:{'Loss/classification_loss': 1.5469499,
#  'Loss/localization_loss': 0.69169706,
#  'Loss/regularization_loss': 0.40209806,
#  'Loss/total_loss': 2.640745,
#  'learning_rate': 0.039953373}
# I0308 04:45:56.681018 22600 model_lib_v2.py:708] {'Loss/classification_loss': 1.5469499,
#  'Loss/localization_loss': 0.69169706,
#  'Loss/regularization_loss': 0.40209806,
#  'Loss/total_loss': 2.640745,
#  'learning_rate': 0.039953373}
# INFO:tensorflow:Step 2600 per-step time 0.876s
# I0308 04:47:24.303135 22600 model_lib_v2.py:705] Step 2600 per-step time 0.876s
# INFO:tensorflow:{'Loss/classification_loss': 0.3391545,
#  'Loss/localization_loss': 0.08014593,
#  'Loss/regularization_loss': 0.39946094,
#  'Loss/total_loss': 0.8187614,
#  'learning_rate': 0.03993287}
# I0308 04:47:24.303135 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.3391545,
#  'Loss/localization_loss': 0.08014593,
#  'Loss/regularization_loss': 0.39946094,
#  'Loss/total_loss': 0.8187614,
#  'learning_rate': 0.03993287}
# INFO:tensorflow:Step 2700 per-step time 0.888s
# I0308 04:48:53.110826 22600 model_lib_v2.py:705] Step 2700 per-step time 0.888s
# INFO:tensorflow:{'Loss/classification_loss': 0.4653694,
#  'Loss/localization_loss': 0.10376743,
#  'Loss/regularization_loss': 0.42143664,
#  'Loss/total_loss': 0.99057347,
#  'learning_rate': 0.039908648}
# I0308 04:48:53.110826 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.4653694,
#  'Loss/localization_loss': 0.10376743,
#  'Loss/regularization_loss': 0.42143664,
#  'Loss/total_loss': 0.99057347,
#  'learning_rate': 0.039908648}
# INFO:tensorflow:Step 2800 per-step time 0.891s
# I0308 04:50:22.259289 22600 model_lib_v2.py:705] Step 2800 per-step time 0.891s
# INFO:tensorflow:{'Loss/classification_loss': 0.3688086,
#  'Loss/localization_loss': 0.020184398,
#  'Loss/regularization_loss': 0.4186845,
#  'Loss/total_loss': 0.8076775,
#  'learning_rate': 0.039880715}
# I0308 04:50:22.259289 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.3688086,
#  'Loss/localization_loss': 0.020184398,
#  'Loss/regularization_loss': 0.4186845,
#  'Loss/total_loss': 0.8076775,
#  'learning_rate': 0.039880715}
# INFO:tensorflow:Step 2900 per-step time 0.896s
# I0308 04:51:51.813418 22600 model_lib_v2.py:705] Step 2900 per-step time 0.896s
# INFO:tensorflow:{'Loss/classification_loss': 6.179782,
#  'Loss/localization_loss': 0.3586281,
#  'Loss/regularization_loss': 0.728437,
#  'Loss/total_loss': 7.266847,
#  'learning_rate': 0.039849065}
# I0308 04:51:51.813418 22600 model_lib_v2.py:708] {'Loss/classification_loss': 6.179782,
#  'Loss/localization_loss': 0.3586281,
#  'Loss/regularization_loss': 0.728437,
#  'Loss/total_loss': 7.266847,
#  'learning_rate': 0.039849065}
# INFO:tensorflow:Step 3000 per-step time 0.899s
# I0308 04:53:21.742728 22600 model_lib_v2.py:705] Step 3000 per-step time 0.899s
# INFO:tensorflow:{'Loss/classification_loss': 0.7433334,
#  'Loss/localization_loss': 0.16486263,
#  'Loss/regularization_loss': 0.90164715,
#  'Loss/total_loss': 1.8098432,
#  'learning_rate': 0.03981372}
# I0308 04:53:21.742728 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.7433334,
#  'Loss/localization_loss': 0.16486263,
#  'Loss/regularization_loss': 0.90164715,
#  'Loss/total_loss': 1.8098432,
#  'learning_rate': 0.03981372}
# INFO:tensorflow:Step 3100 per-step time 0.911s
# I0308 04:54:52.816978 22600 model_lib_v2.py:705] Step 3100 per-step time 0.911s
# INFO:tensorflow:{'Loss/classification_loss': 0.53221965,
#  'Loss/localization_loss': 0.12482184,
#  'Loss/regularization_loss': 0.8978326,
#  'Loss/total_loss': 1.5548742,
#  'learning_rate': 0.03977467}
# I0308 04:54:52.817980 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.53221965,
#  'Loss/localization_loss': 0.12482184,
#  'Loss/regularization_loss': 0.8978326,
#  'Loss/total_loss': 1.5548742,
#  'learning_rate': 0.03977467}
# INFO:tensorflow:Step 3200 per-step time 0.901s
# I0308 04:56:22.888250 22600 model_lib_v2.py:705] Step 3200 per-step time 0.901s
# INFO:tensorflow:{'Loss/classification_loss': 0.5111178,
#  'Loss/localization_loss': 0.16337128,
#  'Loss/regularization_loss': 0.9082317,
#  'Loss/total_loss': 1.5827208,
#  'learning_rate': 0.03973194}
# I0308 04:56:22.888250 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5111178,
#  'Loss/localization_loss': 0.16337128,
#  'Loss/regularization_loss': 0.9082317,
#  'Loss/total_loss': 1.5827208,
#  'learning_rate': 0.03973194}
# INFO:tensorflow:Step 3300 per-step time 0.902s
# I0308 04:57:53.133188 22600 model_lib_v2.py:705] Step 3300 per-step time 0.902s
# INFO:tensorflow:{'Loss/classification_loss': 0.5946551,
#  'Loss/localization_loss': 0.17891261,
#  'Loss/regularization_loss': 0.8975105,
#  'Loss/total_loss': 1.6710782,
#  'learning_rate': 0.03968552}
# I0308 04:57:53.133188 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5946551,
#  'Loss/localization_loss': 0.17891261,
#  'Loss/regularization_loss': 0.8975105,
#  'Loss/total_loss': 1.6710782,
#  'learning_rate': 0.03968552}
# INFO:tensorflow:Step 3400 per-step time 0.903s
# I0308 04:59:23.427700 22600 model_lib_v2.py:705] Step 3400 per-step time 0.903s
# INFO:tensorflow:{'Loss/classification_loss': 0.56026965,
#  'Loss/localization_loss': 0.08240105,
#  'Loss/regularization_loss': 0.87951714,
#  'Loss/total_loss': 1.5221878,
#  'learning_rate': 0.039635435}
# I0308 04:59:23.427700 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.56026965,
#  'Loss/localization_loss': 0.08240105,
#  'Loss/regularization_loss': 0.87951714,
#  'Loss/total_loss': 1.5221878,
#  'learning_rate': 0.039635435}
# INFO:tensorflow:Step 3500 per-step time 0.904s
# I0308 05:00:53.813941 22600 model_lib_v2.py:705] Step 3500 per-step time 0.904s
# INFO:tensorflow:{'Loss/classification_loss': 0.7660858,
#  'Loss/localization_loss': 0.32759643,
#  'Loss/regularization_loss': 0.8648827,
#  'Loss/total_loss': 1.958565,
#  'learning_rate': 0.03958168}
# I0308 05:00:53.813941 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.7660858,
#  'Loss/localization_loss': 0.32759643,
#  'Loss/regularization_loss': 0.8648827,
#  'Loss/total_loss': 1.958565,
#  'learning_rate': 0.03958168}
# INFO:tensorflow:Step 3600 per-step time 0.905s
# I0308 05:02:24.302005 22600 model_lib_v2.py:705] Step 3600 per-step time 0.905s
# INFO:tensorflow:{'Loss/classification_loss': 0.59875625,
#  'Loss/localization_loss': 0.40725455,
#  'Loss/regularization_loss': 0.85537803,
#  'Loss/total_loss': 1.8613888,
#  'learning_rate': 0.039524276}
# I0308 05:02:24.302005 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.59875625,
#  'Loss/localization_loss': 0.40725455,
#  'Loss/regularization_loss': 0.85537803,
#  'Loss/total_loss': 1.8613888,
#  'learning_rate': 0.039524276}
# INFO:tensorflow:Step 3700 per-step time 0.905s
# I0308 05:03:54.840130 22600 model_lib_v2.py:705] Step 3700 per-step time 0.905s
# INFO:tensorflow:{'Loss/classification_loss': 0.49751082,
#  'Loss/localization_loss': 0.05602424,
#  'Loss/regularization_loss': 0.8575753,
#  'Loss/total_loss': 1.4111103,
#  'learning_rate': 0.03946323}
# I0308 05:03:54.840130 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.49751082,
#  'Loss/localization_loss': 0.05602424,
#  'Loss/regularization_loss': 0.8575753,
#  'Loss/total_loss': 1.4111103,
#  'learning_rate': 0.03946323}
# INFO:tensorflow:Step 3800 per-step time 0.906s
# I0308 05:05:25.406661 22600 model_lib_v2.py:705] Step 3800 per-step time 0.906s
# INFO:tensorflow:{'Loss/classification_loss': 0.69657344,
#  'Loss/localization_loss': 0.19623312,
#  'Loss/regularization_loss': 0.9743569,
#  'Loss/total_loss': 1.8671635,
#  'learning_rate': 0.039398547}
# I0308 05:05:25.406661 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.69657344,
#  'Loss/localization_loss': 0.19623312,
#  'Loss/regularization_loss': 0.9743569,
#  'Loss/total_loss': 1.8671635,
#  'learning_rate': 0.039398547}
# INFO:tensorflow:Step 3900 per-step time 0.907s
# I0308 05:06:56.129601 22600 model_lib_v2.py:705] Step 3900 per-step time 0.907s
# INFO:tensorflow:{'Loss/classification_loss': 0.4663612,
#  'Loss/localization_loss': 0.05986067,
#  'Loss/regularization_loss': 0.95200217,
#  'Loss/total_loss': 1.478224,
#  'learning_rate': 0.039330248}
# I0308 05:06:56.129601 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.4663612,
#  'Loss/localization_loss': 0.05986067,
#  'Loss/regularization_loss': 0.95200217,
#  'Loss/total_loss': 1.478224,
#  'learning_rate': 0.039330248}
# INFO:tensorflow:Step 4000 per-step time 0.907s
# I0308 05:08:26.869375 22600 model_lib_v2.py:705] Step 4000 per-step time 0.907s
# INFO:tensorflow:{'Loss/classification_loss': 0.780203,
#  'Loss/localization_loss': 0.11840447,
#  'Loss/regularization_loss': 0.92841595,
#  'Loss/total_loss': 1.8270234,
#  'learning_rate': 0.039258346}
# I0308 05:08:26.869375 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.780203,
#  'Loss/localization_loss': 0.11840447,
#  'Loss/regularization_loss': 0.92841595,
#  'Loss/total_loss': 1.8270234,
#  'learning_rate': 0.039258346}
# INFO:tensorflow:Step 4100 per-step time 0.919s
# I0308 05:09:58.731476 22600 model_lib_v2.py:705] Step 4100 per-step time 0.919s
# INFO:tensorflow:{'Loss/classification_loss': 0.60284066,
#  'Loss/localization_loss': 0.19216943,
#  'Loss/regularization_loss': 0.9084548,
#  'Loss/total_loss': 1.7034649,
#  'learning_rate': 0.03918285}
# I0308 05:09:58.731476 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.60284066,
#  'Loss/localization_loss': 0.19216943,
#  'Loss/regularization_loss': 0.9084548,
#  'Loss/total_loss': 1.7034649,
#  'learning_rate': 0.03918285}
# INFO:tensorflow:Step 4200 per-step time 0.908s
# I0308 05:11:29.554933 22600 model_lib_v2.py:705] Step 4200 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.49725348,
#  'Loss/localization_loss': 0.0805688,
#  'Loss/regularization_loss': 0.90628886,
#  'Loss/total_loss': 1.4841111,
#  'learning_rate': 0.03910377}
# I0308 05:11:29.554933 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.49725348,
#  'Loss/localization_loss': 0.0805688,
#  'Loss/regularization_loss': 0.90628886,
#  'Loss/total_loss': 1.4841111,
#  'learning_rate': 0.03910377}
# INFO:tensorflow:Step 4300 per-step time 0.909s
# I0308 05:13:00.476650 22600 model_lib_v2.py:705] Step 4300 per-step time 0.909s
# INFO:tensorflow:{'Loss/classification_loss': 0.54389894,
#  'Loss/localization_loss': 0.05376119,
#  'Loss/regularization_loss': 0.89013433,
#  'Loss/total_loss': 1.4877945,
#  'learning_rate': 0.039021127}
# I0308 05:13:00.476650 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.54389894,
#  'Loss/localization_loss': 0.05376119,
#  'Loss/regularization_loss': 0.89013433,
#  'Loss/total_loss': 1.4877945,
#  'learning_rate': 0.039021127}
# INFO:tensorflow:Step 4400 per-step time 0.911s
# I0308 05:14:31.538762 22600 model_lib_v2.py:705] Step 4400 per-step time 0.911s
# INFO:tensorflow:{'Loss/classification_loss': 0.504962,
#  'Loss/localization_loss': 0.022269605,
#  'Loss/regularization_loss': 0.8761432,
#  'Loss/total_loss': 1.4033748,
#  'learning_rate': 0.03893494}
# I0308 05:14:31.539762 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.504962,
#  'Loss/localization_loss': 0.022269605,
#  'Loss/regularization_loss': 0.8761432,
#  'Loss/total_loss': 1.4033748,
#  'learning_rate': 0.03893494}
# INFO:tensorflow:Step 4500 per-step time 0.910s
# I0308 05:16:02.508048 22600 model_lib_v2.py:705] Step 4500 per-step time 0.910s
# INFO:tensorflow:{'Loss/classification_loss': 1.1737618,
#  'Loss/localization_loss': 0.70577157,
#  'Loss/regularization_loss': 0.8588785,
#  'Loss/total_loss': 2.738412,
#  'learning_rate': 0.03884522}
# I0308 05:16:02.509047 22600 model_lib_v2.py:708] {'Loss/classification_loss': 1.1737618,
#  'Loss/localization_loss': 0.70577157,
#  'Loss/regularization_loss': 0.8588785,
#  'Loss/total_loss': 2.738412,
#  'learning_rate': 0.03884522}
# INFO:tensorflow:Step 4600 per-step time 0.909s
# I0308 05:17:33.435283 22600 model_lib_v2.py:705] Step 4600 per-step time 0.909s
# INFO:tensorflow:{'Loss/classification_loss': 0.5013568,
#  'Loss/localization_loss': 0.12275774,
#  'Loss/regularization_loss': 0.84766716,
#  'Loss/total_loss': 1.4717817,
#  'learning_rate': 0.03875198}
# I0308 05:17:33.435283 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5013568,
#  'Loss/localization_loss': 0.12275774,
#  'Loss/regularization_loss': 0.84766716,
#  'Loss/total_loss': 1.4717817,
#  'learning_rate': 0.03875198}
# INFO:tensorflow:Step 4700 per-step time 0.911s
# I0308 05:19:04.582409 22600 model_lib_v2.py:705] Step 4700 per-step time 0.911s
# INFO:tensorflow:{'Loss/classification_loss': 0.46370858,
#  'Loss/localization_loss': 0.08843348,
#  'Loss/regularization_loss': 0.8264232,
#  'Loss/total_loss': 1.3785653,
#  'learning_rate': 0.038655244}
# I0308 05:19:04.582409 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.46370858,
#  'Loss/localization_loss': 0.08843348,
#  'Loss/regularization_loss': 0.8264232,
#  'Loss/total_loss': 1.3785653,
#  'learning_rate': 0.038655244}
# INFO:tensorflow:Step 4800 per-step time 0.911s
# I0308 05:20:35.717074 22600 model_lib_v2.py:705] Step 4800 per-step time 0.911s
# INFO:tensorflow:{'Loss/classification_loss': 0.57300454,
#  'Loss/localization_loss': 0.11191944,
#  'Loss/regularization_loss': 0.8145812,
#  'Loss/total_loss': 1.4995052,
#  'learning_rate': 0.038555026}
# I0308 05:20:35.717074 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.57300454,
#  'Loss/localization_loss': 0.11191944,
#  'Loss/regularization_loss': 0.8145812,
#  'Loss/total_loss': 1.4995052,
#  'learning_rate': 0.038555026}
# INFO:tensorflow:Step 4900 per-step time 0.911s
# I0308 05:22:06.845704 22600 model_lib_v2.py:705] Step 4900 per-step time 0.911s
# INFO:tensorflow:{'Loss/classification_loss': 0.5447059,
#  'Loss/localization_loss': 0.10132826,
#  'Loss/regularization_loss': 0.7952251,
#  'Loss/total_loss': 1.4412593,
#  'learning_rate': 0.038451348}
# I0308 05:22:06.845704 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5447059,
#  'Loss/localization_loss': 0.10132826,
#  'Loss/regularization_loss': 0.7952251,
#  'Loss/total_loss': 1.4412593,
#  'learning_rate': 0.038451348}
# INFO:tensorflow:Step 5000 per-step time 0.912s
# I0308 05:23:38.033063 22600 model_lib_v2.py:705] Step 5000 per-step time 0.912s
# INFO:tensorflow:{'Loss/classification_loss': 0.6430555,
#  'Loss/localization_loss': 0.16028185,
#  'Loss/regularization_loss': 0.8162584,
#  'Loss/total_loss': 1.6195958,
#  'learning_rate': 0.038344227}
# I0308 05:23:38.033063 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.6430555,
#  'Loss/localization_loss': 0.16028185,
#  'Loss/regularization_loss': 0.8162584,
#  'Loss/total_loss': 1.6195958,
#  'learning_rate': 0.038344227}
# INFO:tensorflow:Step 5100 per-step time 0.923s
# I0308 05:25:10.312270 22600 model_lib_v2.py:705] Step 5100 per-step time 0.923s
# INFO:tensorflow:{'Loss/classification_loss': 0.55315286,
#  'Loss/localization_loss': 0.02921441,
#  'Loss/regularization_loss': 0.8033455,
#  'Loss/total_loss': 1.3857127,
#  'learning_rate': 0.03823368}
# I0308 05:25:10.312270 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.55315286,
#  'Loss/localization_loss': 0.02921441,
#  'Loss/regularization_loss': 0.8033455,
#  'Loss/total_loss': 1.3857127,
#  'learning_rate': 0.03823368}
# INFO:tensorflow:Step 5200 per-step time 0.913s
# I0308 05:26:41.587881 22600 model_lib_v2.py:705] Step 5200 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.5051173,
#  'Loss/localization_loss': 0.040860604,
#  'Loss/regularization_loss': 0.7880201,
#  'Loss/total_loss': 1.333998,
#  'learning_rate': 0.038119733}
# I0308 05:26:41.587881 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.5051173,
#  'Loss/localization_loss': 0.040860604,
#  'Loss/regularization_loss': 0.7880201,
#  'Loss/total_loss': 1.333998,
#  'learning_rate': 0.038119733}
# INFO:tensorflow:Step 5300 per-step time 0.913s
# I0308 05:28:12.910424 22600 model_lib_v2.py:705] Step 5300 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.50187236,
#  'Loss/localization_loss': 0.068651915,
#  'Loss/regularization_loss': 0.77599406,
#  'Loss/total_loss': 1.3465183,
#  'learning_rate': 0.03800241}
# I0308 05:28:12.910424 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.50187236,
#  'Loss/localization_loss': 0.068651915,
#  'Loss/regularization_loss': 0.77599406,
#  'Loss/total_loss': 1.3465183,
#  'learning_rate': 0.03800241}
# INFO:tensorflow:Step 5400 per-step time 0.914s
# I0308 05:29:44.281462 22600 model_lib_v2.py:705] Step 5400 per-step time 0.914s
# INFO:tensorflow:{'Loss/classification_loss': 0.46896225,
#  'Loss/localization_loss': 0.103703015,
#  'Loss/regularization_loss': 0.75735456,
#  'Loss/total_loss': 1.3300198,
#  'learning_rate': 0.037881725}
# I0308 05:29:44.282464 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.46896225,
#  'Loss/localization_loss': 0.103703015,
#  'Loss/regularization_loss': 0.75735456,
#  'Loss/total_loss': 1.3300198,
#  'learning_rate': 0.037881725}
# INFO:tensorflow:Step 5500 per-step time 0.914s
# I0308 05:31:15.661748 22600 model_lib_v2.py:705] Step 5500 per-step time 0.914s
# INFO:tensorflow:{'Loss/classification_loss': 0.605662,
#  'Loss/localization_loss': 0.26812798,
#  'Loss/regularization_loss': 0.74059784,
#  'Loss/total_loss': 1.6143878,
#  'learning_rate': 0.037757702}
# I0308 05:31:15.661748 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.605662,
#  'Loss/localization_loss': 0.26812798,
#  'Loss/regularization_loss': 0.74059784,
#  'Loss/total_loss': 1.6143878,
#  'learning_rate': 0.037757702}
# INFO:tensorflow:Step 5600 per-step time 0.913s
# I0308 05:32:46.985249 22600 model_lib_v2.py:705] Step 5600 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.558468,
#  'Loss/localization_loss': 0.019074205,
#  'Loss/regularization_loss': 0.72355056,
#  'Loss/total_loss': 1.3010927,
#  'learning_rate': 0.03763037}
# I0308 05:32:46.985249 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.558468,
#  'Loss/localization_loss': 0.019074205,
#  'Loss/regularization_loss': 0.72355056,
#  'Loss/total_loss': 1.3010927,
#  'learning_rate': 0.03763037}
# INFO:tensorflow:Step 5700 per-step time 0.913s
# I0308 05:34:18.298383 22600 model_lib_v2.py:705] Step 5700 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.6056763,
#  'Loss/localization_loss': 0.19502982,
#  'Loss/regularization_loss': 0.70577794,
#  'Loss/total_loss': 1.5064842,
#  'learning_rate': 0.03749975}
# I0308 05:34:18.298383 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.6056763,
#  'Loss/localization_loss': 0.19502982,
#  'Loss/regularization_loss': 0.70577794,
#  'Loss/total_loss': 1.5064842,
#  'learning_rate': 0.03749975}
# INFO:tensorflow:Step 5800 per-step time 0.913s
# I0308 05:35:49.602945 22600 model_lib_v2.py:705] Step 5800 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.7297108,
#  'Loss/localization_loss': 0.12731639,
#  'Loss/regularization_loss': 0.6878394,
#  'Loss/total_loss': 1.5448666,
#  'learning_rate': 0.037365858}
# I0308 05:35:49.603946 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.7297108,
#  'Loss/localization_loss': 0.12731639,
#  'Loss/regularization_loss': 0.6878394,
#  'Loss/total_loss': 1.5448666,
#  'learning_rate': 0.037365858}
# INFO:tensorflow:Step 5900 per-step time 0.913s
# I0308 05:37:20.912014 22600 model_lib_v2.py:705] Step 5900 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.63688993,
#  'Loss/localization_loss': 0.07470006,
#  'Loss/regularization_loss': 0.6714675,
#  'Loss/total_loss': 1.3830576,
#  'learning_rate': 0.03722873}
# I0308 05:37:20.912014 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.63688993,
#  'Loss/localization_loss': 0.07470006,
#  'Loss/regularization_loss': 0.6714675,
#  'Loss/total_loss': 1.3830576,
#  'learning_rate': 0.03722873}
# INFO:tensorflow:Step 6000 per-step time 0.915s
# I0308 05:38:52.380773 22600 model_lib_v2.py:705] Step 6000 per-step time 0.915s
# INFO:tensorflow:{'Loss/classification_loss': 0.76681834,
#  'Loss/localization_loss': 0.06199731,
#  'Loss/regularization_loss': 0.65545774,
#  'Loss/total_loss': 1.4842733,
#  'learning_rate': 0.037088387}
# I0308 05:38:52.380773 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.76681834,
#  'Loss/localization_loss': 0.06199731,
#  'Loss/regularization_loss': 0.65545774,
#  'Loss/total_loss': 1.4842733,
#  'learning_rate': 0.037088387}
# INFO:tensorflow:Step 6100 per-step time 0.923s
# I0308 05:40:24.657556 22600 model_lib_v2.py:705] Step 6100 per-step time 0.923s
# INFO:tensorflow:{'Loss/classification_loss': 0.39147168,
#  'Loss/localization_loss': 0.12235023,
#  'Loss/regularization_loss': 0.64000213,
#  'Loss/total_loss': 1.1538241,
#  'learning_rate': 0.036944855}
# I0308 05:40:24.658556 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.39147168,
#  'Loss/localization_loss': 0.12235023,
#  'Loss/regularization_loss': 0.64000213,
#  'Loss/total_loss': 1.1538241,
#  'learning_rate': 0.036944855}
# ...
# I0308 09:50:51.406257 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.4292197,
#  'Loss/localization_loss': 0.23886707,
#  'Loss/regularization_loss': 0.16527694,
#  'Loss/total_loss': 0.83336365,
#  'learning_rate': 0.0014449739}
# INFO:tensorflow:Step 22300 per-step time 0.983s
# I0308 09:52:29.733274 22600 model_lib_v2.py:705] Step 22300 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.3730407,
#  'Loss/localization_loss': 0.008742937,
#  'Loss/regularization_loss': 0.16511199,
#  'Loss/total_loss': 0.5468956,
#  'learning_rate': 0.0013447559}
# I0308 09:52:29.733274 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.3730407,
#  'Loss/localization_loss': 0.008742937,
#  'Loss/regularization_loss': 0.16511199,
#  'Loss/total_loss': 0.5468956,
#  'learning_rate': 0.0013447559}
# INFO:tensorflow:Step 22400 per-step time 0.985s
# I0308 09:54:08.230666 22600 model_lib_v2.py:705] Step 22400 per-step time 0.985s
# INFO:tensorflow:{'Loss/classification_loss': 0.291472,
#  'Loss/localization_loss': 0.12754522,
#  'Loss/regularization_loss': 0.16496485,
#  'Loss/total_loss': 0.58398205,
#  'learning_rate': 0.0012480199}
# I0308 09:54:08.230666 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.291472,
#  'Loss/localization_loss': 0.12754522,
#  'Loss/regularization_loss': 0.16496485,
#  'Loss/total_loss': 0.58398205,
#  'learning_rate': 0.0012480199}
# INFO:tensorflow:Step 22500 per-step time 0.984s
# I0308 09:55:46.649298 22600 model_lib_v2.py:705] Step 22500 per-step time 0.984s
# INFO:tensorflow:{'Loss/classification_loss': 0.24443465,
#  'Loss/localization_loss': 0.04930348,
#  'Loss/regularization_loss': 0.16482523,
#  'Loss/total_loss': 0.45856336,
#  'learning_rate': 0.0011547804}
# I0308 09:55:46.649298 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.24443465,
#  'Loss/localization_loss': 0.04930348,
#  'Loss/regularization_loss': 0.16482523,
#  'Loss/total_loss': 0.45856336,
#  'learning_rate': 0.0011547804}
# INFO:tensorflow:Step 22600 per-step time 0.984s
# I0308 09:57:25.030473 22600 model_lib_v2.py:705] Step 22600 per-step time 0.984s
# INFO:tensorflow:{'Loss/classification_loss': 0.39446047,
#  'Loss/localization_loss': 0.023205139,
#  'Loss/regularization_loss': 0.16470209,
#  'Loss/total_loss': 0.5823677,
#  'learning_rate': 0.0010650586}
# I0308 09:57:25.030473 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.39446047,
#  'Loss/localization_loss': 0.023205139,
#  'Loss/regularization_loss': 0.16470209,
#  'Loss/total_loss': 0.5823677,
#  'learning_rate': 0.0010650586}
# INFO:tensorflow:Step 22700 per-step time 0.984s
# I0308 09:59:03.410315 22600 model_lib_v2.py:705] Step 22700 per-step time 0.984s
# INFO:tensorflow:{'Loss/classification_loss': 0.27675,
#  'Loss/localization_loss': 0.035193216,
#  'Loss/regularization_loss': 0.16458426,
#  'Loss/total_loss': 0.47652745,
#  'learning_rate': 0.0009788703}
# I0308 09:59:03.410315 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.27675,
#  'Loss/localization_loss': 0.035193216,
#  'Loss/regularization_loss': 0.16458426,
#  'Loss/total_loss': 0.47652745,
#  'learning_rate': 0.0009788703}
# INFO:tensorflow:Step 22800 per-step time 0.983s
# I0308 10:00:41.732333 22600 model_lib_v2.py:705] Step 22800 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.59293455,
#  'Loss/localization_loss': 0.2108965,
#  'Loss/regularization_loss': 0.16447753,
#  'Loss/total_loss': 0.96830857,
#  'learning_rate': 0.00089622854}
# I0308 10:00:41.732333 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.59293455,
#  'Loss/localization_loss': 0.2108965,
#  'Loss/regularization_loss': 0.16447753,
#  'Loss/total_loss': 0.96830857,
#  'learning_rate': 0.00089622854}
# INFO:tensorflow:Step 22900 per-step time 0.983s
# I0308 10:02:20.058990 22600 model_lib_v2.py:705] Step 22900 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.41715574,
#  'Loss/localization_loss': 0.08365454,
#  'Loss/regularization_loss': 0.16437471,
#  'Loss/total_loss': 0.665185,
#  'learning_rate': 0.00081715226}
# I0308 10:02:20.074344 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.41715574,
#  'Loss/localization_loss': 0.08365454,
#  'Loss/regularization_loss': 0.16437471,
#  'Loss/total_loss': 0.665185,
#  'learning_rate': 0.00081715226}
# INFO:tensorflow:Step 23000 per-step time 0.984s
# I0308 10:03:58.501004 22600 model_lib_v2.py:705] Step 23000 per-step time 0.984s
# INFO:tensorflow:{'Loss/classification_loss': 0.49684942,
#  'Loss/localization_loss': 0.026813786,
#  'Loss/regularization_loss': 0.1642796,
#  'Loss/total_loss': 0.6879428,
#  'learning_rate': 0.0007416546}
# I0308 10:03:58.501004 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.49684942,
#  'Loss/localization_loss': 0.026813786,
#  'Loss/regularization_loss': 0.1642796,
#  'Loss/total_loss': 0.6879428,
#  'learning_rate': 0.0007416546}
# INFO:tensorflow:Step 23100 per-step time 0.994s
# I0308 10:05:37.875053 22600 model_lib_v2.py:705] Step 23100 per-step time 0.994s
# INFO:tensorflow:{'Loss/classification_loss': 0.46863145,
#  'Loss/localization_loss': 0.14789398,
#  'Loss/regularization_loss': 0.16419783,
#  'Loss/total_loss': 0.7807233,
#  'learning_rate': 0.0006697476}
# I0308 10:05:37.875053 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.46863145,
#  'Loss/localization_loss': 0.14789398,
#  'Loss/regularization_loss': 0.16419783,
#  'Loss/total_loss': 0.7807233,
#  'learning_rate': 0.0006697476}
# INFO:tensorflow:Step 23200 per-step time 0.982s
# I0308 10:07:16.120731 22600 model_lib_v2.py:705] Step 23200 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.27043563,
#  'Loss/localization_loss': 0.08283153,
#  'Loss/regularization_loss': 0.16412643,
#  'Loss/total_loss': 0.5173936,
#  'learning_rate': 0.0006014514}
# I0308 10:07:16.120731 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.27043563,
#  'Loss/localization_loss': 0.08283153,
#  'Loss/regularization_loss': 0.16412643,
#  'Loss/total_loss': 0.5173936,
#  'learning_rate': 0.0006014514}
# INFO:tensorflow:Step 23300 per-step time 0.983s
# I0308 10:08:54.410998 22600 model_lib_v2.py:705] Step 23300 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.42763883,
#  'Loss/localization_loss': 0.006324538,
#  'Loss/regularization_loss': 0.16405052,
#  'Loss/total_loss': 0.5980139,
#  'learning_rate': 0.000536772}
# I0308 10:08:54.410998 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.42763883,
#  'Loss/localization_loss': 0.006324538,
#  'Loss/regularization_loss': 0.16405052,
#  'Loss/total_loss': 0.5980139,
#  'learning_rate': 0.000536772}
# INFO:tensorflow:Step 23400 per-step time 0.981s
# I0308 10:10:32.514197 22600 model_lib_v2.py:705] Step 23400 per-step time 0.981s
# INFO:tensorflow:{'Loss/classification_loss': 0.32526737,
#  'Loss/localization_loss': 0.07957353,
#  'Loss/regularization_loss': 0.1639886,
#  'Loss/total_loss': 0.5688295,
#  'learning_rate': 0.00047572254}
# I0308 10:10:32.514197 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.32526737,
#  'Loss/localization_loss': 0.07957353,
#  'Loss/regularization_loss': 0.1639886,
#  'Loss/total_loss': 0.5688295,
#  'learning_rate': 0.00047572254}
# INFO:tensorflow:Step 23500 per-step time 0.982s
# I0308 10:12:10.670610 22600 model_lib_v2.py:705] Step 23500 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.404761,
#  'Loss/localization_loss': 0.04674122,
#  'Loss/regularization_loss': 0.1639334,
#  'Loss/total_loss': 0.6154356,
#  'learning_rate': 0.0004183185}
# I0308 10:12:10.670610 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.404761,
#  'Loss/localization_loss': 0.04674122,
#  'Loss/regularization_loss': 0.1639334,
#  'Loss/total_loss': 0.6154356,
#  'learning_rate': 0.0004183185}
# INFO:tensorflow:Step 23600 per-step time 0.982s
# I0308 10:13:48.913223 22600 model_lib_v2.py:705] Step 23600 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.22027409,
#  'Loss/localization_loss': 0.0041155308,
#  'Loss/regularization_loss': 0.16388766,
#  'Loss/total_loss': 0.3882773,
#  'learning_rate': 0.00036456465}
# I0308 10:13:48.913223 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.22027409,
#  'Loss/localization_loss': 0.0041155308,
#  'Loss/regularization_loss': 0.16388766,
#  'Loss/total_loss': 0.3882773,
#  'learning_rate': 0.00036456465}
# INFO:tensorflow:Step 23700 per-step time 0.983s
# I0308 10:15:27.186943 22600 model_lib_v2.py:705] Step 23700 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.22975418,
#  'Loss/localization_loss': 0.051915992,
#  'Loss/regularization_loss': 0.16384514,
#  'Loss/total_loss': 0.44551533,
#  'learning_rate': 0.0003144765}
# I0308 10:15:27.186943 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.22975418,
#  'Loss/localization_loss': 0.051915992,
#  'Loss/regularization_loss': 0.16384514,
#  'Loss/total_loss': 0.44551533,
#  'learning_rate': 0.0003144765}
# INFO:tensorflow:Step 23800 per-step time 0.982s
# I0308 10:17:05.369648 22600 model_lib_v2.py:705] Step 23800 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.19493286,
#  'Loss/localization_loss': 0.018809227,
#  'Loss/regularization_loss': 0.16381082,
#  'Loss/total_loss': 0.3775529,
#  'learning_rate': 0.00026806234}
# I0308 10:17:05.369648 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.19493286,
#  'Loss/localization_loss': 0.018809227,
#  'Loss/regularization_loss': 0.16381082,
#  'Loss/total_loss': 0.3775529,
#  'learning_rate': 0.00026806234}
# INFO:tensorflow:Step 23900 per-step time 0.983s
# I0308 10:18:43.655869 22600 model_lib_v2.py:705] Step 23900 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.36625853,
#  'Loss/localization_loss': 0.0299189,
#  'Loss/regularization_loss': 0.16378038,
#  'Loss/total_loss': 0.5599578,
#  'learning_rate': 0.00022532581}
# I0308 10:18:43.662877 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.36625853,
#  'Loss/localization_loss': 0.0299189,
#  'Loss/regularization_loss': 0.16378038,
#  'Loss/total_loss': 0.5599578,
#  'learning_rate': 0.00022532581}
# INFO:tensorflow:Step 24000 per-step time 0.982s
# I0308 10:20:21.879776 22600 model_lib_v2.py:705] Step 24000 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.37375826,
#  'Loss/localization_loss': 0.06062807,
#  'Loss/regularization_loss': 0.16375585,
#  'Loss/total_loss': 0.59814215,
#  'learning_rate': 0.0001862812}
# I0308 10:20:21.879776 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.37375826,
#  'Loss/localization_loss': 0.06062807,
#  'Loss/regularization_loss': 0.16375585,
#  'Loss/total_loss': 0.59814215,
#  'learning_rate': 0.0001862812}
# INFO:tensorflow:Step 24100 per-step time 0.991s
# I0308 10:22:00.966437 22600 model_lib_v2.py:705] Step 24100 per-step time 0.991s
# INFO:tensorflow:{'Loss/classification_loss': 0.28595278,
#  'Loss/localization_loss': 0.014977318,
#  'Loss/regularization_loss': 0.16373567,
#  'Loss/total_loss': 0.46466574,
#  'learning_rate': 0.00015093207}
# I0308 10:22:00.966437 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.28595278,
#  'Loss/localization_loss': 0.014977318,
#  'Loss/regularization_loss': 0.16373567,
#  'Loss/total_loss': 0.46466574,
#  'learning_rate': 0.00015093207}
# INFO:tensorflow:Step 24200 per-step time 0.983s
# I0308 10:23:39.221195 22600 model_lib_v2.py:705] Step 24200 per-step time 0.983s
# INFO:tensorflow:{'Loss/classification_loss': 0.33984923,
#  'Loss/localization_loss': 0.048000585,
#  'Loss/regularization_loss': 0.1637191,
#  'Loss/total_loss': 0.5515689,
#  'learning_rate': 0.00011928677}
# I0308 10:23:39.221195 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.33984923,
#  'Loss/localization_loss': 0.048000585,
#  'Loss/regularization_loss': 0.1637191,
#  'Loss/total_loss': 0.5515689,
#  'learning_rate': 0.00011928677}
# INFO:tensorflow:Step 24300 per-step time 0.981s
# I0308 10:25:17.319098 22600 model_lib_v2.py:705] Step 24300 per-step time 0.981s
# INFO:tensorflow:{'Loss/classification_loss': 0.251048,
#  'Loss/localization_loss': 0.005274684,
#  'Loss/regularization_loss': 0.16370755,
#  'Loss/total_loss': 0.42003024,
#  'learning_rate': 9.135008e-05}
# I0308 10:25:17.319098 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.251048,
#  'Loss/localization_loss': 0.005274684,
#  'Loss/regularization_loss': 0.16370755,
#  'Loss/total_loss': 0.42003024,
#  'learning_rate': 9.135008e-05}
# INFO:tensorflow:Step 24400 per-step time 0.982s
# I0308 10:26:55.521789 22600 model_lib_v2.py:705] Step 24400 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.41016555,
#  'Loss/localization_loss': 0.03367937,
#  'Loss/regularization_loss': 0.16369703,
#  'Loss/total_loss': 0.6075419,
#  'learning_rate': 6.712794e-05}
# I0308 10:26:55.521789 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.41016555,
#  'Loss/localization_loss': 0.03367937,
#  'Loss/regularization_loss': 0.16369703,
#  'Loss/total_loss': 0.6075419,
#  'learning_rate': 6.712794e-05}
# INFO:tensorflow:Step 24500 per-step time 0.981s
# I0308 10:28:33.640836 22600 model_lib_v2.py:705] Step 24500 per-step time 0.981s
# INFO:tensorflow:{'Loss/classification_loss': 0.23524101,
#  'Loss/localization_loss': 0.017188283,
#  'Loss/regularization_loss': 0.16369031,
#  'Loss/total_loss': 0.4161196,
#  'learning_rate': 4.6623943e-05}
# I0308 10:28:33.640836 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.23524101,
#  'Loss/localization_loss': 0.017188283,
#  'Loss/regularization_loss': 0.16369031,
#  'Loss/total_loss': 0.4161196,
#  'learning_rate': 4.6623943e-05}
# INFO:tensorflow:Step 24600 per-step time 0.981s
# I0308 10:30:11.749640 22600 model_lib_v2.py:705] Step 24600 per-step time 0.981s
# INFO:tensorflow:{'Loss/classification_loss': 0.28785688,
#  'Loss/localization_loss': 0.016490182,
#  'Loss/regularization_loss': 0.16368587,
#  'Loss/total_loss': 0.46803293,
#  'learning_rate': 2.9844045e-05}
# I0308 10:30:11.749640 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.28785688,
#  'Loss/localization_loss': 0.016490182,
#  'Loss/regularization_loss': 0.16368587,
#  'Loss/total_loss': 0.46803293,
#  'learning_rate': 2.9844045e-05}
# INFO:tensorflow:Step 24700 per-step time 0.982s
# I0308 10:31:49.943058 22600 model_lib_v2.py:705] Step 24700 per-step time 0.982s
# INFO:tensorflow:{'Loss/classification_loss': 0.3633581,
#  'Loss/localization_loss': 0.008478114,
#  'Loss/regularization_loss': 0.16368292,
#  'Loss/total_loss': 0.5355191,
#  'learning_rate': 1.6789436e-05}
# I0308 10:31:49.943058 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.3633581,
#  'Loss/localization_loss': 0.008478114,
#  'Loss/regularization_loss': 0.16368292,
#  'Loss/total_loss': 0.5355191,
#  'learning_rate': 1.6789436e-05}
# INFO:tensorflow:Step 24800 per-step time 0.981s
# I0308 10:33:28.056830 22600 model_lib_v2.py:705] Step 24800 per-step time 0.981s
# INFO:tensorflow:{'Loss/classification_loss': 0.29210278,
#  'Loss/localization_loss': 0.016505439,
#  'Loss/regularization_loss': 0.1636815,
#  'Loss/total_loss': 0.47228974,
#  'learning_rate': 7.4625013e-06}
# I0308 10:33:28.056830 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.29210278,
#  'Loss/localization_loss': 0.016505439,
#  'Loss/regularization_loss': 0.1636815,
#  'Loss/total_loss': 0.47228974,
#  'learning_rate': 7.4625013e-06}
# INFO:tensorflow:Step 24900 per-step time 0.979s
# I0308 10:35:05.988872 22600 model_lib_v2.py:705] Step 24900 per-step time 0.979s
# INFO:tensorflow:{'Loss/classification_loss': 0.18462262,
#  'Loss/localization_loss': 0.019436544,
#  'Loss/regularization_loss': 0.16368099,
#  'Loss/total_loss': 0.36774015,
#  'learning_rate': 1.8656253e-06}
# I0308 10:35:05.988872 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.18462262,
#  'Loss/localization_loss': 0.019436544,
#  'Loss/regularization_loss': 0.16368099,
#  'Loss/total_loss': 0.36774015,
#  'learning_rate': 1.8656253e-06}
# INFO:tensorflow:Step 25000 per-step time 0.980s
# I0308 10:36:44.001748 22600 model_lib_v2.py:705] Step 25000 per-step time 0.980s
# INFO:tensorflow:{'Loss/classification_loss': 0.33664715,
#  'Loss/localization_loss': 0.011695294,
#  'Loss/regularization_loss': 0.1636809,
#  'Loss/total_loss': 0.5120233,
#  'learning_rate': 0.0}
# I0308 10:36:44.001748 22600 model_lib_v2.py:708] {'Loss/classification_loss': 0.33664715,
#  'Loss/localization_loss': 0.011695294,
#  'Loss/regularization_loss': 0.1636809,
#  'Loss/total_loss': 0.5120233,
#  'learning_rate': 0.0}

# %%
# !python {SCRIPT_PATH + '/exporter_main_v2.py'} --input_type image_tensor --pipeline_config_path {CONFIG_PATH} --trained_checkpoint_dir {MODEL_PATH + '/' } --output_directory exported-models\my-model
# Out:
# 2024-03-08 10:36:58.282892: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-08 10:36:58.714748: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0308 10:36:58.923770 21752 deprecation.py:623] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0308 10:37:02.357849 21752 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0308 10:37:15.938494 21752 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0308 10:37:25.524055 21752 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001FA3357AB20>, because it is not built.
# W0308 10:37:32.952427 21752 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000001FA3357AB20>, because it is not built.
# W0308 10:37:45.932223 21752 save.py:233] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 278). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exported-models\my-model\saved_model\assets
# I0308 10:37:51.731853 21752 builder_impl.py:779] Assets written to: exported-models\my-model\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to exported-models\my-model\pipeline.config
# I0308 10:37:52.453448 21752 config_util.py:253] Writing pipeline config file to exported-models\my-model\pipeline.config

# %% [markdown]
# Inferencing My Trained Models

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
# from google.colab.patches import cv2_imshow

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = 'D:/Traffic SignBoard Recognition using Deep Learning/Dataset/PASCAL VOC Format Dataset/valid/all_motor_vehicle_prohibited-0_jpg.rf.5c76a51a967738c85efb52f70bf4c981.jpg'

# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = './exported-models/my-model'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = ANNOTATION_PATH + '/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

print('Running inference for {}... '.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
      image_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=2,
      min_score_thresh=0.8,
      agnostic_mode=False)

print('Done')
# DISPLAYS OUTPUT IMAGE
cv2.imshow('test', image_with_detections)
# CLOSES WINDOW ONCE KEY IS PRESSED
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Loading model...Done! Took 11.306719303131104 seconds
# Running inference for D:/Traffic SignBoard Recognition using Deep Learning/Dataset/PASCAL VOC Format Dataset/valid/all_motor_vehicle_prohibited-0_jpg.rf.5c76a51a967738c85efb52f70bf4c981.jpg... Done

# %%
# import os
# from object_detection.utils import label_map_util
# from object_detection.utils import visualization_utils as viz_utils
# from object_detection.builders import model_builder

# CHECKPONT_PATH = MODEL_PATH + '/'

# #load pipeline config and build a detection model
# configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
# detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# #Restore checkpoint
# ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
# ckpt.restore(os.path.join(CHECKPONT_PATH, 'ckpt-16')).expect_partial()

# @tf.function
# def detect_fn(image):
#     image, shapes = detection_model.preprocess(image)
#     prediction_dict = detection_model.predict(image, shapes)
#     detections = detection_model.postprocess(prediction_dict, shapes)
#     return detections

# import cv2
# import numpy as np

# category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt', use_display_name=True)

# #Setup Capture
# cap = cv2.VideoCapture(0)
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# while True:
#     ret, frame = cap.read()
#     image_np = np.array(frame)

#     input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
#     detections = detect_fn(input_tensor)

#     num_detections = int(detections.pop('num_detections'))
#     detections = {key: value[0, :num_detections].numpy()
#                   for key, value in detections.items()}
#     detections['num_detections'] = num_detections
    
#     # detection_classes should be ints.
#     detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

#     label_id_offset = 1
#     image_np_with_detections = image_np.copy()

#     viz_utils.visualize_boxes_and_labels_on_image_array(
#       image_np_with_detections,
#       detections['detection_boxes'],
#       detections['detection_classes']+label_id_offset,
#       detections['detection_scores'],
#       category_index,
#       use_normalized_coordinates=True,
#       max_boxes_to_draw=1,
#       min_score_thresh=0.5,
#       agnostic_mode=False)

#     cv2.imshow('object detection', cv2.resize(image_np_with_detections, (800, 600)))

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#       cap.release()
#       break

# %%
# !tensorboard --logdir D:/"Traffic SignBoard Recognition using Deep Learning"/"SSD ResNet50 V1 FPN 640x640 (RetinaNet50)"/models/ssd_resnet50_v1_fpn_640x640_retinanet50 --host localhost --port 6011
# Out:
# ^C

# %% [markdown]
# ## Evaluation Model:

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'} --checkpoint_dir={MODEL_PATH}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=4.63s).
# Accumulating evaluation results...
# DONE (t=1.54s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.398
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.285
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.810
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.662
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.831
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0313 12:18:45.719954 14208 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0313 12:18:45.719954 14208 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0313 12:18:45.719954 14208 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0313 12:18:45.719954 14208 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0313 12:18:45.719954 14208 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2024-03-13 12:18:45.722222: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 12:18:46.140374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# I0313 12:18:46.252506 14208 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# I0313 12:18:46.252506 14208 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0313 12:18:46.252506 14208 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0313 12:18:46.252506 14208 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0313 12:18:46.254506 14208 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0313 12:18:46.275519 14208 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0313 12:18:49.494923 14208 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 12:18:50.330993 14208 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at ./models/ssd_resnet50_v1_fpn_640x640_retinanet50
# I0313 12:18:52.469325 14208 checkpoint_utils.py:136] Waiting for new checkpoint at ./models/ssd_resnet50_v1_fpn_640x640_retinanet50
# INFO:tensorflow:Found new checkpoint at ./models/ssd_resnet50_v1_fpn_640x640_retinanet50\ckpt-26
# I0313 12:18:52.475323 14208 checkpoint_utils.py:145] Found new checkpoint at ./models/ssd_resnet50_v1_fpn_640x640_retinanet50\ckpt-26
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0313 12:18:56.890094 14208 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0313 12:19:12.795315 14208 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-13 12:19:23.969948: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-13 12:19:25.092070: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.092550: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.133135: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.133564: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.302462: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.302959: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.548557: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.549019: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.777073: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:19:25.777491: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 12:19:27.475669 14208 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0313 12:19:27.482668 14208 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0313 12:19:27.608149 14208 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0313 12:19:51.631162 14208 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0313 12:20:14.536058 14208 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0313 12:20:37.577979 14208 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Finished eval step 400
# I0313 12:21:00.743177 14208 model_lib_v2.py:966] Finished eval step 400
# INFO:tensorflow:Finished eval step 500
# I0313 12:21:24.026469 14208 model_lib_v2.py:966] Finished eval step 500
# INFO:tensorflow:Finished eval step 600
# I0313 12:21:47.574111 14208 model_lib_v2.py:966] Finished eval step 600
# INFO:tensorflow:Performing evaluation on 665 images.
# I0313 12:22:02.481394 14208 coco_evaluation.py:293] Performing evaluation on 665 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0313 12:22:02.483394 14208 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.04s)
# I0313 12:22:02.524395 14208 coco_tools.py:138] DONE (t=0.04s)
# INFO:tensorflow:Eval metrics at step 25000
# I0313 12:22:08.874667 14208 model_lib_v2.py:1015] Eval metrics at step 25000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.279869
# I0313 12:22:08.887624 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.279869
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.353269
# I0313 12:22:08.890624 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.353269
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.332517
# I0313 12:22:08.891623 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.332517
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.060594
# I0313 12:22:08.893624 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.060594
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.397940
# I0313 12:22:08.895623 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.397940
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.284819
# I0313 12:22:08.897637 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.284819
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.809876
# I0313 12:22:08.898636 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.809876
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.818661
# I0313 12:22:08.900623 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.818661
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.818958
# I0313 12:22:08.902623 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.818958
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.060000
# I0313 12:22:08.904632 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.060000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.661905
# I0313 12:22:08.906624 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.661905
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.831243
# I0313 12:22:08.909624 14208 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.831243
# INFO:tensorflow:	+ Loss/localization_loss: 0.044726
# I0313 12:22:08.911629 14208 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.044726
# INFO:tensorflow:	+ Loss/classification_loss: 0.458892
# I0313 12:22:08.912624 14208 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.458892
# INFO:tensorflow:	+ Loss/regularization_loss: 0.163681
# I0313 12:22:08.914636 14208 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.163681
# INFO:tensorflow:	+ Loss/total_loss: 0.667299
# I0313 12:22:08.915624 14208 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.667299
# INFO:tensorflow:Exiting evaluation at step 25000
# I0313 12:22:09.209210 14208 model_lib_v2.py:1168] Exiting evaluation at step 25000
