# %% [markdown]
# # Traffic SignBoard Detection - SSD MobileNet V1 FPN 640x640:

# %% [markdown]
# ## 1. DOWNLOAD THE PRETRAINED MODELS FROM THE TENSOFLOW MODEL ZOO

# %%
import os

# DATA_DIR = os.path.join(os.getcwd(), 'data')
MODELS_DIR = os.path.join('pre-trained-model')
for dir in [MODELS_DIR]:
    if not os.path.exists(dir):
        os.mkdir(dir)

# %%
main_directory = 'models'
subfolder_name = 'ssd_mobilenet_v1_fpn_640x640'

main_directory_path = os.path.join(os.getcwd(), main_directory)
subfolder_path = os.path.join(main_directory_path, subfolder_name)

if not os.path.exists(subfolder_path):
    os.makedirs(subfolder_path)

# %%
import tarfile
import urllib.request
import os

# Download and extract model
MODEL_DATE = '20200711'
MODEL_NAME = 'ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8'
MODEL_TAR_FILENAME = MODEL_NAME + '.tar.gz'
MODELS_DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/'
MODEL_DOWNLOAD_LINK = MODELS_DOWNLOAD_BASE + MODEL_DATE + '/' + MODEL_TAR_FILENAME
PATH_TO_MODEL_TAR = os.path.join(MODELS_DIR, MODEL_TAR_FILENAME)
PATH_TO_CKPT = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'checkpoint/'))
PATH_TO_CFG = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'pipeline.config'))
if not os.path.exists(PATH_TO_CKPT):
    print('Downloading model. This may take a while... ', end='')
    urllib.request.urlretrieve(MODEL_DOWNLOAD_LINK, PATH_TO_MODEL_TAR)
    tar_file = tarfile.open(PATH_TO_MODEL_TAR)
    tar_file.extractall(MODELS_DIR)
    tar_file.close()
    os.remove(PATH_TO_MODEL_TAR)
    print('Done')

# %% [markdown]
# ## 2. SETUP PATHS:

# %%
WORKSPACE_PATH = '../training_helper_directory'
SCRIPT_PATH = WORKSPACE_PATH + '/scripts'
ANNOTATION_PATH = WORKSPACE_PATH + '/annotations'

IMAGE_PATH = '../Dataset/"PASCAL VOC Format Dataset"'

CUSTOM_MODEL_NAME = '/ssd_mobilenet_v1_fpn_640x640'
MODEL_PATH = './models' + CUSTOM_MODEL_NAME

PRETRAINED_PATH = './pre-trained-model/' + MODEL_NAME
CONFIG_PATH = MODEL_PATH + '/pipeline.config'

EXPORT_PATH = '../exported-models/my-model'

# %% [markdown]
# ## 3. CREATE TF RECORDS:

# %%
# Create train data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train-old'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}

# Create test data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: ../training_helper_directory/annotations/train.record
# Successfully created the TFRecord file: ../training_helper_directory/annotations/test.record

# %% [markdown]
# ## 4. COPY MODEL CONFIG FILE TO TRANING FOLDER:

# %%
SOURCE_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\SSD MobileNet V1 FPN 640x640\pre-trained-model\ssd_mobilenet_v1_fpn_640x640_coco17_tpu-8\pipeline.config"
DESTINATION_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\SSD MobileNet V1 FPN 640x640\models\ssd_mobilenet_v1_fpn_640x640"

# %%
# !copy "{SOURCE_PATH}" "{DESTINATION_PATH}"
# Out:
#         1 file(s) copied.

# %% [markdown]
# ## 5. UPDATING CONFIG FOR TRANSFER LEARNING:

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v1_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 256
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 64
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.03999999910593033
#          total_steps: 25000
#          warmup_learning_rate: 0.013333000242710114
#          warmup_steps: 2000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 25000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false
#  batch_size: 1,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = 56

pipeline_config.train_config.batch_size = 2
pipeline_config.train_config.num_steps = 25000

pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_PATH + '/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection" 

pipeline_config.train_input_reader.label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH+ '/train.record'] 
pipeline_config.train_input_reader.shuffle = True

pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:
    f.write(config_text)

# %% [markdown]
# ## 6. TRAIN THE MODEL:

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.getcwd()
# Out:
# 'd:\\Traffic SignBoard Recognition using Deep Learning\\SSD MobileNet V1 FPN 640x640'

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'}
# Out:
# 2024-03-10 15:08:01.647176: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 15:08:02.610090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0310 15:08:06.267137 22584 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0310 15:08:06.273956 22584 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0310 15:08:06.273956 22584 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0310 15:08:06.297189 22584 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# I0310 15:08:06.315246 22584 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# I0310 15:08:06.315622 22584 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0310 15:08:06.315622 22584 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0310 15:08:06.315622 22584 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0310 15:08:06.325355 22584 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0310 15:08:06.373727 22584 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0310 15:08:12.022671 22584 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0310 15:08:14.511537 22584 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0310 15:08:15.897348 22584 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0310 15:08:21.811865 23188 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0310 15:08:29.009367 18224 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-10 15:08:33.062066: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-10 15:08:36.838677: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:08:36.844018: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:08:37.224419: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:08:37.224857: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:08:38.211598: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:08:38.212007: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.721331 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.723232 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.724246 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.725245 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.726250 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.727245 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.728244 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.729246 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.730246 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0310 15:08:39.730246 22584 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0310 15:08:40.306994 11560 deprecation.py:554] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0310 15:08:40.764135 11560 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0310 15:08:45.054934 11236 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0310 15:08:48.893743 13396 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0310 15:08:53.096900 16276 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-10 15:09:05.241833: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:09:05.242222: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:09:05.302625: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 15:09:05.303141: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# INFO:tensorflow:Step 100 per-step time 1.039s
# I0310 15:10:23.900227 22584 model_lib_v2.py:705] Step 100 per-step time 1.039s
# INFO:tensorflow:{'Loss/classification_loss': 1.2282587,
#  'Loss/localization_loss': 0.16687731,
#  'Loss/regularization_loss': 0.7763089,
#  'Loss/total_loss': 2.171445,
#  'learning_rate': 0.014666351}
# I0310 15:10:23.900227 22584 model_lib_v2.py:708] {'Loss/classification_loss': 1.2282587,
#  'Loss/localization_loss': 0.16687731,
#  'Loss/regularization_loss': 0.7763089,
#  'Loss/total_loss': 2.171445,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.518s
# I0310 15:11:15.655853 22584 model_lib_v2.py:705] Step 200 per-step time 0.518s
# INFO:tensorflow:{'Loss/classification_loss': 0.8442279,
#  'Loss/localization_loss': 0.05510002,
#  'Loss/regularization_loss': 0.7758878,
#  'Loss/total_loss': 1.6752157,
#  'learning_rate': 0.0159997}
# I0310 15:11:15.655853 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.8442279,
#  'Loss/localization_loss': 0.05510002,
#  'Loss/regularization_loss': 0.7758878,
#  'Loss/total_loss': 1.6752157,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.519s
# I0310 15:12:07.603774 22584 model_lib_v2.py:705] Step 300 per-step time 0.519s
# INFO:tensorflow:{'Loss/classification_loss': 0.8361286,
#  'Loss/localization_loss': 0.082281694,
#  'Loss/regularization_loss': 0.77531666,
#  'Loss/total_loss': 1.6937269,
#  'learning_rate': 0.01733305}
# I0310 15:12:07.603774 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.8361286,
#  'Loss/localization_loss': 0.082281694,
#  'Loss/regularization_loss': 0.77531666,
#  'Loss/total_loss': 1.6937269,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.528s
# I0310 15:13:00.448860 22584 model_lib_v2.py:705] Step 400 per-step time 0.528s
# INFO:tensorflow:{'Loss/classification_loss': 0.67595845,
#  'Loss/localization_loss': 0.06965195,
#  'Loss/regularization_loss': 0.77459586,
#  'Loss/total_loss': 1.5202063,
#  'learning_rate': 0.0186664}
# I0310 15:13:00.448860 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.67595845,
#  'Loss/localization_loss': 0.06965195,
#  'Loss/regularization_loss': 0.77459586,
#  'Loss/total_loss': 1.5202063,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.534s
# I0310 15:13:53.829737 22584 model_lib_v2.py:705] Step 500 per-step time 0.534s
# INFO:tensorflow:{'Loss/classification_loss': 0.6173017,
#  'Loss/localization_loss': 0.048417013,
#  'Loss/regularization_loss': 0.773916,
#  'Loss/total_loss': 1.4396347,
#  'learning_rate': 0.01999975}
# I0310 15:13:53.829737 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.6173017,
#  'Loss/localization_loss': 0.048417013,
#  'Loss/regularization_loss': 0.773916,
#  'Loss/total_loss': 1.4396347,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.538s
# I0310 15:14:47.615305 22584 model_lib_v2.py:705] Step 600 per-step time 0.538s
# INFO:tensorflow:{'Loss/classification_loss': 0.36425748,
#  'Loss/localization_loss': 0.07317198,
#  'Loss/regularization_loss': 0.7731417,
#  'Loss/total_loss': 1.2105712,
#  'learning_rate': 0.0213331}
# I0310 15:14:47.616308 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.36425748,
#  'Loss/localization_loss': 0.07317198,
#  'Loss/regularization_loss': 0.7731417,
#  'Loss/total_loss': 1.2105712,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.544s
# I0310 15:15:41.965580 22584 model_lib_v2.py:705] Step 700 per-step time 0.544s
# INFO:tensorflow:{'Loss/classification_loss': 0.52927387,
#  'Loss/localization_loss': 0.06326069,
#  'Loss/regularization_loss': 0.7723107,
#  'Loss/total_loss': 1.3648452,
#  'learning_rate': 0.02266645}
# I0310 15:15:41.965580 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.52927387,
#  'Loss/localization_loss': 0.06326069,
#  'Loss/regularization_loss': 0.7723107,
#  'Loss/total_loss': 1.3648452,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.546s
# I0310 15:16:36.526578 22584 model_lib_v2.py:705] Step 800 per-step time 0.546s
# INFO:tensorflow:{'Loss/classification_loss': 0.67494273,
#  'Loss/localization_loss': 0.108688295,
#  'Loss/regularization_loss': 0.77134275,
#  'Loss/total_loss': 1.5549738,
#  'learning_rate': 0.023999799}
# I0310 15:16:36.527578 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.67494273,
#  'Loss/localization_loss': 0.108688295,
#  'Loss/regularization_loss': 0.77134275,
#  'Loss/total_loss': 1.5549738,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.547s
# I0310 15:17:31.247111 22584 model_lib_v2.py:705] Step 900 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.49137706,
#  'Loss/localization_loss': 0.09088487,
#  'Loss/regularization_loss': 0.7703345,
#  'Loss/total_loss': 1.3525965,
#  'learning_rate': 0.025333151}
# I0310 15:17:31.247111 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.49137706,
#  'Loss/localization_loss': 0.09088487,
#  'Loss/regularization_loss': 0.7703345,
#  'Loss/total_loss': 1.3525965,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.547s
# I0310 15:18:25.983510 22584 model_lib_v2.py:705] Step 1000 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.54289275,
#  'Loss/localization_loss': 0.03959974,
#  'Loss/regularization_loss': 0.76920944,
#  'Loss/total_loss': 1.351702,
#  'learning_rate': 0.0266665}
# I0310 15:18:25.983510 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.54289275,
#  'Loss/localization_loss': 0.03959974,
#  'Loss/regularization_loss': 0.76920944,
#  'Loss/total_loss': 1.351702,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 0.552s
# I0310 15:19:21.183335 22584 model_lib_v2.py:705] Step 1100 per-step time 0.552s
# INFO:tensorflow:{'Loss/classification_loss': 0.34923494,
#  'Loss/localization_loss': 0.034195952,
#  'Loss/regularization_loss': 0.7680895,
#  'Loss/total_loss': 1.1515203,
#  'learning_rate': 0.02799985}
# I0310 15:19:21.183335 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.34923494,
#  'Loss/localization_loss': 0.034195952,
#  'Loss/regularization_loss': 0.7680895,
#  'Loss/total_loss': 1.1515203,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 0.547s
# I0310 15:20:15.910012 22584 model_lib_v2.py:705] Step 1200 per-step time 0.547s
# INFO:tensorflow:{'Loss/classification_loss': 0.4410384,
#  'Loss/localization_loss': 0.05037106,
#  'Loss/regularization_loss': 0.76693565,
#  'Loss/total_loss': 1.2583451,
#  'learning_rate': 0.0293332}
# I0310 15:20:15.910012 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4410384,
#  'Loss/localization_loss': 0.05037106,
#  'Loss/regularization_loss': 0.76693565,
#  'Loss/total_loss': 1.2583451,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 0.550s
# I0310 15:21:10.920738 22584 model_lib_v2.py:705] Step 1300 per-step time 0.550s
# INFO:tensorflow:{'Loss/classification_loss': 0.5285934,
#  'Loss/localization_loss': 0.11844353,
#  'Loss/regularization_loss': 0.7658403,
#  'Loss/total_loss': 1.4128772,
#  'learning_rate': 0.03066655}
# I0310 15:21:10.920738 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.5285934,
#  'Loss/localization_loss': 0.11844353,
#  'Loss/regularization_loss': 0.7658403,
#  'Loss/total_loss': 1.4128772,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 0.682s
# I0310 15:22:19.168946 22584 model_lib_v2.py:705] Step 1400 per-step time 0.682s
# INFO:tensorflow:{'Loss/classification_loss': 0.41543648,
#  'Loss/localization_loss': 0.031915765,
#  'Loss/regularization_loss': 0.7644108,
#  'Loss/total_loss': 1.211763,
#  'learning_rate': 0.0319999}
# I0310 15:22:19.168946 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.41543648,
#  'Loss/localization_loss': 0.031915765,
#  'Loss/regularization_loss': 0.7644108,
#  'Loss/total_loss': 1.211763,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 0.777s
# I0310 15:23:36.838946 22584 model_lib_v2.py:705] Step 1500 per-step time 0.777s
# INFO:tensorflow:{'Loss/classification_loss': 0.5478454,
#  'Loss/localization_loss': 0.05510571,
#  'Loss/regularization_loss': 0.7632992,
#  'Loss/total_loss': 1.3662503,
#  'learning_rate': 0.03333325}
# I0310 15:23:36.838946 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.5478454,
#  'Loss/localization_loss': 0.05510571,
#  'Loss/regularization_loss': 0.7632992,
#  'Loss/total_loss': 1.3662503,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 0.772s
# I0310 15:24:54.019462 22584 model_lib_v2.py:705] Step 1600 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.56394595,
#  'Loss/localization_loss': 0.03816628,
#  'Loss/regularization_loss': 0.76197547,
#  'Loss/total_loss': 1.3640877,
#  'learning_rate': 0.034666598}
# I0310 15:24:54.019462 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.56394595,
#  'Loss/localization_loss': 0.03816628,
#  'Loss/regularization_loss': 0.76197547,
#  'Loss/total_loss': 1.3640877,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 0.776s
# I0310 15:26:11.662498 22584 model_lib_v2.py:705] Step 1700 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.42500302,
#  'Loss/localization_loss': 0.024509067,
#  'Loss/regularization_loss': 0.76058805,
#  'Loss/total_loss': 1.2101002,
#  'learning_rate': 0.03599995}
# I0310 15:26:11.662498 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.42500302,
#  'Loss/localization_loss': 0.024509067,
#  'Loss/regularization_loss': 0.76058805,
#  'Loss/total_loss': 1.2101002,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 0.772s
# I0310 15:27:28.862702 22584 model_lib_v2.py:705] Step 1800 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.4936294,
#  'Loss/localization_loss': 0.041188803,
#  'Loss/regularization_loss': 0.75888914,
#  'Loss/total_loss': 1.2937074,
#  'learning_rate': 0.037333302}
# I0310 15:27:28.862702 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4936294,
#  'Loss/localization_loss': 0.041188803,
#  'Loss/regularization_loss': 0.75888914,
#  'Loss/total_loss': 1.2937074,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 0.776s
# I0310 15:28:46.478154 22584 model_lib_v2.py:705] Step 1900 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.26904047,
#  'Loss/localization_loss': 0.04439514,
#  'Loss/regularization_loss': 0.7571256,
#  'Loss/total_loss': 1.0705612,
#  'learning_rate': 0.03866665}
# I0310 15:28:46.478154 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.26904047,
#  'Loss/localization_loss': 0.04439514,
#  'Loss/regularization_loss': 0.7571256,
#  'Loss/total_loss': 1.0705612,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 0.776s
# I0310 15:30:04.100010 22584 model_lib_v2.py:705] Step 2000 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.55675435,
#  'Loss/localization_loss': 0.022793213,
#  'Loss/regularization_loss': 0.75550693,
#  'Loss/total_loss': 1.3350545,
#  'learning_rate': 0.04}
# I0310 15:30:04.100010 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.55675435,
#  'Loss/localization_loss': 0.022793213,
#  'Loss/regularization_loss': 0.75550693,
#  'Loss/total_loss': 1.3350545,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 0.780s
# I0310 15:31:22.138777 22584 model_lib_v2.py:705] Step 2100 per-step time 0.780s
# INFO:tensorflow:{'Loss/classification_loss': 0.42526832,
#  'Loss/localization_loss': 0.034319937,
#  'Loss/regularization_loss': 0.75375724,
#  'Loss/total_loss': 1.2133455,
#  'learning_rate': 0.039998136}
# I0310 15:31:22.138777 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.42526832,
#  'Loss/localization_loss': 0.034319937,
#  'Loss/regularization_loss': 0.75375724,
#  'Loss/total_loss': 1.2133455,
#  'learning_rate': 0.039998136}
# INFO:tensorflow:Step 2200 per-step time 0.773s
# I0310 15:32:39.424399 22584 model_lib_v2.py:705] Step 2200 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.42725915,
#  'Loss/localization_loss': 0.059752338,
#  'Loss/regularization_loss': 0.7519224,
#  'Loss/total_loss': 1.2389339,
#  'learning_rate': 0.039992537}
# I0310 15:32:39.424399 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.42725915,
#  'Loss/localization_loss': 0.059752338,
#  'Loss/regularization_loss': 0.7519224,
#  'Loss/total_loss': 1.2389339,
#  'learning_rate': 0.039992537}
# INFO:tensorflow:Step 2300 per-step time 0.776s
# I0310 15:33:57.011669 22584 model_lib_v2.py:705] Step 2300 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.61213773,
#  'Loss/localization_loss': 0.08550084,
#  'Loss/regularization_loss': 0.7500885,
#  'Loss/total_loss': 1.4477271,
#  'learning_rate': 0.03998321}
# I0310 15:33:57.011669 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.61213773,
#  'Loss/localization_loss': 0.08550084,
#  'Loss/regularization_loss': 0.7500885,
#  'Loss/total_loss': 1.4477271,
#  'learning_rate': 0.03998321}
# INFO:tensorflow:Step 2400 per-step time 0.774s
# I0310 15:35:14.426711 22584 model_lib_v2.py:705] Step 2400 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.53597933,
#  'Loss/localization_loss': 0.090381205,
#  'Loss/regularization_loss': 0.74825126,
#  'Loss/total_loss': 1.3746119,
#  'learning_rate': 0.039970152}
# I0310 15:35:14.426711 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.53597933,
#  'Loss/localization_loss': 0.090381205,
#  'Loss/regularization_loss': 0.74825126,
#  'Loss/total_loss': 1.3746119,
#  'learning_rate': 0.039970152}
# INFO:tensorflow:Step 2500 per-step time 0.772s
# I0310 15:36:31.676287 22584 model_lib_v2.py:705] Step 2500 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.49024954,
#  'Loss/localization_loss': 0.021775851,
#  'Loss/regularization_loss': 0.7465039,
#  'Loss/total_loss': 1.2585293,
#  'learning_rate': 0.039953373}
# I0310 15:36:31.676287 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.49024954,
#  'Loss/localization_loss': 0.021775851,
#  'Loss/regularization_loss': 0.7465039,
#  'Loss/total_loss': 1.2585293,
#  'learning_rate': 0.039953373}
# INFO:tensorflow:Step 2600 per-step time 0.774s
# I0310 15:37:49.029302 22584 model_lib_v2.py:705] Step 2600 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.6677044,
#  'Loss/localization_loss': 0.29058996,
#  'Loss/regularization_loss': 0.74473023,
#  'Loss/total_loss': 1.7030245,
#  'learning_rate': 0.03993287}
# I0310 15:37:49.029302 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.6677044,
#  'Loss/localization_loss': 0.29058996,
#  'Loss/regularization_loss': 0.74473023,
#  'Loss/total_loss': 1.7030245,
#  'learning_rate': 0.03993287}
# INFO:tensorflow:Step 2700 per-step time 0.775s
# I0310 15:39:06.506823 22584 model_lib_v2.py:705] Step 2700 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.41308936,
#  'Loss/localization_loss': 0.02055915,
#  'Loss/regularization_loss': 0.7429085,
#  'Loss/total_loss': 1.1765571,
#  'learning_rate': 0.039908648}
# I0310 15:39:06.506823 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.41308936,
#  'Loss/localization_loss': 0.02055915,
#  'Loss/regularization_loss': 0.7429085,
#  'Loss/total_loss': 1.1765571,
#  'learning_rate': 0.039908648}
# INFO:tensorflow:Step 2800 per-step time 0.775s
# I0310 15:40:23.958299 22584 model_lib_v2.py:705] Step 2800 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.5898956,
#  'Loss/localization_loss': 0.047845397,
#  'Loss/regularization_loss': 0.741175,
#  'Loss/total_loss': 1.378916,
#  'learning_rate': 0.039880715}
# I0310 15:40:23.958299 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.5898956,
#  'Loss/localization_loss': 0.047845397,
#  'Loss/regularization_loss': 0.741175,
#  'Loss/total_loss': 1.378916,
#  'learning_rate': 0.039880715}
# INFO:tensorflow:Step 2900 per-step time 0.775s
# I0310 15:41:41.410346 22584 model_lib_v2.py:705] Step 2900 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.33298102,
#  'Loss/localization_loss': 0.03965083,
#  'Loss/regularization_loss': 0.73927003,
#  'Loss/total_loss': 1.1119019,
#  'learning_rate': 0.039849065}
# I0310 15:41:41.410346 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.33298102,
#  'Loss/localization_loss': 0.03965083,
#  'Loss/regularization_loss': 0.73927003,
#  'Loss/total_loss': 1.1119019,
#  'learning_rate': 0.039849065}
# INFO:tensorflow:Step 3000 per-step time 0.770s
# I0310 15:42:58.434892 22584 model_lib_v2.py:705] Step 3000 per-step time 0.770s
# INFO:tensorflow:{'Loss/classification_loss': 0.3126005,
#  'Loss/localization_loss': 0.08888149,
#  'Loss/regularization_loss': 0.7374117,
#  'Loss/total_loss': 1.1388936,
#  'learning_rate': 0.03981372}
# I0310 15:42:58.434892 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.3126005,
#  'Loss/localization_loss': 0.08888149,
#  'Loss/regularization_loss': 0.7374117,
#  'Loss/total_loss': 1.1388936,
#  'learning_rate': 0.03981372}
# INFO:tensorflow:Step 3100 per-step time 0.779s
# I0310 15:44:16.363629 22584 model_lib_v2.py:705] Step 3100 per-step time 0.779s
# INFO:tensorflow:{'Loss/classification_loss': 0.25137487,
#  'Loss/localization_loss': 0.03658748,
#  'Loss/regularization_loss': 0.73548317,
#  'Loss/total_loss': 1.0234455,
#  'learning_rate': 0.03977467}
# I0310 15:44:16.363629 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.25137487,
#  'Loss/localization_loss': 0.03658748,
#  'Loss/regularization_loss': 0.73548317,
#  'Loss/total_loss': 1.0234455,
#  'learning_rate': 0.03977467}
# INFO:tensorflow:Step 3200 per-step time 0.774s
# I0310 15:45:33.797341 22584 model_lib_v2.py:705] Step 3200 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.48833638,
#  'Loss/localization_loss': 0.046453938,
#  'Loss/regularization_loss': 0.7341007,
#  'Loss/total_loss': 1.2688911,
#  'learning_rate': 0.03973194}
# I0310 15:45:33.797341 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.48833638,
#  'Loss/localization_loss': 0.046453938,
#  'Loss/regularization_loss': 0.7341007,
#  'Loss/total_loss': 1.2688911,
#  'learning_rate': 0.03973194}
# INFO:tensorflow:Step 3300 per-step time 0.776s
# I0310 15:46:51.407996 22584 model_lib_v2.py:705] Step 3300 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.5592044,
#  'Loss/localization_loss': 0.03376518,
#  'Loss/regularization_loss': 0.7321857,
#  'Loss/total_loss': 1.3251554,
#  'learning_rate': 0.03968552}
# I0310 15:46:51.407996 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.5592044,
#  'Loss/localization_loss': 0.03376518,
#  'Loss/regularization_loss': 0.7321857,
#  'Loss/total_loss': 1.3251554,
#  'learning_rate': 0.03968552}
# INFO:tensorflow:Step 3400 per-step time 0.774s
# I0310 15:48:08.767795 22584 model_lib_v2.py:705] Step 3400 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.54304504,
#  'Loss/localization_loss': 0.07233798,
#  'Loss/regularization_loss': 0.7302635,
#  'Loss/total_loss': 1.3456465,
#  'learning_rate': 0.039635435}
# I0310 15:48:08.767795 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.54304504,
#  'Loss/localization_loss': 0.07233798,
#  'Loss/regularization_loss': 0.7302635,
#  'Loss/total_loss': 1.3456465,
#  'learning_rate': 0.039635435}
# INFO:tensorflow:Step 3500 per-step time 0.774s
# I0310 15:49:26.147648 22584 model_lib_v2.py:705] Step 3500 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.4674345,
#  'Loss/localization_loss': 0.050560027,
#  'Loss/regularization_loss': 0.72836125,
#  'Loss/total_loss': 1.2463558,
#  'learning_rate': 0.03958168}
# I0310 15:49:26.147648 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4674345,
#  'Loss/localization_loss': 0.050560027,
#  'Loss/regularization_loss': 0.72836125,
#  'Loss/total_loss': 1.2463558,
#  'learning_rate': 0.03958168}
# INFO:tensorflow:Step 3600 per-step time 0.771s
# I0310 15:50:43.271794 22584 model_lib_v2.py:705] Step 3600 per-step time 0.771s
# INFO:tensorflow:{'Loss/classification_loss': 0.51593184,
#  'Loss/localization_loss': 0.0134509625,
#  'Loss/regularization_loss': 0.72644985,
#  'Loss/total_loss': 1.2558327,
#  'learning_rate': 0.039524276}
# I0310 15:50:43.271794 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.51593184,
#  'Loss/localization_loss': 0.0134509625,
#  'Loss/regularization_loss': 0.72644985,
#  'Loss/total_loss': 1.2558327,
#  'learning_rate': 0.039524276}
# INFO:tensorflow:Step 3700 per-step time 0.773s
# I0310 15:52:00.586229 22584 model_lib_v2.py:705] Step 3700 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.59632707,
#  'Loss/localization_loss': 0.03786242,
#  'Loss/regularization_loss': 0.72457135,
#  'Loss/total_loss': 1.3587608,
#  'learning_rate': 0.03946323}
# I0310 15:52:00.586229 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.59632707,
#  'Loss/localization_loss': 0.03786242,
#  'Loss/regularization_loss': 0.72457135,
#  'Loss/total_loss': 1.3587608,
#  'learning_rate': 0.03946323}
# INFO:tensorflow:Step 3800 per-step time 0.775s
# I0310 15:53:18.022658 22584 model_lib_v2.py:705] Step 3800 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.41392127,
#  'Loss/localization_loss': 0.025810326,
#  'Loss/regularization_loss': 0.7227646,
#  'Loss/total_loss': 1.1624962,
#  'learning_rate': 0.039398547}
# I0310 15:53:18.022658 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.41392127,
#  'Loss/localization_loss': 0.025810326,
#  'Loss/regularization_loss': 0.7227646,
#  'Loss/total_loss': 1.1624962,
#  'learning_rate': 0.039398547}
# INFO:tensorflow:Step 3900 per-step time 0.776s
# I0310 15:54:35.665417 22584 model_lib_v2.py:705] Step 3900 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.42898145,
#  'Loss/localization_loss': 0.01799176,
#  'Loss/regularization_loss': 0.72090197,
#  'Loss/total_loss': 1.1678752,
#  'learning_rate': 0.039330248}
# I0310 15:54:35.665417 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.42898145,
#  'Loss/localization_loss': 0.01799176,
#  'Loss/regularization_loss': 0.72090197,
#  'Loss/total_loss': 1.1678752,
#  'learning_rate': 0.039330248}
# INFO:tensorflow:Step 4000 per-step time 0.776s
# I0310 15:55:53.223294 22584 model_lib_v2.py:705] Step 4000 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.4572595,
#  'Loss/localization_loss': 0.029595818,
#  'Loss/regularization_loss': 0.71903217,
#  'Loss/total_loss': 1.2058876,
#  'learning_rate': 0.039258346}
# I0310 15:55:53.223294 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4572595,
#  'Loss/localization_loss': 0.029595818,
#  'Loss/regularization_loss': 0.71903217,
#  'Loss/total_loss': 1.2058876,
#  'learning_rate': 0.039258346}
# INFO:tensorflow:Step 4100 per-step time 0.779s
# I0310 15:57:11.083420 22584 model_lib_v2.py:705] Step 4100 per-step time 0.779s
# INFO:tensorflow:{'Loss/classification_loss': 0.3823985,
#  'Loss/localization_loss': 0.032082018,
#  'Loss/regularization_loss': 0.71713775,
#  'Loss/total_loss': 1.1316181,
#  'learning_rate': 0.03918285}
# I0310 15:57:11.083420 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.3823985,
#  'Loss/localization_loss': 0.032082018,
#  'Loss/regularization_loss': 0.71713775,
#  'Loss/total_loss': 1.1316181,
#  'learning_rate': 0.03918285}
# INFO:tensorflow:Step 4200 per-step time 0.774s
# I0310 15:58:28.449130 22584 model_lib_v2.py:705] Step 4200 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.41469473,
#  'Loss/localization_loss': 0.039110653,
#  'Loss/regularization_loss': 0.7152797,
#  'Loss/total_loss': 1.169085,
#  'learning_rate': 0.03910377}
# I0310 15:58:28.449130 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.41469473,
#  'Loss/localization_loss': 0.039110653,
#  'Loss/regularization_loss': 0.7152797,
#  'Loss/total_loss': 1.169085,
#  'learning_rate': 0.03910377}
# INFO:tensorflow:Step 4300 per-step time 0.774s
# I0310 15:59:45.836501 22584 model_lib_v2.py:705] Step 4300 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.51903933,
#  'Loss/localization_loss': 0.042741336,
#  'Loss/regularization_loss': 0.713444,
#  'Loss/total_loss': 1.2752247,
#  'learning_rate': 0.039021127}
# I0310 15:59:45.836501 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.51903933,
#  'Loss/localization_loss': 0.042741336,
#  'Loss/regularization_loss': 0.713444,
#  'Loss/total_loss': 1.2752247,
#  'learning_rate': 0.039021127}
# INFO:tensorflow:Step 4400 per-step time 0.774s
# I0310 16:01:03.225545 22584 model_lib_v2.py:705] Step 4400 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.4101179,
#  'Loss/localization_loss': 0.018073319,
#  'Loss/regularization_loss': 0.7116087,
#  'Loss/total_loss': 1.1398,
#  'learning_rate': 0.03893494}
# I0310 16:01:03.225545 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4101179,
#  'Loss/localization_loss': 0.018073319,
#  'Loss/regularization_loss': 0.7116087,
#  'Loss/total_loss': 1.1398,
#  'learning_rate': 0.03893494}
# INFO:tensorflow:Step 4500 per-step time 0.772s
# I0310 16:02:20.446611 22584 model_lib_v2.py:705] Step 4500 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.2096929,
#  'Loss/localization_loss': 0.023379074,
#  'Loss/regularization_loss': 0.709761,
#  'Loss/total_loss': 0.942833,
#  'learning_rate': 0.03884522}
# I0310 16:02:20.446611 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.2096929,
#  'Loss/localization_loss': 0.023379074,
#  'Loss/regularization_loss': 0.709761,
#  'Loss/total_loss': 0.942833,
#  'learning_rate': 0.03884522}
# INFO:tensorflow:Step 4600 per-step time 0.773s
# I0310 16:03:37.716317 22584 model_lib_v2.py:705] Step 4600 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.28215638,
#  'Loss/localization_loss': 0.006701513,
#  'Loss/regularization_loss': 0.7082688,
#  'Loss/total_loss': 0.99712676,
#  'learning_rate': 0.03875198}
# I0310 16:03:37.716317 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.28215638,
#  'Loss/localization_loss': 0.006701513,
#  'Loss/regularization_loss': 0.7082688,
#  'Loss/total_loss': 0.99712676,
#  'learning_rate': 0.03875198}
# INFO:tensorflow:Step 4700 per-step time 0.772s
# I0310 16:04:54.894807 22584 model_lib_v2.py:705] Step 4700 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.42357406,
#  'Loss/localization_loss': 0.05988552,
#  'Loss/regularization_loss': 0.7064577,
#  'Loss/total_loss': 1.1899172,
#  'learning_rate': 0.038655244}
# I0310 16:04:54.894807 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.42357406,
#  'Loss/localization_loss': 0.05988552,
#  'Loss/regularization_loss': 0.7064577,
#  'Loss/total_loss': 1.1899172,
#  'learning_rate': 0.038655244}
# INFO:tensorflow:Step 4800 per-step time 0.772s
# I0310 16:06:12.128614 22584 model_lib_v2.py:705] Step 4800 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.4155898,
#  'Loss/localization_loss': 0.03038494,
#  'Loss/regularization_loss': 0.70466894,
#  'Loss/total_loss': 1.1506437,
#  'learning_rate': 0.038555026}
# I0310 16:06:12.128614 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.4155898,
#  'Loss/localization_loss': 0.03038494,
#  'Loss/regularization_loss': 0.70466894,
#  'Loss/total_loss': 1.1506437,
#  'learning_rate': 0.038555026}
# INFO:tensorflow:Step 4900 per-step time 0.774s
# I0310 16:07:29.515278 22584 model_lib_v2.py:705] Step 4900 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.33248082,
#  'Loss/localization_loss': 0.012021708,
#  'Loss/regularization_loss': 0.702935,
#  'Loss/total_loss': 1.0474374,
#  'learning_rate': 0.038451348}
# I0310 16:07:29.515278 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.33248082,
#  'Loss/localization_loss': 0.012021708,
#  'Loss/regularization_loss': 0.702935,
#  'Loss/total_loss': 1.0474374,
#  'learning_rate': 0.038451348}
# INFO:tensorflow:Step 5000 per-step time 0.773s
# I0310 16:08:46.829944 22584 model_lib_v2.py:705] Step 5000 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.19959755,
#  'Loss/localization_loss': 0.024987848,
#  'Loss/regularization_loss': 0.7011662,
#  'Loss/total_loss': 0.9257516,
#  'learning_rate': 0.038344227}
# I0310 16:08:46.829944 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.19959755,
#  'Loss/localization_loss': 0.024987848,
#  'Loss/regularization_loss': 0.7011662,
#  'Loss/total_loss': 0.9257516,
#  'learning_rate': 0.038344227}
# INFO:tensorflow:Step 5100 per-step time 0.780s
# I0310 16:10:04.804625 22584 model_lib_v2.py:705] Step 5100 per-step time 0.780s
# INFO:tensorflow:{'Loss/classification_loss': 0.29359645,
#  'Loss/localization_loss': 0.03363312,
#  'Loss/regularization_loss': 0.69940215,
#  'Loss/total_loss': 1.0266317,
#  'learning_rate': 0.03823368}
# I0310 16:10:04.804625 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.29359645,
#  'Loss/localization_loss': 0.03363312,
#  'Loss/regularization_loss': 0.69940215,
#  'Loss/total_loss': 1.0266317,
#  'learning_rate': 0.03823368}
# INFO:tensorflow:Step 5200 per-step time 0.774s
# I0310 16:11:22.189631 22584 model_lib_v2.py:705] Step 5200 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.51743567,
#  'Loss/localization_loss': 0.058412053,
#  'Loss/regularization_loss': 0.6976795,
#  'Loss/total_loss': 1.2735273,
#  'learning_rate': 0.038119733}
# I0310 16:11:22.189631 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.51743567,
#  'Loss/localization_loss': 0.058412053,
#  'Loss/regularization_loss': 0.6976795,
#  'Loss/total_loss': 1.2735273,
#  'learning_rate': 0.038119733}
# INFO:tensorflow:Step 5300 per-step time 0.775s
# I0310 16:12:39.638975 22584 model_lib_v2.py:705] Step 5300 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.30792934,
#  'Loss/localization_loss': 0.061856903,
#  'Loss/regularization_loss': 0.6959917,
#  'Loss/total_loss': 1.0657779,
#  'learning_rate': 0.03800241}
# I0310 16:12:39.638975 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.30792934,
#  'Loss/localization_loss': 0.061856903,
#  'Loss/regularization_loss': 0.6959917,
#  'Loss/total_loss': 1.0657779,
#  'learning_rate': 0.03800241}
# INFO:tensorflow:Step 5400 per-step time 0.779s
# I0310 16:13:57.597093 22584 model_lib_v2.py:705] Step 5400 per-step time 0.779s
# INFO:tensorflow:{'Loss/classification_loss': 0.48162258,
#  'Loss/localization_loss': 0.021747563,
#  'Loss/regularization_loss': 0.694243,
#  'Loss/total_loss': 1.1976132,
#  'learning_rate': 0.037881725}
# I0310 16:13:57.597093 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.48162258,
#  'Loss/localization_loss': 0.021747563,
#  'Loss/regularization_loss': 0.694243,
#  'Loss/total_loss': 1.1976132,
#  'learning_rate': 0.037881725}
# INFO:tensorflow:Step 5500 per-step time 0.776s
# I0310 16:15:15.223717 22584 model_lib_v2.py:705] Step 5500 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.35561413,
#  'Loss/localization_loss': 0.027464345,
#  'Loss/regularization_loss': 0.6925174,
#  'Loss/total_loss': 1.0755959,
#  'learning_rate': 0.037757702}
# I0310 16:15:15.223717 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.35561413,
#  'Loss/localization_loss': 0.027464345,
#  'Loss/regularization_loss': 0.6925174,
#  'Loss/total_loss': 1.0755959,
#  'learning_rate': 0.037757702}
# INFO:tensorflow:Step 5600 per-step time 0.776s
# I0310 16:16:32.789285 22584 model_lib_v2.py:705] Step 5600 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.27410558,
#  'Loss/localization_loss': 0.050422158,
#  'Loss/regularization_loss': 0.69079375,
#  'Loss/total_loss': 1.0153215,
#  'learning_rate': 0.03763037}
# I0310 16:16:32.789285 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.27410558,
#  'Loss/localization_loss': 0.050422158,
#  'Loss/regularization_loss': 0.69079375,
#  'Loss/total_loss': 1.0153215,
#  'learning_rate': 0.03763037}
# INFO:tensorflow:Step 5700 per-step time 0.775s
# I0310 16:17:50.244693 22584 model_lib_v2.py:705] Step 5700 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.29564574,
#  'Loss/localization_loss': 0.016380338,
#  'Loss/regularization_loss': 0.6890247,
#  'Loss/total_loss': 1.0010507,
#  'learning_rate': 0.03749975}
# I0310 16:17:50.244693 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.29564574,
#  'Loss/localization_loss': 0.016380338,
#  'Loss/regularization_loss': 0.6890247,
#  'Loss/total_loss': 1.0010507,
#  'learning_rate': 0.03749975}
# INFO:tensorflow:Step 5800 per-step time 0.801s
# I0310 16:19:10.393029 22584 model_lib_v2.py:705] Step 5800 per-step time 0.801s
# INFO:tensorflow:{'Loss/classification_loss': 0.2491733,
#  'Loss/localization_loss': 0.023064686,
#  'Loss/regularization_loss': 0.6872978,
#  'Loss/total_loss': 0.9595358,
#  'learning_rate': 0.037365858}
# I0310 16:19:10.393029 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.2491733,
#  'Loss/localization_loss': 0.023064686,
#  'Loss/regularization_loss': 0.6872978,
#  'Loss/total_loss': 0.9595358,
#  'learning_rate': 0.037365858}
# INFO:tensorflow:Step 5900 per-step time 0.774s
# I0310 16:20:27.746254 22584 model_lib_v2.py:705] Step 5900 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.3722499,
#  'Loss/localization_loss': 0.057928614,
#  'Loss/regularization_loss': 0.68564147,
#  'Loss/total_loss': 1.1158199,
#  'learning_rate': 0.03722873}
# I0310 16:20:27.746254 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.3722499,
#  'Loss/localization_loss': 0.057928614,
#  'Loss/regularization_loss': 0.68564147,
#  'Loss/total_loss': 1.1158199,
#  'learning_rate': 0.03722873}
# INFO:tensorflow:Step 6000 per-step time 0.773s
# I0310 16:21:45.014767 22584 model_lib_v2.py:705] Step 6000 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.21706992,
#  'Loss/localization_loss': 0.049466882,
#  'Loss/regularization_loss': 0.6839152,
#  'Loss/total_loss': 0.950452,
#  'learning_rate': 0.037088387}
# I0310 16:21:45.014767 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.21706992,
#  'Loss/localization_loss': 0.049466882,
#  'Loss/regularization_loss': 0.6839152,
#  'Loss/total_loss': 0.950452,
#  'learning_rate': 0.037088387}
# INFO:tensorflow:Step 6100 per-step time 0.778s
# I0310 16:23:02.847966 22584 model_lib_v2.py:705] Step 6100 per-step time 0.778s
# INFO:tensorflow:{'Loss/classification_loss': 0.61119205,
#  'Loss/localization_loss': 0.012175212,
#  'Loss/regularization_loss': 0.6822248,
#  'Loss/total_loss': 1.3055921,
#  'learning_rate': 0.036944855}
# I0310 16:23:02.847966 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.61119205,
#  'Loss/localization_loss': 0.012175212,
# ...
#  'Loss/localization_loss': 0.0061247433,
#  'Loss/regularization_loss': 0.55717224,
#  'Loss/total_loss': 0.6523065,
#  'learning_rate': 0.0014449739}
# INFO:tensorflow:Step 22300 per-step time 0.775s
# I0310 19:45:02.725473 22584 model_lib_v2.py:705] Step 22300 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.1151819,
#  'Loss/localization_loss': 0.0040837373,
#  'Loss/regularization_loss': 0.5571117,
#  'Loss/total_loss': 0.67637736,
#  'learning_rate': 0.0013447559}
# I0310 19:45:02.725473 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1151819,
#  'Loss/localization_loss': 0.0040837373,
#  'Loss/regularization_loss': 0.5571117,
#  'Loss/total_loss': 0.67637736,
#  'learning_rate': 0.0013447559}
# INFO:tensorflow:Step 22400 per-step time 0.773s
# I0310 19:46:20.032740 22584 model_lib_v2.py:705] Step 22400 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.10330155,
#  'Loss/localization_loss': 0.0147436345,
#  'Loss/regularization_loss': 0.5570548,
#  'Loss/total_loss': 0.67509997,
#  'learning_rate': 0.0012480199}
# I0310 19:46:20.032740 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10330155,
#  'Loss/localization_loss': 0.0147436345,
#  'Loss/regularization_loss': 0.5570548,
#  'Loss/total_loss': 0.67509997,
#  'learning_rate': 0.0012480199}
# INFO:tensorflow:Step 22500 per-step time 0.774s
# I0310 19:47:37.374940 22584 model_lib_v2.py:705] Step 22500 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.050703306,
#  'Loss/localization_loss': 0.031809874,
#  'Loss/regularization_loss': 0.5570026,
#  'Loss/total_loss': 0.63951576,
#  'learning_rate': 0.0011547804}
# I0310 19:47:37.374940 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.050703306,
#  'Loss/localization_loss': 0.031809874,
#  'Loss/regularization_loss': 0.5570026,
#  'Loss/total_loss': 0.63951576,
#  'learning_rate': 0.0011547804}
# INFO:tensorflow:Step 22600 per-step time 0.772s
# I0310 19:48:54.637847 22584 model_lib_v2.py:705] Step 22600 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.10822307,
#  'Loss/localization_loss': 0.016033735,
#  'Loss/regularization_loss': 0.55695295,
#  'Loss/total_loss': 0.68120974,
#  'learning_rate': 0.0010650586}
# I0310 19:48:54.637847 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10822307,
#  'Loss/localization_loss': 0.016033735,
#  'Loss/regularization_loss': 0.55695295,
#  'Loss/total_loss': 0.68120974,
#  'learning_rate': 0.0010650586}
# INFO:tensorflow:Step 22700 per-step time 0.772s
# I0310 19:50:11.796892 22584 model_lib_v2.py:705] Step 22700 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.08610111,
#  'Loss/localization_loss': 0.022727046,
#  'Loss/regularization_loss': 0.55690783,
#  'Loss/total_loss': 0.665736,
#  'learning_rate': 0.0009788703}
# I0310 19:50:11.797893 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08610111,
#  'Loss/localization_loss': 0.022727046,
#  'Loss/regularization_loss': 0.55690783,
#  'Loss/total_loss': 0.665736,
#  'learning_rate': 0.0009788703}
# INFO:tensorflow:Step 22800 per-step time 0.774s
# I0310 19:51:29.157858 22584 model_lib_v2.py:705] Step 22800 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.07432374,
#  'Loss/localization_loss': 0.0104072215,
#  'Loss/regularization_loss': 0.5568668,
#  'Loss/total_loss': 0.64159775,
#  'learning_rate': 0.00089622854}
# I0310 19:51:29.157858 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07432374,
#  'Loss/localization_loss': 0.0104072215,
#  'Loss/regularization_loss': 0.5568668,
#  'Loss/total_loss': 0.64159775,
#  'learning_rate': 0.00089622854}
# INFO:tensorflow:Step 22900 per-step time 0.773s
# I0310 19:52:46.436624 22584 model_lib_v2.py:705] Step 22900 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.10872042,
#  'Loss/localization_loss': 0.010717541,
#  'Loss/regularization_loss': 0.55682904,
#  'Loss/total_loss': 0.676267,
#  'learning_rate': 0.00081715226}
# I0310 19:52:46.436624 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.10872042,
#  'Loss/localization_loss': 0.010717541,
#  'Loss/regularization_loss': 0.55682904,
#  'Loss/total_loss': 0.676267,
#  'learning_rate': 0.00081715226}
# INFO:tensorflow:Step 23000 per-step time 0.771s
# I0310 19:54:03.601141 22584 model_lib_v2.py:705] Step 23000 per-step time 0.771s
# INFO:tensorflow:{'Loss/classification_loss': 0.073762305,
#  'Loss/localization_loss': 0.027511714,
#  'Loss/regularization_loss': 0.55679375,
#  'Loss/total_loss': 0.65806776,
#  'learning_rate': 0.0007416546}
# I0310 19:54:03.601141 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.073762305,
#  'Loss/localization_loss': 0.027511714,
#  'Loss/regularization_loss': 0.55679375,
#  'Loss/total_loss': 0.65806776,
#  'learning_rate': 0.0007416546}
# INFO:tensorflow:Step 23100 per-step time 0.778s
# I0310 19:55:21.415402 22584 model_lib_v2.py:705] Step 23100 per-step time 0.778s
# INFO:tensorflow:{'Loss/classification_loss': 0.06688312,
#  'Loss/localization_loss': 0.011173054,
#  'Loss/regularization_loss': 0.55676305,
#  'Loss/total_loss': 0.6348192,
#  'learning_rate': 0.0006697476}
# I0310 19:55:21.415402 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06688312,
#  'Loss/localization_loss': 0.011173054,
#  'Loss/regularization_loss': 0.55676305,
#  'Loss/total_loss': 0.6348192,
#  'learning_rate': 0.0006697476}
# INFO:tensorflow:Step 23200 per-step time 0.771s
# I0310 19:56:38.486877 22584 model_lib_v2.py:705] Step 23200 per-step time 0.771s
# INFO:tensorflow:{'Loss/classification_loss': 0.073334046,
#  'Loss/localization_loss': 0.0015420523,
#  'Loss/regularization_loss': 0.5567355,
#  'Loss/total_loss': 0.6316116,
#  'learning_rate': 0.0006014514}
# I0310 19:56:38.486877 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.073334046,
#  'Loss/localization_loss': 0.0015420523,
#  'Loss/regularization_loss': 0.5567355,
#  'Loss/total_loss': 0.6316116,
#  'learning_rate': 0.0006014514}
# INFO:tensorflow:Step 23300 per-step time 0.773s
# I0310 19:57:55.750053 22584 model_lib_v2.py:705] Step 23300 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.15610701,
#  'Loss/localization_loss': 0.0050392183,
#  'Loss/regularization_loss': 0.55671,
#  'Loss/total_loss': 0.7178562,
#  'learning_rate': 0.000536772}
# I0310 19:57:55.750053 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.15610701,
#  'Loss/localization_loss': 0.0050392183,
#  'Loss/regularization_loss': 0.55671,
#  'Loss/total_loss': 0.7178562,
#  'learning_rate': 0.000536772}
# INFO:tensorflow:Step 23400 per-step time 0.771s
# I0310 19:59:12.877940 22584 model_lib_v2.py:705] Step 23400 per-step time 0.771s
# INFO:tensorflow:{'Loss/classification_loss': 0.31088564,
#  'Loss/localization_loss': 0.019603275,
#  'Loss/regularization_loss': 0.55668765,
#  'Loss/total_loss': 0.8871765,
#  'learning_rate': 0.00047572254}
# I0310 19:59:12.893552 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.31088564,
#  'Loss/localization_loss': 0.019603275,
#  'Loss/regularization_loss': 0.55668765,
#  'Loss/total_loss': 0.8871765,
#  'learning_rate': 0.00047572254}
# INFO:tensorflow:Step 23500 per-step time 0.772s
# I0310 20:00:30.128982 22584 model_lib_v2.py:705] Step 23500 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.092497855,
#  'Loss/localization_loss': 0.00889004,
#  'Loss/regularization_loss': 0.5566684,
#  'Loss/total_loss': 0.65805626,
#  'learning_rate': 0.0004183185}
# I0310 20:00:30.128982 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.092497855,
#  'Loss/localization_loss': 0.00889004,
#  'Loss/regularization_loss': 0.5566684,
#  'Loss/total_loss': 0.65805626,
#  'learning_rate': 0.0004183185}
# INFO:tensorflow:Step 23600 per-step time 0.776s
# I0310 20:01:47.698321 22584 model_lib_v2.py:705] Step 23600 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.13374461,
#  'Loss/localization_loss': 0.012004602,
#  'Loss/regularization_loss': 0.556651,
#  'Loss/total_loss': 0.7024002,
#  'learning_rate': 0.00036456465}
# I0310 20:01:47.698321 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.13374461,
#  'Loss/localization_loss': 0.012004602,
#  'Loss/regularization_loss': 0.556651,
#  'Loss/total_loss': 0.7024002,
#  'learning_rate': 0.00036456465}
# INFO:tensorflow:Step 23700 per-step time 0.775s
# I0310 20:03:05.190512 22584 model_lib_v2.py:705] Step 23700 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.08263454,
#  'Loss/localization_loss': 0.012217962,
#  'Loss/regularization_loss': 0.5566359,
#  'Loss/total_loss': 0.65148836,
#  'learning_rate': 0.0003144765}
# I0310 20:03:05.190512 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.08263454,
#  'Loss/localization_loss': 0.012217962,
#  'Loss/regularization_loss': 0.5566359,
#  'Loss/total_loss': 0.65148836,
#  'learning_rate': 0.0003144765}
# INFO:tensorflow:Step 23800 per-step time 0.776s
# I0310 20:04:22.776664 22584 model_lib_v2.py:705] Step 23800 per-step time 0.776s
# INFO:tensorflow:{'Loss/classification_loss': 0.16208987,
#  'Loss/localization_loss': 0.002711324,
#  'Loss/regularization_loss': 0.5566232,
#  'Loss/total_loss': 0.7214244,
#  'learning_rate': 0.00026806234}
# I0310 20:04:22.776664 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.16208987,
#  'Loss/localization_loss': 0.002711324,
#  'Loss/regularization_loss': 0.5566232,
#  'Loss/total_loss': 0.7214244,
#  'learning_rate': 0.00026806234}
# INFO:tensorflow:Step 23900 per-step time 0.774s
# I0310 20:05:40.210032 22584 model_lib_v2.py:705] Step 23900 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.065891825,
#  'Loss/localization_loss': 0.034876175,
#  'Loss/regularization_loss': 0.5566122,
#  'Loss/total_loss': 0.65738016,
#  'learning_rate': 0.00022532581}
# I0310 20:05:40.210032 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.065891825,
#  'Loss/localization_loss': 0.034876175,
#  'Loss/regularization_loss': 0.5566122,
#  'Loss/total_loss': 0.65738016,
#  'learning_rate': 0.00022532581}
# INFO:tensorflow:Step 24000 per-step time 0.773s
# I0310 20:06:57.539559 22584 model_lib_v2.py:705] Step 24000 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.07089107,
#  'Loss/localization_loss': 0.006420962,
#  'Loss/regularization_loss': 0.55660295,
#  'Loss/total_loss': 0.633915,
#  'learning_rate': 0.0001862812}
# I0310 20:06:57.539559 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.07089107,
#  'Loss/localization_loss': 0.006420962,
#  'Loss/regularization_loss': 0.55660295,
#  'Loss/total_loss': 0.633915,
#  'learning_rate': 0.0001862812}
# INFO:tensorflow:Step 24100 per-step time 0.777s
# I0310 20:08:15.272135 22584 model_lib_v2.py:705] Step 24100 per-step time 0.777s
# INFO:tensorflow:{'Loss/classification_loss': 0.1313522,
#  'Loss/localization_loss': 0.014096539,
#  'Loss/regularization_loss': 0.5565949,
#  'Loss/total_loss': 0.70204365,
#  'learning_rate': 0.00015093207}
# I0310 20:08:15.272135 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.1313522,
#  'Loss/localization_loss': 0.014096539,
#  'Loss/regularization_loss': 0.5565949,
#  'Loss/total_loss': 0.70204365,
#  'learning_rate': 0.00015093207}
# INFO:tensorflow:Step 24200 per-step time 0.775s
# I0310 20:09:32.758901 22584 model_lib_v2.py:705] Step 24200 per-step time 0.775s
# INFO:tensorflow:{'Loss/classification_loss': 0.040660903,
#  'Loss/localization_loss': 0.0059791235,
#  'Loss/regularization_loss': 0.5565885,
#  'Loss/total_loss': 0.6032285,
#  'learning_rate': 0.00011928677}
# I0310 20:09:32.758901 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.040660903,
#  'Loss/localization_loss': 0.0059791235,
#  'Loss/regularization_loss': 0.5565885,
#  'Loss/total_loss': 0.6032285,
#  'learning_rate': 0.00011928677}
# INFO:tensorflow:Step 24300 per-step time 0.773s
# I0310 20:10:50.012529 22584 model_lib_v2.py:705] Step 24300 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.12551817,
#  'Loss/localization_loss': 0.08959087,
#  'Loss/regularization_loss': 0.55658406,
#  'Loss/total_loss': 0.77169305,
#  'learning_rate': 9.135008e-05}
# I0310 20:10:50.012529 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.12551817,
#  'Loss/localization_loss': 0.08959087,
#  'Loss/regularization_loss': 0.55658406,
#  'Loss/total_loss': 0.77169305,
#  'learning_rate': 9.135008e-05}
# INFO:tensorflow:Step 24400 per-step time 0.774s
# I0310 20:12:07.448714 22584 model_lib_v2.py:705] Step 24400 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.04802811,
#  'Loss/localization_loss': 0.01886875,
#  'Loss/regularization_loss': 0.5565812,
#  'Loss/total_loss': 0.62347806,
#  'learning_rate': 6.712794e-05}
# I0310 20:12:07.448714 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.04802811,
#  'Loss/localization_loss': 0.01886875,
#  'Loss/regularization_loss': 0.5565812,
#  'Loss/total_loss': 0.62347806,
#  'learning_rate': 6.712794e-05}
# INFO:tensorflow:Step 24500 per-step time 0.774s
# I0310 20:13:24.813366 22584 model_lib_v2.py:705] Step 24500 per-step time 0.774s
# INFO:tensorflow:{'Loss/classification_loss': 0.04903202,
#  'Loss/localization_loss': 0.0022507284,
#  'Loss/regularization_loss': 0.5565796,
#  'Loss/total_loss': 0.60786235,
#  'learning_rate': 4.6623943e-05}
# I0310 20:13:24.813366 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.04903202,
#  'Loss/localization_loss': 0.0022507284,
#  'Loss/regularization_loss': 0.5565796,
#  'Loss/total_loss': 0.60786235,
#  'learning_rate': 4.6623943e-05}
# INFO:tensorflow:Step 24600 per-step time 0.773s
# I0310 20:14:42.100405 22584 model_lib_v2.py:705] Step 24600 per-step time 0.773s
# INFO:tensorflow:{'Loss/classification_loss': 0.20972885,
#  'Loss/localization_loss': 0.017989848,
#  'Loss/regularization_loss': 0.5565788,
#  'Loss/total_loss': 0.7842975,
#  'learning_rate': 2.9844045e-05}
# I0310 20:14:42.100405 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.20972885,
#  'Loss/localization_loss': 0.017989848,
#  'Loss/regularization_loss': 0.5565788,
#  'Loss/total_loss': 0.7842975,
#  'learning_rate': 2.9844045e-05}
# INFO:tensorflow:Step 24700 per-step time 0.772s
# I0310 20:15:59.343575 22584 model_lib_v2.py:705] Step 24700 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.18565492,
#  'Loss/localization_loss': 0.02546906,
#  'Loss/regularization_loss': 0.5565785,
#  'Loss/total_loss': 0.7677025,
#  'learning_rate': 1.6789436e-05}
# I0310 20:15:59.343575 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.18565492,
#  'Loss/localization_loss': 0.02546906,
#  'Loss/regularization_loss': 0.5565785,
#  'Loss/total_loss': 0.7677025,
#  'learning_rate': 1.6789436e-05}
# INFO:tensorflow:Step 24800 per-step time 0.771s
# I0310 20:17:16.448910 22584 model_lib_v2.py:705] Step 24800 per-step time 0.771s
# INFO:tensorflow:{'Loss/classification_loss': 0.09639506,
#  'Loss/localization_loss': 0.011305258,
#  'Loss/regularization_loss': 0.55657834,
#  'Loss/total_loss': 0.6642787,
#  'learning_rate': 7.4625013e-06}
# I0310 20:17:16.448910 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.09639506,
#  'Loss/localization_loss': 0.011305258,
#  'Loss/regularization_loss': 0.55657834,
#  'Loss/total_loss': 0.6642787,
#  'learning_rate': 7.4625013e-06}
# INFO:tensorflow:Step 24900 per-step time 0.772s
# I0310 20:18:33.668541 22584 model_lib_v2.py:705] Step 24900 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.06879199,
#  'Loss/localization_loss': 0.0201179,
#  'Loss/regularization_loss': 0.55657834,
#  'Loss/total_loss': 0.6454882,
#  'learning_rate': 1.8656253e-06}
# I0310 20:18:33.668541 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.06879199,
#  'Loss/localization_loss': 0.0201179,
#  'Loss/regularization_loss': 0.55657834,
#  'Loss/total_loss': 0.6454882,
#  'learning_rate': 1.8656253e-06}
# INFO:tensorflow:Step 25000 per-step time 0.772s
# I0310 20:19:50.850472 22584 model_lib_v2.py:705] Step 25000 per-step time 0.772s
# INFO:tensorflow:{'Loss/classification_loss': 0.11065534,
#  'Loss/localization_loss': 0.012644397,
#  'Loss/regularization_loss': 0.55657834,
#  'Loss/total_loss': 0.6798781,
#  'learning_rate': 0.0}
# I0310 20:19:50.850472 22584 model_lib_v2.py:708] {'Loss/classification_loss': 0.11065534,
#  'Loss/localization_loss': 0.012644397,
#  'Loss/regularization_loss': 0.55657834,
#  'Loss/total_loss': 0.6798781,
#  'learning_rate': 0.0}

# %%
# !python {SCRIPT_PATH + '/exporter_main_v2.py'} --input_type image_tensor --pipeline_config_path {CONFIG_PATH} --trained_checkpoint_dir {MODEL_PATH + '/' } --output_directory exported-models\my-model
# Out:
# 2024-03-10 20:20:12.707967: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 20:20:13.145038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0310 20:20:13.453366 20336 deprecation.py:623] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0310 20:20:16.109866 20336 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0310 20:20:29.940799 20336 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0310 20:20:38.827144 20336 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000153460ECE20>, because it is not built.
# W0310 20:20:46.083917 20336 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000153460ECE20>, because it is not built.
# W0310 20:20:53.501044 20336 save.py:233] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 252). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exported-models\my-model\saved_model\assets
# I0310 20:20:57.570718 20336 builder_impl.py:779] Assets written to: exported-models\my-model\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to exported-models\my-model\pipeline.config
# I0310 20:20:58.077342 20336 config_util.py:253] Writing pipeline config file to exported-models\my-model\pipeline.config
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Evaluation Model:

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'} --checkpoint_dir={MODEL_PATH}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=4.86s).
# Accumulating evaluation results...
# DONE (t=1.56s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.919
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.904
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.771
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.891
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.807
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.900
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0313 12:12:35.595531  6108 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0313 12:12:35.595531  6108 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0313 12:12:35.595531  6108 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0313 12:12:35.595531  6108 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0313 12:12:35.595531  6108 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2024-03-13 12:12:35.598300: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 12:12:36.426152: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# I0313 12:12:36.599996  6108 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# I0313 12:12:36.601009  6108 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0313 12:12:36.601009  6108 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0313 12:12:36.601009  6108 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0313 12:12:36.602002  6108 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0313 12:12:36.627002  6108 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0313 12:12:40.025695  6108 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 12:12:40.936736  6108 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at ./models/ssd_mobilenet_v1_fpn_640x640
# I0313 12:12:43.187365  6108 checkpoint_utils.py:136] Waiting for new checkpoint at ./models/ssd_mobilenet_v1_fpn_640x640
# INFO:tensorflow:Found new checkpoint at ./models/ssd_mobilenet_v1_fpn_640x640\ckpt-26
# I0313 12:12:43.201085  6108 checkpoint_utils.py:145] Found new checkpoint at ./models/ssd_mobilenet_v1_fpn_640x640\ckpt-26
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0313 12:12:47.142133  6108 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0313 12:13:08.059556  6108 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-13 12:13:22.599827: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-13 12:13:24.251338: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:13:24.251723: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:13:24.451604: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:13:24.452019: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:13:24.951255: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:13:24.951778: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 12:13:25.422041  6108 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0313 12:13:25.432061  6108 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0313 12:13:25.561140  6108 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0313 12:13:40.852916  6108 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0313 12:13:54.783612  6108 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0313 12:14:08.976739  6108 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Finished eval step 400
# I0313 12:14:23.211466  6108 model_lib_v2.py:966] Finished eval step 400
# INFO:tensorflow:Finished eval step 500
# I0313 12:14:38.164254  6108 model_lib_v2.py:966] Finished eval step 500
# INFO:tensorflow:Finished eval step 600
# I0313 12:14:55.871766  6108 model_lib_v2.py:966] Finished eval step 600
# INFO:tensorflow:Performing evaluation on 665 images.
# I0313 12:15:06.972384  6108 coco_evaluation.py:293] Performing evaluation on 665 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0313 12:15:06.973383  6108 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I0313 12:15:07.006383  6108 coco_tools.py:138] DONE (t=0.03s)
# INFO:tensorflow:Eval metrics at step 25000
# I0313 12:15:13.603814  6108 model_lib_v2.py:1015] Eval metrics at step 25000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.804386
# I0313 12:15:13.616645  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.804386
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.918698
# I0313 12:15:13.618631  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.918698
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.904220
# I0313 12:15:13.620641  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.904220
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.285407
# I0313 12:15:13.622642  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.285407
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.771440
# I0313 12:15:13.623630  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.771440
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.815023
# I0313 12:15:13.625642  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.815023
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.890810
# I0313 12:15:13.627640  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.890810
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.892451
# I0313 12:15:13.628156  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.892451
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.892451
# I0313 12:15:13.630165  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.892451
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.420000
# I0313 12:15:13.632176  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.420000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.807143
# I0313 12:15:13.633166  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.807143
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.900029
# I0313 12:15:13.636175  6108 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.900029
# INFO:tensorflow:	+ Loss/localization_loss: 0.021549
# I0313 12:15:13.637175  6108 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.021549
# INFO:tensorflow:	+ Loss/classification_loss: 0.201669
# I0313 12:15:13.639165  6108 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.201669
# INFO:tensorflow:	+ Loss/regularization_loss: 0.556578
# I0313 12:15:13.640190  6108 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.556578
# INFO:tensorflow:	+ Loss/total_loss: 0.779796
# I0313 12:15:13.642177  6108 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.779796
# INFO:tensorflow:Exiting evaluation at step 25000
# I0313 12:15:13.929728  6108 model_lib_v2.py:1168] Exiting evaluation at step 25000

# %% [markdown]
# ## Convert tensorflow model to tflite:

# %%
# !python {SCRIPT_PATH + '/export_tflite_graph_tf2.py'} --pipeline_config_path {CONFIG_PATH} --trained_checkpoint_dir {MODEL_PATH + '/' } --output_directory tflite-exported-models\my-model
# Out:
# 2024-03-13 14:36:06.969482: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 14:36:08.090109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# I0313 14:36:10.757506 20924 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-13 14:36:14.105715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2024-03-13 14:36:14.142721: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# I0313 14:36:14.699273 20924 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-13 14:36:15.581877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# I0313 14:36:16.437207 20924 api.py:459] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# 2024-03-13 14:36:17.189887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000288B00FE910>, because it is not built.
# W0313 14:36:17.672713 20924 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000288B00FE910>, because it is not built.
# W0313 14:36:25.576313 20924 save.py:233] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 252). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: tflite-exported-models\my-model\saved_model\assets
# I0313 14:36:28.722613 20924 builder_impl.py:779] Assets written to: tflite-exported-models\my-model\saved_model\assets

# %%
import tensorflow as tf

# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model('./tflite-exported-models/my-model/saved_model')
tflite_model = converter.convert()

#Save the model.
with open('ssd_mobilenet_model.tflite', 'wb') as f:
    f.write(tflite_model)

# %% [markdown]
# Inferencing My Trained Models

# %%
# """
# Object Detection (On Image) From TF2 Saved Model
# =====================================
# """

# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
# import pathlib
# import tensorflow as tf
# import cv2
# import argparse
# # from google.colab.patches import cv2_imshow

# # # Enable GPU dynamic memory allocation
# # gpus = tf.config.experimental.list_physical_devices('GPU')
# # for gpu in gpus:
# #     tf.config.experimental.set_memory_growth(gpu, True)

# # PROVIDE PATH TO IMAGE DIRECTORY
# IMAGE_PATHS = 'D:/Traffic SignBoard Recognition using Deep Learning/Dataset/PASCAL VOC Format Dataset/valid/school_ahead-47_jpg.rf.27437842a37927cad2b44bca959ae0de.jpg'

# # PROVIDE PATH TO MODEL DIRECTORY
# PATH_TO_MODEL_DIR = './exported-models/my-model'

# # PROVIDE PATH TO LABEL MAP
# PATH_TO_LABELS = ANNOTATION_PATH + '/label_map.pbtxt'

# # PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
# MIN_CONF_THRESH = float(0.60)

# # LOAD THE MODEL

# import time
# from object_detection.utils import label_map_util
# from object_detection.utils import visualization_utils as viz_utils

# PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

# print('Loading model...', end='')
# start_time = time.time()

# # LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
# detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

# end_time = time.time()
# elapsed_time = end_time - start_time
# print('Done! Took {} seconds'.format(elapsed_time))

# # LOAD LABEL MAP DATA FOR PLOTTING

# category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
#                                                                     use_display_name=True)

# import numpy as np
# from PIL import Image
# import matplotlib.pyplot as plt
# import warnings
# warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

# def load_image_into_numpy_array(path):
#     """Load an image from file into a numpy array.
#     Puts image into numpy array to feed into tensorflow graph.
#     Note that by convention we put it into a numpy array with shape
#     (height, width, channels), where channels=3 for RGB.
#     Args:
#       path: the file path to the image
#     Returns:
#       uint8 numpy array with shape (img_height, img_width, 3)
#     """
#     return np.array(Image.open(path))

# print('Running inference for {}... '.format(IMAGE_PATHS), end='')

# image = cv2.imread(IMAGE_PATHS)
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image_expanded = np.expand_dims(image_rgb, axis=0)

# # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
# input_tensor = tf.convert_to_tensor(image)
# # The model expects a batch of images, so add an axis with `tf.newaxis`.
# input_tensor = input_tensor[tf.newaxis, ...]

# # input_tensor = np.expand_dims(image_np, 0)
# detections = detect_fn(input_tensor)

# # All outputs are batches tensors.
# # Convert to numpy arrays, and take index [0] to remove the batch dimension.
# # We're only interested in the first num_detections.
# num_detections = int(detections.pop('num_detections'))
# detections = {key: value[0, :num_detections].numpy()
#                for key, value in detections.items()}
# detections['num_detections'] = num_detections

# # detection_classes should be ints.
# detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

# image_with_detections = image.copy()

# # SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
# viz_utils.visualize_boxes_and_labels_on_image_array(
#       image_with_detections,
#       detections['detection_boxes'],
#       detections['detection_classes'],
#       detections['detection_scores'],
#       category_index,
#       use_normalized_coordinates=True,
#       max_boxes_to_draw=1,
#       min_score_thresh=0.3,
#       agnostic_mode=False)

# print('Done')
# # DISPLAYS OUTPUT IMAGE
# cv2.imshow('test', image_with_detections)
# # CLOSES WINDOW ONCE KEY IS PRESSED
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# !tensorboard --logdir D:/"Traffic SignBoard Recognition using Deep Learning"/"SSD MobileNet V1 FPN 640x640"/models/ssd_mobilenet_v1_fpn_640x640 --host localhost --port 6008
# Out:
# ^C
