# %% [markdown]
# # Traffic SignBoard Detection - CenterNet ResNet50 V2 512x512:

# %% [markdown]
# ## 1. DOWNLOAD THE PRETRAINED MODELS FROM THE TENSOFLOW MODEL ZOO

# %%
import os

MODELS_DIR = os.path.join('pre-trained-model')
for dir in [MODELS_DIR]:
    if not os.path.exists(dir):
        os.mkdir(dir)

# %%
main_directory = 'models'
subfolder_name = 'centernet_resnet50_v2_512x512'

main_directory_path = os.path.join(os.getcwd(), main_directory)
subfolder_path = os.path.join(main_directory_path, subfolder_name)

if not os.path.exists(subfolder_path):
    os.makedirs(subfolder_path)

# %%
import tarfile
import urllib.request
import os

# Download and extract model
MODEL_DATE = '20200711'
MODEL_NAME = 'centernet_resnet50_v2_512x512_coco17_tpu-8'
MODEL_TAR_FILENAME = MODEL_NAME + '.tar.gz'
MODELS_DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/'
MODEL_DOWNLOAD_LINK = MODELS_DOWNLOAD_BASE + MODEL_DATE + '/' + MODEL_TAR_FILENAME
PATH_TO_MODEL_TAR = os.path.join(MODELS_DIR, MODEL_TAR_FILENAME)
PATH_TO_CKPT = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'checkpoint/'))
PATH_TO_CFG = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'pipeline.config'))
if not os.path.exists(PATH_TO_CKPT):
    print('Downloading model. This may take a while... ', end='')
    urllib.request.urlretrieve(MODEL_DOWNLOAD_LINK, PATH_TO_MODEL_TAR)
    tar_file = tarfile.open(PATH_TO_MODEL_TAR)
    tar_file.extractall(MODELS_DIR)
    tar_file.close()
    os.remove(PATH_TO_MODEL_TAR)
    print('Done')

# %% [markdown]
# ## 2. SETUP PATHS:

# %%
WORKSPACE_PATH = '../training_helper_directory'
SCRIPT_PATH = WORKSPACE_PATH + '/scripts'
ANNOTATION_PATH = WORKSPACE_PATH + '/annotations'

IMAGE_PATH = '../Dataset/"PASCAL VOC Format Dataset"'

CUSTOM_MODEL_NAME = '/centernet_resnet50_v2_512x512'
MODEL_PATH = './models' + CUSTOM_MODEL_NAME

PRETRAINED_PATH = './pre-trained-model/' + MODEL_NAME
CONFIG_PATH = MODEL_PATH + '/pipeline.config'

EXPORT_PATH = '../exported-models/my-model'

# %% [markdown]
# ## 3. CREATE TF RECORDS:

# %%
# Create train data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}

# Create test data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: ../training_helper_directory/annotations/train.record
# Successfully created the TFRecord file: ../training_helper_directory/annotations/test.record

# %% [markdown]
# ## 4. COPY MODEL CONFIG FILE TO TRANING FOLDER:

# %%
SOURCE_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\CenterNet Resnet50 V2 512x512\pre-trained-model\centernet_resnet50_v2_512x512_coco17_tpu-8\pipeline.config"
DESTINATION_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\CenterNet Resnet50 V2 512x512\models\centernet_resnet50_v2_512x512"

# %%
# !copy "{SOURCE_PATH}" "{DESTINATION_PATH}"
# Out:
#         1 file(s) copied.

# %% [markdown]
# ## 5. UPDATING CONFIG FOR TRANSFER LEARNING:

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': center_net {
#    num_classes: 90
#    feature_extractor {
#      type: "resnet_v2_50"
#    }
#    image_resizer {
#      keep_aspect_ratio_resizer {
#        min_dimension: 512
#        max_dimension: 512
#        pad_to_max_dimension: true
#      }
#    }
#    object_detection_task {
#      task_loss_weight: 1.0
#      offset_loss_weight: 1.0
#      scale_loss_weight: 0.10000000149011612
#      localization_loss {
#        l1_localization_loss {
#        }
#      }
#    }
#    object_center_params {
#      object_center_loss_weight: 1.0
#      classification_loss {
#        penalty_reduced_logistic_focal_loss {
#          alpha: 2.0
#          beta: 4.0
#        }
#      }
#      min_box_overlap_iou: 0.699999988079071
#      max_box_predictions: 100
#    }
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_aspect_ratio: 0.5
#      max_aspect_ratio: 1.7000000476837158
#      random_coef: 0.25
#    }
#  }
#  data_augmentation_options {
#    random_adjust_hue {
#    }
#  }
#  data_augmentation_options {
#    random_adjust_contrast {
#    }
#  }
#  data_augmentation_options {
#    random_adjust_saturation {
#    }
#  }
#  data_augmentation_options {
#    random_adjust_brightness {
#    }
#  }
#  data_augmentation_options {
#    random_absolute_pad_image {
#      max_height_padding: 200
#      max_width_padding: 200
#      pad_color: 0.0
#      pad_color: 0.0
#      pad_color: 0.0
#    }
#  }
#  optimizer {
#    adam_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.0010000000474974513
#          total_steps: 250000
#          warmup_learning_rate: 0.0002500000118743628
#          warmup_steps: 5000
#        }
#      }
#      epsilon: 1.0000000116860974e-07
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 250000
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/train2017-?????-of-00256.tfrecord"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false
#  batch_size: 1,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.center_net.num_classes = 56

pipeline_config.train_config.batch_size = 2
pipeline_config.train_config.num_steps = 25000

pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_PATH + '/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection" 

pipeline_config.train_input_reader.label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH+ '/train.record'] 

pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:
    f.write(config_text)

# %% [markdown]
# ## 6. TRAIN THE MODEL:

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.getcwd()
# Out:
# 'd:\\Traffic SignBoard Recognition using Deep Learning\\CenterNet Resnet50 V2 512x512'

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'}
# Out:
# 2024-03-07 00:08:41.962982: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-07 00:08:42.811935: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0307 00:08:42.898658 15648 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0307 00:08:42.906658 15648 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0307 00:08:42.906658 15648 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.944428 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.947334 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.948334 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.949334 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.954332 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.957331 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.976376 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.977375 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.978376 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0307 00:08:42.978376 15648 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0307 00:08:44.704337 15648 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# I0307 00:08:44.721347 15648 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# I0307 00:08:44.721347 15648 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0307 00:08:44.721347 15648 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0307 00:08:44.721347 15648 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0307 00:08:44.725198 15648 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0307 00:08:44.752403 15648 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0307 00:08:50.440144 15648 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0307 00:08:52.806301 15648 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0307 00:08:55.269749 15648 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2024-03-07 00:09:08.119147: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-07 00:09:10.663485: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.663943: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.746463: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.746953: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.793958: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.794451: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.962005: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:10.962414: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:11.010801: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-07 00:09:11.011228: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0307 00:09:15.041805 15932 deprecation.py:554] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W0307 00:09:16.541454 15932 utils.py:76] Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W0307 00:09:19.793267 22188 utils.py:76] Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W0307 00:09:22.699091 13960 utils.py:76] Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# W0307 00:09:25.717005 12360 utils.py:76] Gradients do not exist for variables ['post_bn/gamma:0', 'post_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# INFO:tensorflow:Step 100 per-step time 0.424s
# I0307 00:09:57.139107 15648 model_lib_v2.py:705] Step 100 per-step time 0.424s
# INFO:tensorflow:{'Loss/box/offset': 0.53557277,
#  'Loss/box/scale': 6.2932487,
#  'Loss/object_center': 6.152008,
#  'Loss/total_loss': 12.98083,
#  'learning_rate': 0.000265}
# I0307 00:09:57.139107 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.53557277,
#  'Loss/box/scale': 6.2932487,
#  'Loss/object_center': 6.152008,
#  'Loss/total_loss': 12.98083,
#  'learning_rate': 0.000265}
# INFO:tensorflow:Step 200 per-step time 0.238s
# I0307 00:10:20.915626 15648 model_lib_v2.py:705] Step 200 per-step time 0.238s
# INFO:tensorflow:{'Loss/box/offset': 0.17380992,
#  'Loss/box/scale': 3.1181352,
#  'Loss/object_center': 6.044963,
#  'Loss/total_loss': 9.336908,
#  'learning_rate': 0.00028}
# I0307 00:10:20.916624 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.17380992,
#  'Loss/box/scale': 3.1181352,
#  'Loss/object_center': 6.044963,
#  'Loss/total_loss': 9.336908,
#  'learning_rate': 0.00028}
# INFO:tensorflow:Step 300 per-step time 0.238s
# I0307 00:10:44.690066 15648 model_lib_v2.py:705] Step 300 per-step time 0.238s
# INFO:tensorflow:{'Loss/box/offset': 0.6501664,
#  'Loss/box/scale': 0.82194024,
#  'Loss/object_center': 5.456622,
#  'Loss/total_loss': 6.928729,
#  'learning_rate': 0.000295}
# I0307 00:10:44.690066 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.6501664,
#  'Loss/box/scale': 0.82194024,
#  'Loss/object_center': 5.456622,
#  'Loss/total_loss': 6.928729,
#  'learning_rate': 0.000295}
# INFO:tensorflow:Step 400 per-step time 0.241s
# I0307 00:11:08.823438 15648 model_lib_v2.py:705] Step 400 per-step time 0.241s
# INFO:tensorflow:{'Loss/box/offset': 0.70802957,
#  'Loss/box/scale': 2.0940118,
#  'Loss/object_center': 4.35307,
#  'Loss/total_loss': 7.1551113,
#  'learning_rate': 0.00031}
# I0307 00:11:08.823438 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.70802957,
#  'Loss/box/scale': 2.0940118,
#  'Loss/object_center': 4.35307,
#  'Loss/total_loss': 7.1551113,
#  'learning_rate': 0.00031}
# INFO:tensorflow:Step 500 per-step time 0.246s
# I0307 00:11:33.450184 15648 model_lib_v2.py:705] Step 500 per-step time 0.246s
# INFO:tensorflow:{'Loss/box/offset': 0.5185803,
#  'Loss/box/scale': 1.8905262,
#  'Loss/object_center': 4.3687243,
#  'Loss/total_loss': 6.777831,
#  'learning_rate': 0.00032500003}
# I0307 00:11:33.450184 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5185803,
#  'Loss/box/scale': 1.8905262,
#  'Loss/object_center': 4.3687243,
#  'Loss/total_loss': 6.777831,
#  'learning_rate': 0.00032500003}
# INFO:tensorflow:Step 600 per-step time 0.249s
# I0307 00:11:58.336067 15648 model_lib_v2.py:705] Step 600 per-step time 0.249s
# INFO:tensorflow:{'Loss/box/offset': 0.6506052,
#  'Loss/box/scale': 1.4918603,
#  'Loss/object_center': 3.9829164,
#  'Loss/total_loss': 6.125382,
#  'learning_rate': 0.00034000003}
# I0307 00:11:58.336067 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.6506052,
#  'Loss/box/scale': 1.4918603,
#  'Loss/object_center': 3.9829164,
#  'Loss/total_loss': 6.125382,
#  'learning_rate': 0.00034000003}
# INFO:tensorflow:Step 700 per-step time 0.250s
# I0307 00:12:23.385280 15648 model_lib_v2.py:705] Step 700 per-step time 0.250s
# INFO:tensorflow:{'Loss/box/offset': 0.47582334,
#  'Loss/box/scale': 0.7011835,
#  'Loss/object_center': 3.7099898,
#  'Loss/total_loss': 4.8869967,
#  'learning_rate': 0.00035500003}
# I0307 00:12:23.385280 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.47582334,
#  'Loss/box/scale': 0.7011835,
#  'Loss/object_center': 3.7099898,
#  'Loss/total_loss': 4.8869967,
#  'learning_rate': 0.00035500003}
# INFO:tensorflow:Step 800 per-step time 0.253s
# I0307 00:12:48.683943 15648 model_lib_v2.py:705] Step 800 per-step time 0.253s
# INFO:tensorflow:{'Loss/box/offset': 0.4811958,
#  'Loss/box/scale': 1.687661,
#  'Loss/object_center': 3.3904722,
#  'Loss/total_loss': 5.559329,
#  'learning_rate': 0.00037000002}
# I0307 00:12:48.683943 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.4811958,
#  'Loss/box/scale': 1.687661,
#  'Loss/object_center': 3.3904722,
#  'Loss/total_loss': 5.559329,
#  'learning_rate': 0.00037000002}
# INFO:tensorflow:Step 900 per-step time 0.254s
# I0307 00:13:14.047602 15648 model_lib_v2.py:705] Step 900 per-step time 0.254s
# INFO:tensorflow:{'Loss/box/offset': 0.53355867,
#  'Loss/box/scale': 2.2044969,
#  'Loss/object_center': 3.4845805,
#  'Loss/total_loss': 6.222636,
#  'learning_rate': 0.00038500002}
# I0307 00:13:14.047602 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.53355867,
#  'Loss/box/scale': 2.2044969,
#  'Loss/object_center': 3.4845805,
#  'Loss/total_loss': 6.222636,
#  'learning_rate': 0.00038500002}
# INFO:tensorflow:Step 1000 per-step time 0.256s
# I0307 00:13:39.679274 15648 model_lib_v2.py:705] Step 1000 per-step time 0.256s
# INFO:tensorflow:{'Loss/box/offset': 0.5497736,
#  'Loss/box/scale': 2.4731865,
#  'Loss/object_center': 3.439863,
#  'Loss/total_loss': 6.4628234,
#  'learning_rate': 0.00040000002}
# I0307 00:13:39.679274 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5497736,
#  'Loss/box/scale': 2.4731865,
#  'Loss/object_center': 3.439863,
#  'Loss/total_loss': 6.4628234,
#  'learning_rate': 0.00040000002}
# INFO:tensorflow:Step 1100 per-step time 0.267s
# I0307 00:14:06.384205 15648 model_lib_v2.py:705] Step 1100 per-step time 0.267s
# INFO:tensorflow:{'Loss/box/offset': 0.506266,
#  'Loss/box/scale': 1.2804688,
#  'Loss/object_center': 2.8417842,
#  'Loss/total_loss': 4.628519,
#  'learning_rate': 0.00041500002}
# I0307 00:14:06.384205 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.506266,
#  'Loss/box/scale': 1.2804688,
#  'Loss/object_center': 2.8417842,
#  'Loss/total_loss': 4.628519,
#  'learning_rate': 0.00041500002}
# INFO:tensorflow:Step 1200 per-step time 0.258s
# I0307 00:14:32.170126 15648 model_lib_v2.py:705] Step 1200 per-step time 0.258s
# INFO:tensorflow:{'Loss/box/offset': 0.868461,
#  'Loss/box/scale': 1.1602305,
#  'Loss/object_center': 2.886847,
#  'Loss/total_loss': 4.915539,
#  'learning_rate': 0.00043000001}
# I0307 00:14:32.171126 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.868461,
#  'Loss/box/scale': 1.1602305,
#  'Loss/object_center': 2.886847,
#  'Loss/total_loss': 4.915539,
#  'learning_rate': 0.00043000001}
# INFO:tensorflow:Step 1300 per-step time 0.259s
# I0307 00:14:58.025425 15648 model_lib_v2.py:705] Step 1300 per-step time 0.259s
# INFO:tensorflow:{'Loss/box/offset': 0.5004561,
#  'Loss/box/scale': 1.6535767,
#  'Loss/object_center': 2.9386864,
#  'Loss/total_loss': 5.092719,
#  'learning_rate': 0.000445}
# I0307 00:14:58.025425 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5004561,
#  'Loss/box/scale': 1.6535767,
#  'Loss/object_center': 2.9386864,
#  'Loss/total_loss': 5.092719,
#  'learning_rate': 0.000445}
# INFO:tensorflow:Step 1400 per-step time 0.261s
# I0307 00:15:24.086359 15648 model_lib_v2.py:705] Step 1400 per-step time 0.261s
# INFO:tensorflow:{'Loss/box/offset': 0.9597381,
#  'Loss/box/scale': 0.5876549,
#  'Loss/object_center': 2.7010834,
#  'Loss/total_loss': 4.2484765,
#  'learning_rate': 0.00046}
# I0307 00:15:24.086359 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.9597381,
#  'Loss/box/scale': 0.5876549,
#  'Loss/object_center': 2.7010834,
#  'Loss/total_loss': 4.2484765,
#  'learning_rate': 0.00046}
# INFO:tensorflow:Step 1500 per-step time 0.260s
# I0307 00:15:50.100971 15648 model_lib_v2.py:705] Step 1500 per-step time 0.260s
# INFO:tensorflow:{'Loss/box/offset': 0.54186046,
#  'Loss/box/scale': 1.742917,
#  'Loss/object_center': 2.455576,
#  'Loss/total_loss': 4.7403536,
#  'learning_rate': 0.000475}
# I0307 00:15:50.100971 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.54186046,
#  'Loss/box/scale': 1.742917,
#  'Loss/object_center': 2.455576,
#  'Loss/total_loss': 4.7403536,
#  'learning_rate': 0.000475}
# INFO:tensorflow:Step 1600 per-step time 0.261s
# I0307 00:16:16.198757 15648 model_lib_v2.py:705] Step 1600 per-step time 0.261s
# INFO:tensorflow:{'Loss/box/offset': 0.7736323,
#  'Loss/box/scale': 0.9800709,
#  'Loss/object_center': 2.8480031,
#  'Loss/total_loss': 4.6017065,
#  'learning_rate': 0.00049}
# I0307 00:16:16.198757 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.7736323,
#  'Loss/box/scale': 0.9800709,
#  'Loss/object_center': 2.8480031,
#  'Loss/total_loss': 4.6017065,
#  'learning_rate': 0.00049}
# INFO:tensorflow:Step 1700 per-step time 0.260s
# I0307 00:16:42.235324 15648 model_lib_v2.py:705] Step 1700 per-step time 0.260s
# INFO:tensorflow:{'Loss/box/offset': 0.43371978,
#  'Loss/box/scale': 1.1708145,
#  'Loss/object_center': 2.3479931,
#  'Loss/total_loss': 3.9525275,
#  'learning_rate': 0.000505}
# I0307 00:16:42.235324 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.43371978,
#  'Loss/box/scale': 1.1708145,
#  'Loss/object_center': 2.3479931,
#  'Loss/total_loss': 3.9525275,
#  'learning_rate': 0.000505}
# INFO:tensorflow:Step 1800 per-step time 0.260s
# I0307 00:17:08.239460 15648 model_lib_v2.py:705] Step 1800 per-step time 0.260s
# INFO:tensorflow:{'Loss/box/offset': 0.65525365,
#  'Loss/box/scale': 1.7331066,
#  'Loss/object_center': 3.4785125,
#  'Loss/total_loss': 5.866873,
#  'learning_rate': 0.00052}
# I0307 00:17:08.239460 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.65525365,
#  'Loss/box/scale': 1.7331066,
#  'Loss/object_center': 3.4785125,
#  'Loss/total_loss': 5.866873,
#  'learning_rate': 0.00052}
# INFO:tensorflow:Step 1900 per-step time 0.260s
# I0307 00:17:34.282849 15648 model_lib_v2.py:705] Step 1900 per-step time 0.260s
# INFO:tensorflow:{'Loss/box/offset': 0.60688674,
#  'Loss/box/scale': 3.4018593,
#  'Loss/object_center': 3.0416062,
#  'Loss/total_loss': 7.050352,
#  'learning_rate': 0.000535}
# I0307 00:17:34.282849 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.60688674,
#  'Loss/box/scale': 3.4018593,
#  'Loss/object_center': 3.0416062,
#  'Loss/total_loss': 7.050352,
#  'learning_rate': 0.000535}
# INFO:tensorflow:Step 2000 per-step time 0.263s
# I0307 00:18:00.562375 15648 model_lib_v2.py:705] Step 2000 per-step time 0.263s
# INFO:tensorflow:{'Loss/box/offset': 0.49270147,
#  'Loss/box/scale': 2.4518924,
#  'Loss/object_center': 2.4876037,
#  'Loss/total_loss': 5.4321976,
#  'learning_rate': 0.00055}
# I0307 00:18:00.562375 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.49270147,
#  'Loss/box/scale': 2.4518924,
#  'Loss/object_center': 2.4876037,
#  'Loss/total_loss': 5.4321976,
#  'learning_rate': 0.00055}
# INFO:tensorflow:Step 2100 per-step time 0.276s
# I0307 00:18:28.151835 15648 model_lib_v2.py:705] Step 2100 per-step time 0.276s
# INFO:tensorflow:{'Loss/box/offset': 0.4825979,
#  'Loss/box/scale': 1.3764114,
#  'Loss/object_center': 2.4167404,
#  'Loss/total_loss': 4.2757497,
#  'learning_rate': 0.000565}
# I0307 00:18:28.151835 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.4825979,
#  'Loss/box/scale': 1.3764114,
#  'Loss/object_center': 2.4167404,
#  'Loss/total_loss': 4.2757497,
#  'learning_rate': 0.000565}
# INFO:tensorflow:Step 2200 per-step time 0.261s
# I0307 00:18:54.295557 15648 model_lib_v2.py:705] Step 2200 per-step time 0.261s
# INFO:tensorflow:{'Loss/box/offset': 0.56564856,
#  'Loss/box/scale': 0.6789382,
#  'Loss/object_center': 2.4071517,
#  'Loss/total_loss': 3.6517384,
#  'learning_rate': 0.00058}
# I0307 00:18:54.295557 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.56564856,
#  'Loss/box/scale': 0.6789382,
#  'Loss/object_center': 2.4071517,
#  'Loss/total_loss': 3.6517384,
#  'learning_rate': 0.00058}
# INFO:tensorflow:Step 2300 per-step time 0.262s
# I0307 00:19:20.492758 15648 model_lib_v2.py:705] Step 2300 per-step time 0.262s
# INFO:tensorflow:{'Loss/box/offset': 0.46222746,
#  'Loss/box/scale': 1.334171,
#  'Loss/object_center': 3.5794942,
#  'Loss/total_loss': 5.3758926,
#  'learning_rate': 0.000595}
# I0307 00:19:20.492758 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.46222746,
#  'Loss/box/scale': 1.334171,
#  'Loss/object_center': 3.5794942,
#  'Loss/total_loss': 5.3758926,
#  'learning_rate': 0.000595}
# INFO:tensorflow:Step 2400 per-step time 0.261s
# I0307 00:19:46.595602 15648 model_lib_v2.py:705] Step 2400 per-step time 0.261s
# INFO:tensorflow:{'Loss/box/offset': 0.5670788,
#  'Loss/box/scale': 0.25952703,
#  'Loss/object_center': 2.1752746,
#  'Loss/total_loss': 3.0018804,
#  'learning_rate': 0.00061}
# I0307 00:19:46.596602 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5670788,
#  'Loss/box/scale': 0.25952703,
#  'Loss/object_center': 2.1752746,
#  'Loss/total_loss': 3.0018804,
#  'learning_rate': 0.00061}
# INFO:tensorflow:Step 2500 per-step time 0.282s
# I0307 00:20:14.765991 15648 model_lib_v2.py:705] Step 2500 per-step time 0.282s
# INFO:tensorflow:{'Loss/box/offset': 0.69847745,
#  'Loss/box/scale': 1.0598186,
#  'Loss/object_center': 3.2832716,
#  'Loss/total_loss': 5.0415673,
#  'learning_rate': 0.000625}
# I0307 00:20:14.765991 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.69847745,
#  'Loss/box/scale': 1.0598186,
#  'Loss/object_center': 3.2832716,
#  'Loss/total_loss': 5.0415673,
#  'learning_rate': 0.000625}
# INFO:tensorflow:Step 2600 per-step time 0.379s
# I0307 00:20:52.685979 15648 model_lib_v2.py:705] Step 2600 per-step time 0.379s
# INFO:tensorflow:{'Loss/box/offset': 0.6479894,
#  'Loss/box/scale': 0.722126,
#  'Loss/object_center': 3.4040387,
#  'Loss/total_loss': 4.7741537,
#  'learning_rate': 0.00064}
# I0307 00:20:52.685979 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.6479894,
#  'Loss/box/scale': 0.722126,
#  'Loss/object_center': 3.4040387,
#  'Loss/total_loss': 4.7741537,
#  'learning_rate': 0.00064}
# INFO:tensorflow:Step 2700 per-step time 0.403s
# I0307 00:21:33.038882 15648 model_lib_v2.py:705] Step 2700 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.3881086,
#  'Loss/box/scale': 1.0235227,
#  'Loss/object_center': 2.5453155,
#  'Loss/total_loss': 3.9569468,
#  'learning_rate': 0.00065500004}
# I0307 00:21:33.038882 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.3881086,
#  'Loss/box/scale': 1.0235227,
#  'Loss/object_center': 2.5453155,
#  'Loss/total_loss': 3.9569468,
#  'learning_rate': 0.00065500004}
# INFO:tensorflow:Step 2800 per-step time 0.381s
# I0307 00:22:11.136801 15648 model_lib_v2.py:705] Step 2800 per-step time 0.381s
# INFO:tensorflow:{'Loss/box/offset': 0.4809215,
#  'Loss/box/scale': 1.5291138,
#  'Loss/object_center': 2.5527935,
#  'Loss/total_loss': 4.562829,
#  'learning_rate': 0.00067000004}
# I0307 00:22:11.136801 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.4809215,
#  'Loss/box/scale': 1.5291138,
#  'Loss/object_center': 2.5527935,
#  'Loss/total_loss': 4.562829,
#  'learning_rate': 0.00067000004}
# INFO:tensorflow:Step 2900 per-step time 0.410s
# I0307 00:22:52.165177 15648 model_lib_v2.py:705] Step 2900 per-step time 0.410s
# INFO:tensorflow:{'Loss/box/offset': 0.20954941,
#  'Loss/box/scale': 0.7172821,
#  'Loss/object_center': 3.380121,
#  'Loss/total_loss': 4.3069525,
#  'learning_rate': 0.00068500004}
# I0307 00:22:52.165177 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.20954941,
#  'Loss/box/scale': 0.7172821,
#  'Loss/object_center': 3.380121,
#  'Loss/total_loss': 4.3069525,
#  'learning_rate': 0.00068500004}
# INFO:tensorflow:Step 3000 per-step time 0.412s
# I0307 00:23:33.322779 15648 model_lib_v2.py:705] Step 3000 per-step time 0.412s
# INFO:tensorflow:{'Loss/box/offset': 0.3610338,
#  'Loss/box/scale': 0.88382196,
#  'Loss/object_center': 2.56993,
#  'Loss/total_loss': 3.814786,
#  'learning_rate': 0.00070000003}
# I0307 00:23:33.323781 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.3610338,
#  'Loss/box/scale': 0.88382196,
#  'Loss/object_center': 2.56993,
#  'Loss/total_loss': 3.814786,
#  'learning_rate': 0.00070000003}
# INFO:tensorflow:Step 3100 per-step time 0.415s
# I0307 00:24:14.783682 15648 model_lib_v2.py:705] Step 3100 per-step time 0.415s
# INFO:tensorflow:{'Loss/box/offset': 0.692502,
#  'Loss/box/scale': 1.2729924,
#  'Loss/object_center': 3.6974335,
#  'Loss/total_loss': 5.6629276,
#  'learning_rate': 0.00071500003}
# I0307 00:24:14.783682 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.692502,
#  'Loss/box/scale': 1.2729924,
#  'Loss/object_center': 3.6974335,
#  'Loss/total_loss': 5.6629276,
#  'learning_rate': 0.00071500003}
# INFO:tensorflow:Step 3200 per-step time 0.405s
# I0307 00:24:55.336759 15648 model_lib_v2.py:705] Step 3200 per-step time 0.405s
# INFO:tensorflow:{'Loss/box/offset': 0.61727816,
#  'Loss/box/scale': 0.5331492,
#  'Loss/object_center': 2.400932,
#  'Loss/total_loss': 3.5513594,
#  'learning_rate': 0.00073}
# I0307 00:24:55.337759 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.61727816,
#  'Loss/box/scale': 0.5331492,
#  'Loss/object_center': 2.400932,
#  'Loss/total_loss': 3.5513594,
#  'learning_rate': 0.00073}
# INFO:tensorflow:Step 3300 per-step time 0.410s
# I0307 00:25:36.310802 15648 model_lib_v2.py:705] Step 3300 per-step time 0.410s
# INFO:tensorflow:{'Loss/box/offset': 0.46521318,
#  'Loss/box/scale': 1.768158,
#  'Loss/object_center': 3.1648674,
#  'Loss/total_loss': 5.3982387,
#  'learning_rate': 0.0007450001}
# I0307 00:25:36.310802 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.46521318,
#  'Loss/box/scale': 1.768158,
#  'Loss/object_center': 3.1648674,
#  'Loss/total_loss': 5.3982387,
#  'learning_rate': 0.0007450001}
# INFO:tensorflow:Step 3400 per-step time 0.403s
# I0307 00:26:16.655312 15648 model_lib_v2.py:705] Step 3400 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.23208429,
#  'Loss/box/scale': 0.6910252,
#  'Loss/object_center': 2.8218346,
#  'Loss/total_loss': 3.744944,
#  'learning_rate': 0.0007600001}
# I0307 00:26:16.655312 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.23208429,
#  'Loss/box/scale': 0.6910252,
#  'Loss/object_center': 2.8218346,
#  'Loss/total_loss': 3.744944,
#  'learning_rate': 0.0007600001}
# INFO:tensorflow:Step 3500 per-step time 0.403s
# I0307 00:26:56.976702 15648 model_lib_v2.py:705] Step 3500 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.9737596,
#  'Loss/box/scale': 1.0184654,
#  'Loss/object_center': 3.1871176,
#  'Loss/total_loss': 5.1793427,
#  'learning_rate': 0.0007750001}
# I0307 00:26:56.976702 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.9737596,
#  'Loss/box/scale': 1.0184654,
#  'Loss/object_center': 3.1871176,
#  'Loss/total_loss': 5.1793427,
#  'learning_rate': 0.0007750001}
# INFO:tensorflow:Step 3600 per-step time 0.404s
# I0307 00:27:37.354556 15648 model_lib_v2.py:705] Step 3600 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.3498693,
#  'Loss/box/scale': 0.69535637,
#  'Loss/object_center': 3.1423776,
#  'Loss/total_loss': 4.1876035,
#  'learning_rate': 0.0007900001}
# I0307 00:27:37.354556 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.3498693,
#  'Loss/box/scale': 0.69535637,
#  'Loss/object_center': 3.1423776,
#  'Loss/total_loss': 4.1876035,
#  'learning_rate': 0.0007900001}
# INFO:tensorflow:Step 3700 per-step time 0.405s
# I0307 00:28:17.880267 15648 model_lib_v2.py:705] Step 3700 per-step time 0.405s
# INFO:tensorflow:{'Loss/box/offset': 0.34766537,
#  'Loss/box/scale': 0.3948044,
#  'Loss/object_center': 2.3999615,
#  'Loss/total_loss': 3.1424313,
#  'learning_rate': 0.0008050001}
# I0307 00:28:17.881267 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.34766537,
#  'Loss/box/scale': 0.3948044,
#  'Loss/object_center': 2.3999615,
#  'Loss/total_loss': 3.1424313,
#  'learning_rate': 0.0008050001}
# INFO:tensorflow:Step 3800 per-step time 0.404s
# I0307 00:28:58.233155 15648 model_lib_v2.py:705] Step 3800 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.31265163,
#  'Loss/box/scale': 2.7382314,
#  'Loss/object_center': 4.8679423,
#  'Loss/total_loss': 7.918825,
#  'learning_rate': 0.0008200001}
# I0307 00:28:58.234157 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.31265163,
#  'Loss/box/scale': 2.7382314,
#  'Loss/object_center': 4.8679423,
#  'Loss/total_loss': 7.918825,
#  'learning_rate': 0.0008200001}
# INFO:tensorflow:Step 3900 per-step time 0.392s
# I0307 00:29:37.439456 15648 model_lib_v2.py:705] Step 3900 per-step time 0.392s
# INFO:tensorflow:{'Loss/box/offset': 0.7420502,
#  'Loss/box/scale': 0.60418016,
#  'Loss/object_center': 3.764867,
#  'Loss/total_loss': 5.1110973,
#  'learning_rate': 0.0008350001}
# I0307 00:29:37.440460 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.7420502,
#  'Loss/box/scale': 0.60418016,
#  'Loss/object_center': 3.764867,
#  'Loss/total_loss': 5.1110973,
#  'learning_rate': 0.0008350001}
# INFO:tensorflow:Step 4000 per-step time 0.404s
# I0307 00:30:17.820231 15648 model_lib_v2.py:705] Step 4000 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.42822883,
#  'Loss/box/scale': 0.6691788,
#  'Loss/object_center': 3.188907,
#  'Loss/total_loss': 4.2863145,
#  'learning_rate': 0.00085000007}
# I0307 00:30:17.820231 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.42822883,
#  'Loss/box/scale': 0.6691788,
#  'Loss/object_center': 3.188907,
#  'Loss/total_loss': 4.2863145,
#  'learning_rate': 0.00085000007}
# INFO:tensorflow:Step 4100 per-step time 0.416s
# I0307 00:30:59.415548 15648 model_lib_v2.py:705] Step 4100 per-step time 0.416s
# INFO:tensorflow:{'Loss/box/offset': 0.7685097,
#  'Loss/box/scale': 1.0554253,
#  'Loss/object_center': 2.9139948,
#  'Loss/total_loss': 4.73793,
#  'learning_rate': 0.00086500007}
# I0307 00:30:59.416546 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.7685097,
#  'Loss/box/scale': 1.0554253,
#  'Loss/object_center': 2.9139948,
#  'Loss/total_loss': 4.73793,
#  'learning_rate': 0.00086500007}
# INFO:tensorflow:Step 4200 per-step time 0.404s
# I0307 00:31:39.765286 15648 model_lib_v2.py:705] Step 4200 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.36985895,
#  'Loss/box/scale': 1.4240719,
#  'Loss/object_center': 2.3851204,
#  'Loss/total_loss': 4.179051,
#  'learning_rate': 0.00088000007}
# I0307 00:31:39.765286 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.36985895,
#  'Loss/box/scale': 1.4240719,
#  'Loss/object_center': 2.3851204,
#  'Loss/total_loss': 4.179051,
#  'learning_rate': 0.00088000007}
# INFO:tensorflow:Step 4300 per-step time 0.403s
# I0307 00:32:20.116856 15648 model_lib_v2.py:705] Step 4300 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.4244092,
#  'Loss/box/scale': 0.6151554,
#  'Loss/object_center': 2.9567187,
#  'Loss/total_loss': 3.9962833,
#  'learning_rate': 0.00089500006}
# I0307 00:32:20.116856 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.4244092,
#  'Loss/box/scale': 0.6151554,
#  'Loss/object_center': 2.9567187,
#  'Loss/total_loss': 3.9962833,
#  'learning_rate': 0.00089500006}
# INFO:tensorflow:Step 4400 per-step time 0.403s
# I0307 00:33:00.454784 15648 model_lib_v2.py:705] Step 4400 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.48598644,
#  'Loss/box/scale': 1.1413167,
#  'Loss/object_center': 2.3911142,
#  'Loss/total_loss': 4.0184174,
#  'learning_rate': 0.00091000006}
# I0307 00:33:00.454784 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.48598644,
#  'Loss/box/scale': 1.1413167,
#  'Loss/object_center': 2.3911142,
#  'Loss/total_loss': 4.0184174,
#  'learning_rate': 0.00091000006}
# INFO:tensorflow:Step 4500 per-step time 0.403s
# I0307 00:33:40.795136 15648 model_lib_v2.py:705] Step 4500 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.5457303,
#  'Loss/box/scale': 1.8670319,
#  'Loss/object_center': 2.9342437,
#  'Loss/total_loss': 5.347006,
#  'learning_rate': 0.00092500006}
# I0307 00:33:40.795136 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5457303,
#  'Loss/box/scale': 1.8670319,
#  'Loss/object_center': 2.9342437,
#  'Loss/total_loss': 5.347006,
#  'learning_rate': 0.00092500006}
# INFO:tensorflow:Step 4600 per-step time 0.404s
# I0307 00:34:21.149781 15648 model_lib_v2.py:705] Step 4600 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.591367,
#  'Loss/box/scale': 0.97032684,
#  'Loss/object_center': 2.2714,
#  'Loss/total_loss': 3.833094,
#  'learning_rate': 0.00094000006}
# I0307 00:34:21.150781 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.591367,
#  'Loss/box/scale': 0.97032684,
#  'Loss/object_center': 2.2714,
#  'Loss/total_loss': 3.833094,
#  'learning_rate': 0.00094000006}
# INFO:tensorflow:Step 4700 per-step time 0.404s
# I0307 00:35:01.547997 15648 model_lib_v2.py:705] Step 4700 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.5595123,
#  'Loss/box/scale': 0.43975553,
#  'Loss/object_center': 2.7438056,
#  'Loss/total_loss': 3.7430735,
#  'learning_rate': 0.00095500005}
# I0307 00:35:01.547997 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5595123,
#  'Loss/box/scale': 0.43975553,
#  'Loss/object_center': 2.7438056,
#  'Loss/total_loss': 3.7430735,
#  'learning_rate': 0.00095500005}
# INFO:tensorflow:Step 4800 per-step time 0.404s
# I0307 00:35:41.948329 15648 model_lib_v2.py:705] Step 4800 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.5387105,
#  'Loss/box/scale': 0.4772911,
#  'Loss/object_center': 2.7264977,
#  'Loss/total_loss': 3.7424994,
#  'learning_rate': 0.00097000005}
# I0307 00:35:41.948329 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5387105,
#  'Loss/box/scale': 0.4772911,
#  'Loss/object_center': 2.7264977,
#  'Loss/total_loss': 3.7424994,
#  'learning_rate': 0.00097000005}
# INFO:tensorflow:Step 4900 per-step time 0.404s
# I0307 00:36:22.305701 15648 model_lib_v2.py:705] Step 4900 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.5450921,
#  'Loss/box/scale': 1.8919604,
#  'Loss/object_center': 1.9770383,
#  'Loss/total_loss': 4.4140906,
#  'learning_rate': 0.000985}
# I0307 00:36:22.305701 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5450921,
#  'Loss/box/scale': 1.8919604,
#  'Loss/object_center': 1.9770383,
#  'Loss/total_loss': 4.4140906,
#  'learning_rate': 0.000985}
# INFO:tensorflow:Step 5000 per-step time 0.404s
# I0307 00:37:02.663267 15648 model_lib_v2.py:705] Step 5000 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.45254743,
#  'Loss/box/scale': 0.26091814,
#  'Loss/object_center': 1.938731,
#  'Loss/total_loss': 2.6521964,
#  'learning_rate': 0.001}
# I0307 00:37:02.663267 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.45254743,
#  'Loss/box/scale': 0.26091814,
#  'Loss/object_center': 1.938731,
#  'Loss/total_loss': 2.6521964,
#  'learning_rate': 0.001}
# INFO:tensorflow:Step 5100 per-step time 0.415s
# I0307 00:37:44.165705 15648 model_lib_v2.py:705] Step 5100 per-step time 0.415s
# INFO:tensorflow:{'Loss/box/offset': 0.41085383,
#  'Loss/box/scale': 1.7444317,
#  'Loss/object_center': 3.1072488,
#  'Loss/total_loss': 5.2625346,
#  'learning_rate': 0.0009999996}
# I0307 00:37:44.165705 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.41085383,
#  'Loss/box/scale': 1.7444317,
#  'Loss/object_center': 3.1072488,
#  'Loss/total_loss': 5.2625346,
#  'learning_rate': 0.0009999996}
# INFO:tensorflow:Step 5200 per-step time 0.404s
# I0307 00:38:24.542244 15648 model_lib_v2.py:705] Step 5200 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.40137038,
#  'Loss/box/scale': 0.8891841,
#  'Loss/object_center': 2.7089257,
#  'Loss/total_loss': 3.99948,
#  'learning_rate': 0.0009999984}
# I0307 00:38:24.542244 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.40137038,
#  'Loss/box/scale': 0.8891841,
#  'Loss/object_center': 2.7089257,
#  'Loss/total_loss': 3.99948,
#  'learning_rate': 0.0009999984}
# INFO:tensorflow:Step 5300 per-step time 0.409s
# I0307 00:39:05.480733 15648 model_lib_v2.py:705] Step 5300 per-step time 0.409s
# INFO:tensorflow:{'Loss/box/offset': 0.52955943,
#  'Loss/box/scale': 2.738179,
#  'Loss/object_center': 3.2884862,
#  'Loss/total_loss': 6.556225,
#  'learning_rate': 0.0009999963}
# I0307 00:39:05.481734 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.52955943,
#  'Loss/box/scale': 2.738179,
#  'Loss/object_center': 3.2884862,
#  'Loss/total_loss': 6.556225,
#  'learning_rate': 0.0009999963}
# INFO:tensorflow:Step 5400 per-step time 0.410s
# I0307 00:39:46.471359 15648 model_lib_v2.py:705] Step 5400 per-step time 0.410s
# INFO:tensorflow:{'Loss/box/offset': 0.64671165,
#  'Loss/box/scale': 0.9429161,
#  'Loss/object_center': 2.1581678,
#  'Loss/total_loss': 3.7477956,
#  'learning_rate': 0.0009999935}
# I0307 00:39:46.472670 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.64671165,
#  'Loss/box/scale': 0.9429161,
#  'Loss/object_center': 2.1581678,
#  'Loss/total_loss': 3.7477956,
#  'learning_rate': 0.0009999935}
# INFO:tensorflow:Step 5500 per-step time 0.406s
# I0307 00:40:27.056728 15648 model_lib_v2.py:705] Step 5500 per-step time 0.406s
# INFO:tensorflow:{'Loss/box/offset': 0.54803663,
#  'Loss/box/scale': 0.3589115,
#  'Loss/object_center': 2.1224086,
#  'Loss/total_loss': 3.0293567,
#  'learning_rate': 0.0009999898}
# I0307 00:40:27.056728 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.54803663,
#  'Loss/box/scale': 0.3589115,
#  'Loss/object_center': 2.1224086,
#  'Loss/total_loss': 3.0293567,
#  'learning_rate': 0.0009999898}
# INFO:tensorflow:Step 5600 per-step time 0.404s
# I0307 00:41:07.417107 15648 model_lib_v2.py:705] Step 5600 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.7058934,
#  'Loss/box/scale': 1.5265316,
#  'Loss/object_center': 2.7848907,
#  'Loss/total_loss': 5.017316,
#  'learning_rate': 0.0009999853}
# I0307 00:41:07.417107 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.7058934,
#  'Loss/box/scale': 1.5265316,
#  'Loss/object_center': 2.7848907,
#  'Loss/total_loss': 5.017316,
#  'learning_rate': 0.0009999853}
# INFO:tensorflow:Step 5700 per-step time 0.403s
# I0307 00:41:47.765935 15648 model_lib_v2.py:705] Step 5700 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.6599467,
#  'Loss/box/scale': 0.8038567,
#  'Loss/object_center': 2.5265934,
#  'Loss/total_loss': 3.9903967,
#  'learning_rate': 0.0009999799}
# I0307 00:41:47.766936 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.6599467,
#  'Loss/box/scale': 0.8038567,
#  'Loss/object_center': 2.5265934,
#  'Loss/total_loss': 3.9903967,
#  'learning_rate': 0.0009999799}
# INFO:tensorflow:Step 5800 per-step time 0.403s
# I0307 00:42:28.105450 15648 model_lib_v2.py:705] Step 5800 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.5656016,
#  'Loss/box/scale': 1.7328396,
#  'Loss/object_center': 2.3205364,
#  'Loss/total_loss': 4.6189775,
#  'learning_rate': 0.0009999737}
# I0307 00:42:28.105450 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5656016,
#  'Loss/box/scale': 1.7328396,
#  'Loss/object_center': 2.3205364,
#  'Loss/total_loss': 4.6189775,
#  'learning_rate': 0.0009999737}
# INFO:tensorflow:Step 5900 per-step time 0.403s
# I0307 00:43:08.453240 15648 model_lib_v2.py:705] Step 5900 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.76802444,
#  'Loss/box/scale': 0.9786852,
#  'Loss/object_center': 3.2471962,
#  'Loss/total_loss': 4.993906,
#  'learning_rate': 0.0009999668}
# I0307 00:43:08.454744 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.76802444,
#  'Loss/box/scale': 0.9786852,
#  'Loss/object_center': 3.2471962,
#  'Loss/total_loss': 4.993906,
#  'learning_rate': 0.0009999668}
# INFO:tensorflow:Step 6000 per-step time 0.403s
# I0307 00:43:48.797681 15648 model_lib_v2.py:705] Step 6000 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.40740433,
#  'Loss/box/scale': 0.6968425,
#  'Loss/object_center': 2.4196703,
#  'Loss/total_loss': 3.5239172,
#  'learning_rate': 0.000999959}
# I0307 00:43:48.797681 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.40740433,
#  'Loss/box/scale': 0.6968425,
#  'Loss/object_center': 2.4196703,
#  'Loss/total_loss': 3.5239172,
#  'learning_rate': 0.000999959}
# INFO:tensorflow:Step 6100 per-step time 0.391s
# I0307 00:44:27.906153 15648 model_lib_v2.py:705] Step 6100 per-step time 0.391s
# INFO:tensorflow:{'Loss/box/offset': 0.51502836,
#  'Loss/box/scale': 1.6180772,
#  'Loss/object_center': 2.5939572,
#  'Loss/total_loss': 4.7270627,
#  'learning_rate': 0.0009999503}
# I0307 00:44:27.907154 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.51502836,
#  'Loss/box/scale': 1.6180772,
#  'Loss/object_center': 2.5939572,
#  'Loss/total_loss': 4.7270627,
#  'learning_rate': 0.0009999503}
# INFO:tensorflow:Step 6200 per-step time 0.404s
# I0307 00:45:08.309904 15648 model_lib_v2.py:705] Step 6200 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.3018825,
#  'Loss/box/scale': 1.1943467,
#  'Loss/object_center': 2.3667428,
#  'Loss/total_loss': 3.862972,
#  'learning_rate': 0.0009999409}
# I0307 00:45:08.310904 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.3018825,
#  'Loss/box/scale': 1.1943467,
#  'Loss/object_center': 2.3667428,
#  'Loss/total_loss': 3.862972,
#  'learning_rate': 0.0009999409}
# INFO:tensorflow:Step 6300 per-step time 0.404s
# I0307 00:45:48.693309 15648 model_lib_v2.py:705] Step 6300 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.68435663,
#  'Loss/box/scale': 1.1246758,
#  'Loss/object_center': 2.301826,
#  'Loss/total_loss': 4.1108584,
#  'learning_rate': 0.0009999305}
# I0307 00:45:48.693309 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.68435663,
#  'Loss/box/scale': 1.1246758,
#  'Loss/object_center': 2.301826,
#  'Loss/total_loss': 4.1108584,
#  'learning_rate': 0.0009999305}
# INFO:tensorflow:Step 6400 per-step time 0.404s
# I0307 00:46:29.061564 15648 model_lib_v2.py:705] Step 6400 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.49278915,
#  'Loss/box/scale': 0.5725798,
#  'Loss/object_center': 2.2914495,
#  'Loss/total_loss': 3.3568187,
#  'learning_rate': 0.0009999195}
# I0307 00:46:29.061564 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.49278915,
#  'Loss/box/scale': 0.5725798,
#  'Loss/object_center': 2.2914495,
#  'Loss/total_loss': 3.3568187,
#  'learning_rate': 0.0009999195}
# INFO:tensorflow:Step 6500 per-step time 0.404s
# I0307 00:47:09.425498 15648 model_lib_v2.py:705] Step 6500 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.40022418,
#  'Loss/box/scale': 1.3448822,
#  'Loss/object_center': 2.590493,
#  'Loss/total_loss': 4.3355994,
#  'learning_rate': 0.0009999075}
# I0307 00:47:09.425498 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.40022418,
#  'Loss/box/scale': 1.3448822,
#  'Loss/object_center': 2.590493,
# ...
#  'Loss/box/scale': 0.8471922,
#  'Loss/object_center': 2.0999558,
#  'Loss/total_loss': 3.4389403,
#  'learning_rate': 0.0009883057}
# INFO:tensorflow:Step 22000 per-step time 0.404s
# I0307 02:32:03.046574 15648 model_lib_v2.py:705] Step 22000 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.6141556,
#  'Loss/box/scale': 0.5915455,
#  'Loss/object_center': 1.9977753,
#  'Loss/total_loss': 3.2034764,
#  'learning_rate': 0.0009881674}
# I0307 02:32:03.046574 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.6141556,
#  'Loss/box/scale': 0.5915455,
#  'Loss/object_center': 1.9977753,
#  'Loss/total_loss': 3.2034764,
#  'learning_rate': 0.0009881674}
# INFO:tensorflow:Step 22100 per-step time 0.415s
# I0307 02:32:44.498443 15648 model_lib_v2.py:705] Step 22100 per-step time 0.415s
# INFO:tensorflow:{'Loss/box/offset': 0.49856734,
#  'Loss/box/scale': 0.4018568,
#  'Loss/object_center': 0.8294582,
#  'Loss/total_loss': 1.7298824,
#  'learning_rate': 0.0009880282}
# I0307 02:32:44.498443 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.49856734,
#  'Loss/box/scale': 0.4018568,
#  'Loss/object_center': 0.8294582,
#  'Loss/total_loss': 1.7298824,
#  'learning_rate': 0.0009880282}
# INFO:tensorflow:Step 22200 per-step time 0.403s
# I0307 02:33:24.840794 15648 model_lib_v2.py:705] Step 22200 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.25141233,
#  'Loss/box/scale': 0.794158,
#  'Loss/object_center': 1.5031056,
#  'Loss/total_loss': 2.548676,
#  'learning_rate': 0.0009878884}
# I0307 02:33:24.840794 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.25141233,
#  'Loss/box/scale': 0.794158,
#  'Loss/object_center': 1.5031056,
#  'Loss/total_loss': 2.548676,
#  'learning_rate': 0.0009878884}
# INFO:tensorflow:Step 22300 per-step time 0.403s
# I0307 02:34:05.188391 15648 model_lib_v2.py:705] Step 22300 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.35538572,
#  'Loss/box/scale': 0.88977414,
#  'Loss/object_center': 2.1994886,
#  'Loss/total_loss': 3.4446485,
#  'learning_rate': 0.0009877477}
# I0307 02:34:05.188391 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.35538572,
#  'Loss/box/scale': 0.88977414,
#  'Loss/object_center': 2.1994886,
#  'Loss/total_loss': 3.4446485,
#  'learning_rate': 0.0009877477}
# INFO:tensorflow:Step 22400 per-step time 0.403s
# I0307 02:34:45.527528 15648 model_lib_v2.py:705] Step 22400 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.49015766,
#  'Loss/box/scale': 0.5216323,
#  'Loss/object_center': 1.5362377,
#  'Loss/total_loss': 2.5480275,
#  'learning_rate': 0.0009876062}
# I0307 02:34:45.527528 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.49015766,
#  'Loss/box/scale': 0.5216323,
#  'Loss/object_center': 1.5362377,
#  'Loss/total_loss': 2.5480275,
#  'learning_rate': 0.0009876062}
# INFO:tensorflow:Step 22500 per-step time 0.404s
# I0307 02:35:25.887403 15648 model_lib_v2.py:705] Step 22500 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.22215919,
#  'Loss/box/scale': 0.61550564,
#  'Loss/object_center': 1.3932453,
#  'Loss/total_loss': 2.23091,
#  'learning_rate': 0.000987464}
# I0307 02:35:25.887403 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.22215919,
#  'Loss/box/scale': 0.61550564,
#  'Loss/object_center': 1.3932453,
#  'Loss/total_loss': 2.23091,
#  'learning_rate': 0.000987464}
# INFO:tensorflow:Step 22600 per-step time 0.404s
# I0307 02:36:06.253039 15648 model_lib_v2.py:705] Step 22600 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.24462241,
#  'Loss/box/scale': 0.42443886,
#  'Loss/object_center': 1.8129007,
#  'Loss/total_loss': 2.481962,
#  'learning_rate': 0.0009873209}
# I0307 02:36:06.253039 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.24462241,
#  'Loss/box/scale': 0.42443886,
#  'Loss/object_center': 1.8129007,
#  'Loss/total_loss': 2.481962,
#  'learning_rate': 0.0009873209}
# INFO:tensorflow:Step 22700 per-step time 0.403s
# I0307 02:36:46.582985 15648 model_lib_v2.py:705] Step 22700 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.55199265,
#  'Loss/box/scale': 0.10967483,
#  'Loss/object_center': 1.5393991,
#  'Loss/total_loss': 2.2010665,
#  'learning_rate': 0.000987177}
# I0307 02:36:46.582985 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.55199265,
#  'Loss/box/scale': 0.10967483,
#  'Loss/object_center': 1.5393991,
#  'Loss/total_loss': 2.2010665,
#  'learning_rate': 0.000987177}
# INFO:tensorflow:Step 22800 per-step time 0.403s
# I0307 02:37:26.927034 15648 model_lib_v2.py:705] Step 22800 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.4943549,
#  'Loss/box/scale': 0.88082314,
#  'Loss/object_center': 1.4384562,
#  'Loss/total_loss': 2.8136342,
#  'learning_rate': 0.0009870324}
# I0307 02:37:26.927034 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.4943549,
#  'Loss/box/scale': 0.88082314,
#  'Loss/object_center': 1.4384562,
#  'Loss/total_loss': 2.8136342,
#  'learning_rate': 0.0009870324}
# INFO:tensorflow:Step 22900 per-step time 0.403s
# I0307 02:38:07.268791 15648 model_lib_v2.py:705] Step 22900 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.31966418,
#  'Loss/box/scale': 0.66019905,
#  'Loss/object_center': 1.558634,
#  'Loss/total_loss': 2.5384972,
#  'learning_rate': 0.0009868869}
# I0307 02:38:07.268791 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.31966418,
#  'Loss/box/scale': 0.66019905,
#  'Loss/object_center': 1.558634,
#  'Loss/total_loss': 2.5384972,
#  'learning_rate': 0.0009868869}
# INFO:tensorflow:Step 23000 per-step time 0.403s
# I0307 02:38:47.616647 15648 model_lib_v2.py:705] Step 23000 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.70192987,
#  'Loss/box/scale': 1.1116089,
#  'Loss/object_center': 1.8683327,
#  'Loss/total_loss': 3.6818714,
#  'learning_rate': 0.0009867407}
# I0307 02:38:47.616647 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.70192987,
#  'Loss/box/scale': 1.1116089,
#  'Loss/object_center': 1.8683327,
#  'Loss/total_loss': 3.6818714,
#  'learning_rate': 0.0009867407}
# INFO:tensorflow:Step 23100 per-step time 0.416s
# I0307 02:39:29.235157 15648 model_lib_v2.py:705] Step 23100 per-step time 0.416s
# INFO:tensorflow:{'Loss/box/offset': 0.2182013,
#  'Loss/box/scale': 0.83343774,
#  'Loss/object_center': 2.1541939,
#  'Loss/total_loss': 3.205833,
#  'learning_rate': 0.0009865935}
# I0307 02:39:29.236171 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.2182013,
#  'Loss/box/scale': 0.83343774,
#  'Loss/object_center': 2.1541939,
#  'Loss/total_loss': 3.205833,
#  'learning_rate': 0.0009865935}
# INFO:tensorflow:Step 23200 per-step time 0.404s
# I0307 02:40:09.653079 15648 model_lib_v2.py:705] Step 23200 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.38412493,
#  'Loss/box/scale': 0.7571053,
#  'Loss/object_center': 2.7599535,
#  'Loss/total_loss': 3.9011838,
#  'learning_rate': 0.0009864457}
# I0307 02:40:09.654079 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.38412493,
#  'Loss/box/scale': 0.7571053,
#  'Loss/object_center': 2.7599535,
#  'Loss/total_loss': 3.9011838,
#  'learning_rate': 0.0009864457}
# INFO:tensorflow:Step 23300 per-step time 0.416s
# I0307 02:40:51.245954 15648 model_lib_v2.py:705] Step 23300 per-step time 0.416s
# INFO:tensorflow:{'Loss/box/offset': 0.46188226,
#  'Loss/box/scale': 0.64585537,
#  'Loss/object_center': 2.7078102,
#  'Loss/total_loss': 3.815548,
#  'learning_rate': 0.000986297}
# I0307 02:40:51.245954 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.46188226,
#  'Loss/box/scale': 0.64585537,
#  'Loss/object_center': 2.7078102,
#  'Loss/total_loss': 3.815548,
#  'learning_rate': 0.000986297}
# INFO:tensorflow:Step 23400 per-step time 0.405s
# I0307 02:41:31.787852 15648 model_lib_v2.py:705] Step 23400 per-step time 0.405s
# INFO:tensorflow:{'Loss/box/offset': 0.24446341,
#  'Loss/box/scale': 1.1033449,
#  'Loss/object_center': 1.1702477,
#  'Loss/total_loss': 2.518056,
#  'learning_rate': 0.0009861476}
# I0307 02:41:31.787852 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.24446341,
#  'Loss/box/scale': 1.1033449,
#  'Loss/object_center': 1.1702477,
#  'Loss/total_loss': 2.518056,
#  'learning_rate': 0.0009861476}
# INFO:tensorflow:Step 23500 per-step time 0.405s
# I0307 02:42:12.249179 15648 model_lib_v2.py:705] Step 23500 per-step time 0.405s
# INFO:tensorflow:{'Loss/box/offset': 0.45611134,
#  'Loss/box/scale': 0.59173626,
#  'Loss/object_center': 0.9420909,
#  'Loss/total_loss': 1.9899385,
#  'learning_rate': 0.0009859973}
# I0307 02:42:12.249179 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.45611134,
#  'Loss/box/scale': 0.59173626,
#  'Loss/object_center': 0.9420909,
#  'Loss/total_loss': 1.9899385,
#  'learning_rate': 0.0009859973}
# INFO:tensorflow:Step 23600 per-step time 0.404s
# I0307 02:42:52.627084 15648 model_lib_v2.py:705] Step 23600 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.48803484,
#  'Loss/box/scale': 0.8716797,
#  'Loss/object_center': 2.047301,
#  'Loss/total_loss': 3.4070158,
#  'learning_rate': 0.0009858462}
# I0307 02:42:52.627084 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.48803484,
#  'Loss/box/scale': 0.8716797,
#  'Loss/object_center': 2.047301,
#  'Loss/total_loss': 3.4070158,
#  'learning_rate': 0.0009858462}
# INFO:tensorflow:Step 23700 per-step time 0.404s
# I0307 02:43:33.053987 15648 model_lib_v2.py:705] Step 23700 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.62996304,
#  'Loss/box/scale': 1.1273507,
#  'Loss/object_center': 1.3391515,
#  'Loss/total_loss': 3.096465,
#  'learning_rate': 0.0009856944}
# I0307 02:43:33.053987 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.62996304,
#  'Loss/box/scale': 1.1273507,
#  'Loss/object_center': 1.3391515,
#  'Loss/total_loss': 3.096465,
#  'learning_rate': 0.0009856944}
# INFO:tensorflow:Step 23800 per-step time 0.404s
# I0307 02:44:13.446695 15648 model_lib_v2.py:705] Step 23800 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.26175255,
#  'Loss/box/scale': 0.26720944,
#  'Loss/object_center': 1.8450085,
#  'Loss/total_loss': 2.3739705,
#  'learning_rate': 0.0009855417}
# I0307 02:44:13.446695 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.26175255,
#  'Loss/box/scale': 0.26720944,
#  'Loss/object_center': 1.8450085,
#  'Loss/total_loss': 2.3739705,
#  'learning_rate': 0.0009855417}
# INFO:tensorflow:Step 23900 per-step time 0.403s
# I0307 02:44:53.777729 15648 model_lib_v2.py:705] Step 23900 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.5944326,
#  'Loss/box/scale': 0.40276453,
#  'Loss/object_center': 2.3865588,
#  'Loss/total_loss': 3.383756,
#  'learning_rate': 0.0009853882}
# I0307 02:44:53.777729 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5944326,
#  'Loss/box/scale': 0.40276453,
#  'Loss/object_center': 2.3865588,
#  'Loss/total_loss': 3.383756,
#  'learning_rate': 0.0009853882}
# INFO:tensorflow:Step 24000 per-step time 0.404s
# I0307 02:45:34.202638 15648 model_lib_v2.py:705] Step 24000 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.35087314,
#  'Loss/box/scale': 0.22936897,
#  'Loss/object_center': 1.8436446,
#  'Loss/total_loss': 2.4238868,
#  'learning_rate': 0.0009852339}
# I0307 02:45:34.202638 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.35087314,
#  'Loss/box/scale': 0.22936897,
#  'Loss/object_center': 1.8436446,
#  'Loss/total_loss': 2.4238868,
#  'learning_rate': 0.0009852339}
# INFO:tensorflow:Step 24100 per-step time 0.414s
# I0307 02:46:15.606546 15648 model_lib_v2.py:705] Step 24100 per-step time 0.414s
# INFO:tensorflow:{'Loss/box/offset': 0.49324584,
#  'Loss/box/scale': 0.96994364,
#  'Loss/object_center': 3.2804215,
#  'Loss/total_loss': 4.7436113,
#  'learning_rate': 0.0009850789}
# I0307 02:46:15.607547 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.49324584,
#  'Loss/box/scale': 0.96994364,
#  'Loss/object_center': 3.2804215,
#  'Loss/total_loss': 4.7436113,
#  'learning_rate': 0.0009850789}
# INFO:tensorflow:Step 24200 per-step time 0.403s
# I0307 02:46:55.948815 15648 model_lib_v2.py:705] Step 24200 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.31157106,
#  'Loss/box/scale': 0.7723198,
#  'Loss/object_center': 2.0794907,
#  'Loss/total_loss': 3.1633816,
#  'learning_rate': 0.0009849231}
# I0307 02:46:55.949829 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.31157106,
#  'Loss/box/scale': 0.7723198,
#  'Loss/object_center': 2.0794907,
#  'Loss/total_loss': 3.1633816,
#  'learning_rate': 0.0009849231}
# INFO:tensorflow:Step 24300 per-step time 0.405s
# I0307 02:47:36.448243 15648 model_lib_v2.py:705] Step 24300 per-step time 0.405s
# INFO:tensorflow:{'Loss/box/offset': 0.50193185,
#  'Loss/box/scale': 0.84540445,
#  'Loss/object_center': 2.2351644,
#  'Loss/total_loss': 3.5825007,
#  'learning_rate': 0.0009847664}
# I0307 02:47:36.448243 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.50193185,
#  'Loss/box/scale': 0.84540445,
#  'Loss/object_center': 2.2351644,
#  'Loss/total_loss': 3.5825007,
#  'learning_rate': 0.0009847664}
# INFO:tensorflow:Step 24400 per-step time 0.405s
# I0307 02:48:16.990806 15648 model_lib_v2.py:705] Step 24400 per-step time 0.405s
# INFO:tensorflow:{'Loss/box/offset': 0.38173318,
#  'Loss/box/scale': 0.45578519,
#  'Loss/object_center': 3.0303395,
#  'Loss/total_loss': 3.867858,
#  'learning_rate': 0.0009846089}
# I0307 02:48:16.990806 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.38173318,
#  'Loss/box/scale': 0.45578519,
#  'Loss/object_center': 3.0303395,
#  'Loss/total_loss': 3.867858,
#  'learning_rate': 0.0009846089}
# INFO:tensorflow:Step 24500 per-step time 0.410s
# I0307 02:48:57.947373 15648 model_lib_v2.py:705] Step 24500 per-step time 0.410s
# INFO:tensorflow:{'Loss/box/offset': 0.64527905,
#  'Loss/box/scale': 2.6219623,
#  'Loss/object_center': 2.233965,
#  'Loss/total_loss': 5.5012064,
#  'learning_rate': 0.0009844507}
# I0307 02:48:57.947373 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.64527905,
#  'Loss/box/scale': 2.6219623,
#  'Loss/object_center': 2.233965,
#  'Loss/total_loss': 5.5012064,
#  'learning_rate': 0.0009844507}
# INFO:tensorflow:Step 24600 per-step time 0.403s
# I0307 02:49:38.290864 15648 model_lib_v2.py:705] Step 24600 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.6237781,
#  'Loss/box/scale': 0.5120945,
#  'Loss/object_center': 1.8872164,
#  'Loss/total_loss': 3.0230892,
#  'learning_rate': 0.0009842915}
# I0307 02:49:38.290864 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.6237781,
#  'Loss/box/scale': 0.5120945,
#  'Loss/object_center': 1.8872164,
#  'Loss/total_loss': 3.0230892,
#  'learning_rate': 0.0009842915}
# INFO:tensorflow:Step 24700 per-step time 0.404s
# I0307 02:50:18.648636 15648 model_lib_v2.py:705] Step 24700 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.531397,
#  'Loss/box/scale': 0.38564816,
#  'Loss/object_center': 2.4124365,
#  'Loss/total_loss': 3.3294816,
#  'learning_rate': 0.0009841317}
# I0307 02:50:18.648636 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.531397,
#  'Loss/box/scale': 0.38564816,
#  'Loss/object_center': 2.4124365,
#  'Loss/total_loss': 3.3294816,
#  'learning_rate': 0.0009841317}
# INFO:tensorflow:Step 24800 per-step time 0.404s
# I0307 02:50:59.001566 15648 model_lib_v2.py:705] Step 24800 per-step time 0.404s
# INFO:tensorflow:{'Loss/box/offset': 0.5421978,
#  'Loss/box/scale': 0.940823,
#  'Loss/object_center': 2.3462942,
#  'Loss/total_loss': 3.8293152,
#  'learning_rate': 0.0009839712}
# I0307 02:50:59.001566 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.5421978,
#  'Loss/box/scale': 0.940823,
#  'Loss/object_center': 2.3462942,
#  'Loss/total_loss': 3.8293152,
#  'learning_rate': 0.0009839712}
# INFO:tensorflow:Step 24900 per-step time 0.403s
# I0307 02:51:39.354249 15648 model_lib_v2.py:705] Step 24900 per-step time 0.403s
# INFO:tensorflow:{'Loss/box/offset': 0.24754244,
#  'Loss/box/scale': 0.53966695,
#  'Loss/object_center': 2.6913812,
#  'Loss/total_loss': 3.4785905,
#  'learning_rate': 0.0009838097}
# I0307 02:51:39.354249 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.24754244,
#  'Loss/box/scale': 0.53966695,
#  'Loss/object_center': 2.6913812,
#  'Loss/total_loss': 3.4785905,
#  'learning_rate': 0.0009838097}
# INFO:tensorflow:Step 25000 per-step time 0.413s
# I0307 02:52:20.660657 15648 model_lib_v2.py:705] Step 25000 per-step time 0.413s
# INFO:tensorflow:{'Loss/box/offset': 0.57777876,
#  'Loss/box/scale': 0.73489153,
#  'Loss/object_center': 2.8089745,
#  'Loss/total_loss': 4.121645,
#  'learning_rate': 0.0009836475}
# I0307 02:52:20.660657 15648 model_lib_v2.py:708] {'Loss/box/offset': 0.57777876,
#  'Loss/box/scale': 0.73489153,
#  'Loss/object_center': 2.8089745,
#  'Loss/total_loss': 4.121645,
#  'learning_rate': 0.0009836475}

# %%
# !python {SCRIPT_PATH + '/exporter_main_v2.py'} --input_type image_tensor --pipeline_config_path {CONFIG_PATH} --trained_checkpoint_dir {MODEL_PATH + '/' } --output_directory exported-models\my-model
# Out:
# 2024-03-07 02:52:41.384181: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-07 02:52:41.804160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0307 02:52:43.929345 16092 deprecation.py:623] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.center_net_meta_arch.CenterNetMetaArch object at 0x0000025FDD89D4C0>, because it is not built.
# W0307 02:52:49.132355 16092 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.center_net_meta_arch.CenterNetMetaArch object at 0x0000025FDD89D4C0>, because it is not built.
# W0307 02:53:05.520392 16092 save.py:233] Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 65). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exported-models\my-model\saved_model\assets
# I0307 02:53:09.861774 16092 builder_impl.py:779] Assets written to: exported-models\my-model\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to exported-models\my-model\pipeline.config
# I0307 02:53:10.441180 16092 config_util.py:253] Writing pipeline config file to exported-models\my-model\pipeline.config

# %% [markdown]
# Inferencing My Trained Models

# %%
# """
# Object Detection (On Image) From TF2 Saved Model
# =====================================
# """

# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
# import pathlib
# import tensorflow as tf
# import cv2
# import argparse
# # from google.colab.patches import cv2_imshow

# # # Enable GPU dynamic memory allocation
# # gpus = tf.config.experimental.list_physical_devices('GPU')
# # for gpu in gpus:
# #     tf.config.experimental.set_memory_growth(gpu, True)

# # PROVIDE PATH TO IMAGE DIRECTORY
# IMAGE_PATHS = 'D:/Traffic SignBoard Recognition using Deep Learning/Dataset/PASCAL VOC Format Dataset/valid/cross_road-35_jpg.rf.f10e53b4eb17cb6cc0c9377d6aa8023d.jpg'

# # PROVIDE PATH TO MODEL DIRECTORY
# PATH_TO_MODEL_DIR = './exported-models/my-model'

# # PROVIDE PATH TO LABEL MAP
# PATH_TO_LABELS = ANNOTATION_PATH + '/label_map.pbtxt'

# # PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
# MIN_CONF_THRESH = float(0.60)

# # LOAD THE MODEL

# import time
# from object_detection.utils import label_map_util
# from object_detection.utils import visualization_utils as viz_utils

# PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

# print('Loading model...', end='')
# start_time = time.time()

# # LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
# detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

# end_time = time.time()
# elapsed_time = end_time - start_time
# print('Done! Took {} seconds'.format(elapsed_time))

# # LOAD LABEL MAP DATA FOR PLOTTING

# category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
#                                                                     use_display_name=True)

# import numpy as np
# from PIL import Image
# import matplotlib.pyplot as plt
# import warnings
# warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

# def load_image_into_numpy_array(path):
#     """Load an image from file into a numpy array.
#     Puts image into numpy array to feed into tensorflow graph.
#     Note that by convention we put it into a numpy array with shape
#     (height, width, channels), where channels=3 for RGB.
#     Args:
#       path: the file path to the image
#     Returns:
#       uint8 numpy array with shape (img_height, img_width, 3)
#     """
#     return np.array(Image.open(path))

# print('Running inference for {}... '.format(IMAGE_PATHS), end='')

# image = cv2.imread(IMAGE_PATHS)
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image_expanded = np.expand_dims(image_rgb, axis=0)

# # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
# input_tensor = tf.convert_to_tensor(image)
# # The model expects a batch of images, so add an axis with `tf.newaxis`.
# input_tensor = input_tensor[tf.newaxis, ...]

# # input_tensor = np.expand_dims(image_np, 0)
# detections = detect_fn(input_tensor)

# # All outputs are batches tensors.
# # Convert to numpy arrays, and take index [0] to remove the batch dimension.
# # We're only interested in the first num_detections.
# num_detections = int(detections.pop('num_detections'))
# detections = {key: value[0, :num_detections].numpy()
#                for key, value in detections.items()}
# detections['num_detections'] = num_detections

# # detection_classes should be ints.
# detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

# image_with_detections = image.copy()

# # SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
# viz_utils.visualize_boxes_and_labels_on_image_array(
#       image_with_detections,
#       detections['detection_boxes'],
#       detections['detection_classes'],
#       detections['detection_scores'],
#       category_index,
#       use_normalized_coordinates=True,
#       max_boxes_to_draw=1,
#       min_score_thresh=0.3,
#       agnostic_mode=False)

# print('Done')
# # DISPLAYS OUTPUT IMAGE
# cv2.imshow('test', image_with_detections)
# # CLOSES WINDOW ONCE KEY IS PRESSED
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# ## Detect in Real Time

# %%
# import os
# from object_detection.utils import label_map_util
# from object_detection.utils import visualization_utils as viz_utils
# from object_detection.builders import model_builder

# %%
# CHECKPONT_PATH = MODEL_PATH + '/'

# #load pipeline config and build a detection model
# configs = config_util.get_configs_from_pipeline_file(CONFIG_PATH)
# detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# #Restore checkpoint
# ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
# ckpt.restore(os.path.join(CHECKPONT_PATH, 'ckpt-26')).expect_partial()

# @tf.function
# def detect_fn(image):
#     image, shapes = detection_model.preprocess(image)
#     prediction_dict = detection_model.predict(image, shapes)
#     detections = detection_model.postprocess(prediction_dict, shapes)
#     return detections

# %%
# import cv2
# import numpy as np

# %%
# category_index = label_map_util.create_category_index_from_labelmap(ANNOTATION_PATH+'/label_map.pbtxt', use_display_name=True)

# %%
# #Setup Capture
# cap = cv2.VideoCapture(0)
# width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
# while True:
#     ret, frame = cap.read()
#     image_np = np.array(frame)

#     input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
#     detections = detect_fn(input_tensor)

#     num_detections = int(detections.pop('num_detections'))
#     detections = {key: value[0, :num_detections].numpy()
#                   for key, value in detections.items()}
#     detections['num_detections'] = num_detections
    
#     # detection_classes should be ints.
#     detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

#     label_id_offset = 1
#     image_np_with_detections = image_np.copy()

#     viz_utils.visualize_boxes_and_labels_on_image_array(
#       image_np_with_detections,
#       detections['detection_boxes'],
#       detections['detection_classes']+label_id_offset,
#       detections['detection_scores'],
#       category_index,
#       use_normalized_coordinates=True,
#       max_boxes_to_draw=1,
#       min_score_thresh=0.3,
#       agnostic_mode=False)

#     cv2.imshow('object detection', cv2.resize(image_np_with_detections, (800, 600)))

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#       cap.release()
#       break

# %%
# !tensorboard --logdir D:/"Traffic SignBoard Recognition using Deep Learning"/"CenterNet Resnet50 V2 512x512"/models/centernet_resnet50_v2_512x512 --host localhost --port 6007
# Out:
# ^C

# %% [markdown]
# ## Evaluation Model:

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'} --checkpoint_dir={MODEL_PATH}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.02s).
# Accumulating evaluation results...
# DONE (t=1.26s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.247
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.175
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.237
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.190
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.502
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.830
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0313 11:55:49.363347 20220 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0313 11:55:49.363347 20220 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0313 11:55:49.363347 20220 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0313 11:55:49.363347 20220 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0313 11:55:49.363347 20220 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2024-03-13 11:55:49.371056: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 11:55:50.311364: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# I0313 11:55:51.392689 20220 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# I0313 11:55:51.393700 20220 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0313 11:55:51.393700 20220 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0313 11:55:51.393700 20220 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0313 11:55:51.397183 20220 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0313 11:55:51.427975 20220 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0313 11:55:54.674921 20220 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 11:55:55.732429 20220 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at ./models/centernet_resnet50_v2_512x512
# I0313 11:55:57.901284 20220 checkpoint_utils.py:136] Waiting for new checkpoint at ./models/centernet_resnet50_v2_512x512
# INFO:tensorflow:Found new checkpoint at ./models/centernet_resnet50_v2_512x512\ckpt-26
# I0313 11:55:57.908363 20220 checkpoint_utils.py:145] Found new checkpoint at ./models/centernet_resnet50_v2_512x512\ckpt-26
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2024-03-13 11:56:09.356581: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-13 11:56:12.052928: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.053428: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.156555: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.156923: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.217407: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.217829: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.432699: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.433174: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.494189: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 11:56:12.494655: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 11:56:14.871907 20220 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0313 11:56:14.883101 20220 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0313 11:56:15.016013 20220 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0313 11:56:26.310240 20220 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0313 11:56:36.595123 20220 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0313 11:56:44.728430 20220 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Finished eval step 400
# I0313 11:56:53.418363 20220 model_lib_v2.py:966] Finished eval step 400
# INFO:tensorflow:Finished eval step 500
# I0313 11:57:03.880922 20220 model_lib_v2.py:966] Finished eval step 500
# INFO:tensorflow:Finished eval step 600
# I0313 11:57:14.217284 20220 model_lib_v2.py:966] Finished eval step 600
# INFO:tensorflow:Performing evaluation on 665 images.
# I0313 11:57:20.831157 20220 coco_evaluation.py:293] Performing evaluation on 665 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0313 11:57:20.832144 20220 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.03s)
# I0313 11:57:20.864651 20220 coco_tools.py:138] DONE (t=0.03s)
# INFO:tensorflow:Eval metrics at step 25000
# I0313 11:57:25.276818 20220 model_lib_v2.py:1015] Eval metrics at step 25000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.246911
# I0313 11:57:25.286737 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.246911
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.311570
# I0313 11:57:25.289753 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.311570
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.288983
# I0313 11:57:25.291749 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.288983
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.175297
# I0313 11:57:25.293749 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.175297
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.237449
# I0313 11:57:25.295766 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.237449
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.259277
# I0313 11:57:25.296760 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.259277
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.783498
# I0313 11:57:25.298759 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.783498
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.812317
# I0313 11:57:25.300749 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.812317
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.813713
# I0313 11:57:25.302760 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.813713
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.190000
# I0313 11:57:25.304749 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.190000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.502381
# I0313 11:57:25.305761 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.502381
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.829920
# I0313 11:57:25.309495 20220 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.829920
# INFO:tensorflow:	+ Loss/object_center: 2.307031
# I0313 11:57:25.310516 20220 model_lib_v2.py:1018] 	+ Loss/object_center: 2.307031
# INFO:tensorflow:	+ Loss/box/scale: 0.856898
# I0313 11:57:25.312518 20220 model_lib_v2.py:1018] 	+ Loss/box/scale: 0.856898
# INFO:tensorflow:	+ Loss/box/offset: 0.473181
# I0313 11:57:25.313518 20220 model_lib_v2.py:1018] 	+ Loss/box/offset: 0.473181
# INFO:tensorflow:	+ Loss/total_loss: 3.637109
# I0313 11:57:25.314518 20220 model_lib_v2.py:1018] 	+ Loss/total_loss: 3.637109
# INFO:tensorflow:Exiting evaluation at step 25000
# I0313 11:57:25.384189 20220 model_lib_v2.py:1168] Exiting evaluation at step 25000
