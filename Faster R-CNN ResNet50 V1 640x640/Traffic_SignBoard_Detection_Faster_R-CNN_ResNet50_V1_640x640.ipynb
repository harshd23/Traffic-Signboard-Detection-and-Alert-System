# %% [markdown]
# # Traffic SignBoard Detection - Faster R-CNN ResNet50 V1 640x640:

# %% [markdown]
# ## 1. DOWNLOAD THE PRETRAINED MODELS FROM THE TENSOFLOW MODEL ZOO

# %%
import os

# DATA_DIR = os.path.join(os.getcwd(), 'data')
MODELS_DIR = os.path.join('pre-trained-model')
for dir in [MODELS_DIR]:
    if not os.path.exists(dir):
        os.mkdir(dir)

# %%
main_directory = 'models'
subfolder_name = 'faster_r-cnn_resnet50_v1_640x640'

main_directory_path = os.path.join(os.getcwd(), main_directory)
subfolder_path = os.path.join(main_directory_path, subfolder_name)

if not os.path.exists(subfolder_path):
    os.makedirs(subfolder_path)

# %%
import tarfile
import urllib.request
import os

# Download and extract model
MODEL_DATE = '20200711'
MODEL_NAME = 'faster_rcnn_resnet50_v1_640x640_coco17_tpu-8'
MODEL_TAR_FILENAME = MODEL_NAME + '.tar.gz'
MODELS_DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/'
MODEL_DOWNLOAD_LINK = MODELS_DOWNLOAD_BASE + MODEL_DATE + '/' + MODEL_TAR_FILENAME
PATH_TO_MODEL_TAR = os.path.join(MODELS_DIR, MODEL_TAR_FILENAME)
PATH_TO_CKPT = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'checkpoint/'))
PATH_TO_CFG = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'pipeline.config'))
if not os.path.exists(PATH_TO_CKPT):
    print('Downloading model. This may take a while... ', end='')
    urllib.request.urlretrieve(MODEL_DOWNLOAD_LINK, PATH_TO_MODEL_TAR)
    tar_file = tarfile.open(PATH_TO_MODEL_TAR)
    tar_file.extractall(MODELS_DIR)
    tar_file.close()
    os.remove(PATH_TO_MODEL_TAR)
    print('Done')

# %% [markdown]
# ## 2. SETUP PATHS:

# %%
WORKSPACE_PATH = '../training_helper_directory'
SCRIPT_PATH = WORKSPACE_PATH + '/scripts'
ANNOTATION_PATH = WORKSPACE_PATH + '/annotations'

IMAGE_PATH = '../Dataset/"PASCAL VOC Format Dataset"'

CUSTOM_MODEL_NAME = '/faster_r-cnn_resnet50_v1_640x640'
MODEL_PATH = './models' + CUSTOM_MODEL_NAME

PRETRAINED_PATH = './pre-trained-model/' + MODEL_NAME
CONFIG_PATH = MODEL_PATH + '/pipeline.config'

EXPORT_PATH = '../exported-models/my-model'

# %% [markdown]
# ## 3. CREATE TF RECORDS:

# %%
# Create train data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}

# Create test data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: ../training_helper_directory/annotations/train.record
# Successfully created the TFRecord file: ../training_helper_directory/annotations/test.record

# %% [markdown]
# ## 4. COPY MODEL CONFIG FILE TO TRANING FOLDER:

# %%
SOURCE_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\Faster R-CNN ResNet50 V1 640x640\pre-trained-model\\faster_rcnn_resnet50_v1_640x640_coco17_tpu-8\pipeline.config"
DESTINATION_PATH = "D:\Traffic SignBoard Recognition using Deep Learning\Faster R-CNN ResNet50 V1 640x640\models\\faster_r-cnn_resnet50_v1_640x640"

# %%
# !copy "{SOURCE_PATH}" "{DESTINATION_PATH}"
# Out:
#         1 file(s) copied.

# %% [markdown]
# ## 5. UPDATING CONFIG FOR TRANSFER LEARNING:

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': faster_rcnn {
#    num_classes: 90
#    image_resizer {
#      keep_aspect_ratio_resizer {
#        min_dimension: 640
#        max_dimension: 640
#        pad_to_max_dimension: true
#      }
#    }
#    feature_extractor {
#      type: "faster_rcnn_resnet50_keras"
#      batch_norm_trainable: true
#    }
#    first_stage_anchor_generator {
#      grid_anchor_generator {
#        height_stride: 16
#        width_stride: 16
#        scales: 0.25
#        scales: 0.5
#        scales: 1.0
#        scales: 2.0
#        aspect_ratios: 0.5
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#      }
#    }
#    first_stage_box_predictor_conv_hyperparams {
#      op: CONV
#      regularizer {
#        l2_regularizer {
#          weight: 0.0
#        }
#      }
#      initializer {
#        truncated_normal_initializer {
#          stddev: 0.009999999776482582
#        }
#      }
#    }
#    first_stage_nms_score_threshold: 0.0
#    first_stage_nms_iou_threshold: 0.699999988079071
#    first_stage_max_proposals: 300
#    first_stage_localization_loss_weight: 2.0
#    first_stage_objectness_loss_weight: 1.0
#    initial_crop_size: 14
#    maxpool_kernel_size: 2
#    maxpool_stride: 2
#    second_stage_box_predictor {
#      mask_rcnn_box_predictor {
#        fc_hyperparams {
#          op: FC
#          regularizer {
#            l2_regularizer {
#              weight: 0.0
#            }
#          }
#          initializer {
#            variance_scaling_initializer {
#              factor: 1.0
#              uniform: true
#              mode: FAN_AVG
#            }
#          }
#        }
#        use_dropout: false
#        dropout_keep_probability: 1.0
#        share_box_across_classes: true
#      }
#    }
#    second_stage_post_processing {
#      batch_non_max_suppression {
#        score_threshold: 0.0
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 300
#      }
#      score_converter: SOFTMAX
#    }
#    second_stage_localization_loss_weight: 2.0
#    second_stage_classification_loss_weight: 1.0
#    use_matmul_crop_and_resize: true
#    clip_anchors_to_image: true
#    use_matmul_gather_in_matcher: true
#    use_static_balanced_label_sampler: true
#    use_static_shapes: true
#  },
#  'train_config': batch_size: 64
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.03999999910593033
#          total_steps: 25000
#          warmup_learning_rate: 0.013333000242710114
#          warmup_steps: 2000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 25000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  use_bfloat16: true
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/train2017-?????-of-00256.tfrecord"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false
#  batch_size: 1,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.faster_rcnn.num_classes = 56 

pipeline_config.train_config.batch_size = 1
pipeline_config.train_config.num_steps = 25000
pipeline_config.train_config.use_bfloat16 = False

pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_PATH + '/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection" 

pipeline_config.train_input_reader.label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH+ '/train.record'] 

pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:
    f.write(config_text)

# %% [markdown]
# ## 6. TRAIN THE MODEL:

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.getcwd()
# Out:
# 'd:\\Traffic SignBoard Recognition using Deep Learning\\Faster R-CNN ResNet50 V1 640x640'

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'}
# Out:
# 2024-03-08 00:51:28.064594: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-08 00:51:28.609286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0308 00:51:28.681802 25596 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0308 00:51:28.685800 25596 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0308 00:51:28.685800 25596 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0308 00:51:28.706799 25596 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# I0308 00:51:28.720800 25596 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# I0308 00:51:28.721800 25596 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0308 00:51:28.721800 25596 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0308 00:51:28.721800 25596 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0308 00:51:28.723800 25596 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0308 00:51:28.743805 25596 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0308 00:51:34.122965 25596 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0308 00:51:36.318398 25596 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0308 00:51:42.863794 21340 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0308 00:51:48.287631 21340 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0308 00:51:51.773695 21340 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2024-03-08 00:51:59.026627: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-08 00:52:00.308637: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.309057: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.347961: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.348365: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.517150: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.517583: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.711815: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.712202: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.999032: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-08 00:52:00.999425: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.702578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.703578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.704578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.705578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.706578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.707578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.708578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.709578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.710578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0308 00:52:03.710578 25596 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0308 00:52:04.335552 24808 deprecation.py:554] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.658s
# I0308 00:53:09.892111 25596 model_lib_v2.py:705] Step 100 per-step time 0.658s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.2670258,
#  'Loss/BoxClassifierLoss/localization_loss': 0.40992245,
#  'Loss/RPNLoss/localization_loss': 0.01949237,
#  'Loss/RPNLoss/objectness_loss': 0.09788576,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7943264,
#  'learning_rate': 0.014666351}
# I0308 00:53:09.892111 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.2670258,
#  'Loss/BoxClassifierLoss/localization_loss': 0.40992245,
#  'Loss/RPNLoss/localization_loss': 0.01949237,
#  'Loss/RPNLoss/objectness_loss': 0.09788576,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7943264,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.377s
# I0308 00:53:47.636406 25596 model_lib_v2.py:705] Step 200 per-step time 0.377s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.0791123,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29048255,
#  'Loss/RPNLoss/localization_loss': 0.32435215,
#  'Loss/RPNLoss/objectness_loss': 0.08082406,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.774771,
#  'learning_rate': 0.0159997}
# I0308 00:53:47.636406 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.0791123,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29048255,
#  'Loss/RPNLoss/localization_loss': 0.32435215,
#  'Loss/RPNLoss/objectness_loss': 0.08082406,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.774771,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.378s
# I0308 00:54:25.472556 25596 model_lib_v2.py:705] Step 300 per-step time 0.378s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.98524046,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5361568,
#  'Loss/RPNLoss/localization_loss': 1.3915159,
#  'Loss/RPNLoss/objectness_loss': 0.2503273,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.1632404,
#  'learning_rate': 0.01733305}
# I0308 00:54:25.472556 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.98524046,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5361568,
#  'Loss/RPNLoss/localization_loss': 1.3915159,
#  'Loss/RPNLoss/objectness_loss': 0.2503273,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 3.1632404,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.384s
# I0308 00:55:03.908226 25596 model_lib_v2.py:705] Step 400 per-step time 0.384s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.1921666,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3825615,
#  'Loss/RPNLoss/localization_loss': 0.47951904,
#  'Loss/RPNLoss/objectness_loss': 0.08818787,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.142435,
#  'learning_rate': 0.0186664}
# I0308 00:55:03.908226 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.1921666,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3825615,
#  'Loss/RPNLoss/localization_loss': 0.47951904,
#  'Loss/RPNLoss/objectness_loss': 0.08818787,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.142435,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.377s
# I0308 00:55:41.614080 25596 model_lib_v2.py:705] Step 500 per-step time 0.377s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.87857354,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5462238,
#  'Loss/RPNLoss/localization_loss': 0.93377876,
#  'Loss/RPNLoss/objectness_loss': 0.24786825,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.6064444,
#  'learning_rate': 0.01999975}
# I0308 00:55:41.614080 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.87857354,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5462238,
#  'Loss/RPNLoss/localization_loss': 0.93377876,
#  'Loss/RPNLoss/objectness_loss': 0.24786825,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.6064444,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.378s
# I0308 00:56:19.459222 25596 model_lib_v2.py:705] Step 600 per-step time 0.378s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.98092866,
#  'Loss/BoxClassifierLoss/localization_loss': 0.16497678,
#  'Loss/RPNLoss/localization_loss': 0.14519915,
#  'Loss/RPNLoss/objectness_loss': 0.16613543,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.45724,
#  'learning_rate': 0.0213331}
# I0308 00:56:19.459222 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.98092866,
#  'Loss/BoxClassifierLoss/localization_loss': 0.16497678,
#  'Loss/RPNLoss/localization_loss': 0.14519915,
#  'Loss/RPNLoss/objectness_loss': 0.16613543,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.45724,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.381s
# I0308 00:56:57.584336 25596 model_lib_v2.py:705] Step 700 per-step time 0.381s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.9273458,
#  'Loss/BoxClassifierLoss/localization_loss': 0.20399934,
#  'Loss/RPNLoss/localization_loss': 0.3396294,
#  'Loss/RPNLoss/objectness_loss': 0.083646595,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5546212,
#  'learning_rate': 0.02266645}
# I0308 00:56:57.584336 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.9273458,
#  'Loss/BoxClassifierLoss/localization_loss': 0.20399934,
#  'Loss/RPNLoss/localization_loss': 0.3396294,
#  'Loss/RPNLoss/objectness_loss': 0.083646595,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5546212,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.381s
# I0308 00:57:35.689131 25596 model_lib_v2.py:705] Step 800 per-step time 0.381s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.8151372,
#  'Loss/BoxClassifierLoss/localization_loss': 0.33004248,
#  'Loss/RPNLoss/localization_loss': 0.18313724,
#  'Loss/RPNLoss/objectness_loss': 0.05514757,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.3834646,
#  'learning_rate': 0.023999799}
# I0308 00:57:35.689131 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.8151372,
#  'Loss/BoxClassifierLoss/localization_loss': 0.33004248,
#  'Loss/RPNLoss/localization_loss': 0.18313724,
#  'Loss/RPNLoss/objectness_loss': 0.05514757,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.3834646,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.389s
# I0308 00:58:14.622376 25596 model_lib_v2.py:705] Step 900 per-step time 0.389s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.81102777,
#  'Loss/BoxClassifierLoss/localization_loss': 0.28337678,
#  'Loss/RPNLoss/localization_loss': 0.0036931117,
#  'Loss/RPNLoss/objectness_loss': 0.13479298,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.2328906,
#  'learning_rate': 0.025333151}
# I0308 00:58:14.629314 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.81102777,
#  'Loss/BoxClassifierLoss/localization_loss': 0.28337678,
#  'Loss/RPNLoss/localization_loss': 0.0036931117,
#  'Loss/RPNLoss/objectness_loss': 0.13479298,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.2328906,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.392s
# I0308 00:58:53.813061 25596 model_lib_v2.py:705] Step 1000 per-step time 0.392s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.6424811,
#  'Loss/BoxClassifierLoss/localization_loss': 0.13608867,
#  'Loss/RPNLoss/localization_loss': 0.36001897,
#  'Loss/RPNLoss/objectness_loss': 0.071346276,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.209935,
#  'learning_rate': 0.0266665}
# I0308 00:58:53.813061 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.6424811,
#  'Loss/BoxClassifierLoss/localization_loss': 0.13608867,
#  'Loss/RPNLoss/localization_loss': 0.36001897,
#  'Loss/RPNLoss/objectness_loss': 0.071346276,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.209935,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 0.409s
# I0308 00:59:34.728765 25596 model_lib_v2.py:705] Step 1100 per-step time 0.409s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.0304477,
#  'Loss/BoxClassifierLoss/localization_loss': 0.27748188,
#  'Loss/RPNLoss/localization_loss': 0.9171269,
#  'Loss/RPNLoss/objectness_loss': 0.17716464,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4022212,
#  'learning_rate': 0.02799985}
# I0308 00:59:34.728765 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.0304477,
#  'Loss/BoxClassifierLoss/localization_loss': 0.27748188,
#  'Loss/RPNLoss/localization_loss': 0.9171269,
#  'Loss/RPNLoss/objectness_loss': 0.17716464,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4022212,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 0.401s
# I0308 01:00:14.798835 25596 model_lib_v2.py:705] Step 1200 per-step time 0.401s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.7852981,
#  'Loss/BoxClassifierLoss/localization_loss': 0.1387052,
#  'Loss/RPNLoss/localization_loss': 0.45189762,
#  'Loss/RPNLoss/objectness_loss': 0.18042277,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5563238,
#  'learning_rate': 0.0293332}
# I0308 01:00:14.798835 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.7852981,
#  'Loss/BoxClassifierLoss/localization_loss': 0.1387052,
#  'Loss/RPNLoss/localization_loss': 0.45189762,
#  'Loss/RPNLoss/objectness_loss': 0.18042277,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5563238,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 0.418s
# I0308 01:00:56.593858 25596 model_lib_v2.py:705] Step 1300 per-step time 0.418s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.1905332,
#  'Loss/BoxClassifierLoss/localization_loss': 0.53562033,
#  'Loss/RPNLoss/localization_loss': 0.72017455,
#  'Loss/RPNLoss/objectness_loss': 0.16669686,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.613025,
#  'learning_rate': 0.03066655}
# I0308 01:00:56.593858 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.1905332,
#  'Loss/BoxClassifierLoss/localization_loss': 0.53562033,
#  'Loss/RPNLoss/localization_loss': 0.72017455,
#  'Loss/RPNLoss/objectness_loss': 0.16669686,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.613025,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 0.408s
# I0308 01:01:37.425162 25596 model_lib_v2.py:705] Step 1400 per-step time 0.408s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.676638,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15978181,
#  'Loss/RPNLoss/localization_loss': 0.2641233,
#  'Loss/RPNLoss/objectness_loss': 0.06290598,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.163449,
#  'learning_rate': 0.0319999}
# I0308 01:01:37.425479 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.676638,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15978181,
#  'Loss/RPNLoss/localization_loss': 0.2641233,
#  'Loss/RPNLoss/objectness_loss': 0.06290598,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.163449,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 0.405s
# I0308 01:02:17.961316 25596 model_lib_v2.py:705] Step 1500 per-step time 0.405s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.8651256,
#  'Loss/BoxClassifierLoss/localization_loss': 0.28267038,
#  'Loss/RPNLoss/localization_loss': 0.013863302,
#  'Loss/RPNLoss/objectness_loss': 0.032877523,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.1945368,
#  'learning_rate': 0.03333325}
# I0308 01:02:17.961316 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.8651256,
#  'Loss/BoxClassifierLoss/localization_loss': 0.28267038,
#  'Loss/RPNLoss/localization_loss': 0.013863302,
#  'Loss/RPNLoss/objectness_loss': 0.032877523,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.1945368,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 0.419s
# I0308 01:02:59.879768 25596 model_lib_v2.py:705] Step 1600 per-step time 0.419s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.59805113,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3362223,
#  'Loss/RPNLoss/localization_loss': 0.011002419,
#  'Loss/RPNLoss/objectness_loss': 0.037200578,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.9824764,
#  'learning_rate': 0.034666598}
# I0308 01:02:59.880768 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.59805113,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3362223,
#  'Loss/RPNLoss/localization_loss': 0.011002419,
#  'Loss/RPNLoss/objectness_loss': 0.037200578,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.9824764,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 0.422s
# I0308 01:03:42.047349 25596 model_lib_v2.py:705] Step 1700 per-step time 0.422s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.034483,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2732338,
#  'Loss/RPNLoss/localization_loss': 0.7479931,
#  'Loss/RPNLoss/objectness_loss': 0.13435449,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1900644,
#  'learning_rate': 0.03599995}
# I0308 01:03:42.047349 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.034483,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2732338,
#  'Loss/RPNLoss/localization_loss': 0.7479931,
#  'Loss/RPNLoss/objectness_loss': 0.13435449,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1900644,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 0.428s
# I0308 01:04:24.820379 25596 model_lib_v2.py:705] Step 1800 per-step time 0.428s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.2519698,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3862685,
#  'Loss/RPNLoss/localization_loss': 0.57405555,
#  'Loss/RPNLoss/objectness_loss': 0.2298539,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4421477,
#  'learning_rate': 0.037333302}
# I0308 01:04:24.820379 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.2519698,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3862685,
#  'Loss/RPNLoss/localization_loss': 0.57405555,
#  'Loss/RPNLoss/objectness_loss': 0.2298539,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4421477,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 0.427s
# I0308 01:05:07.488939 25596 model_lib_v2.py:705] Step 1900 per-step time 0.427s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.3745219,
#  'Loss/BoxClassifierLoss/localization_loss': 0.4925567,
#  'Loss/RPNLoss/localization_loss': 0.013122583,
#  'Loss/RPNLoss/objectness_loss': 0.057622526,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.9378237,
#  'learning_rate': 0.03866665}
# I0308 01:05:07.488939 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.3745219,
#  'Loss/BoxClassifierLoss/localization_loss': 0.4925567,
#  'Loss/RPNLoss/localization_loss': 0.013122583,
#  'Loss/RPNLoss/objectness_loss': 0.057622526,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.9378237,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 0.427s
# I0308 01:05:50.222682 25596 model_lib_v2.py:705] Step 2000 per-step time 0.427s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.4862635,
#  'Loss/BoxClassifierLoss/localization_loss': 0.22155452,
#  'Loss/RPNLoss/localization_loss': 0.39139932,
#  'Loss/RPNLoss/objectness_loss': 0.0741228,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.17334,
#  'learning_rate': 0.04}
# I0308 01:05:50.222682 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.4862635,
#  'Loss/BoxClassifierLoss/localization_loss': 0.22155452,
#  'Loss/RPNLoss/localization_loss': 0.39139932,
#  'Loss/RPNLoss/objectness_loss': 0.0741228,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.17334,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 0.440s
# I0308 01:06:34.265606 25596 model_lib_v2.py:705] Step 2100 per-step time 0.440s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.99876934,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15952006,
#  'Loss/RPNLoss/localization_loss': 0.35927117,
#  'Loss/RPNLoss/objectness_loss': 0.087671906,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6052325,
#  'learning_rate': 0.039998136}
# I0308 01:06:34.266582 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.99876934,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15952006,
#  'Loss/RPNLoss/localization_loss': 0.35927117,
#  'Loss/RPNLoss/objectness_loss': 0.087671906,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6052325,
#  'learning_rate': 0.039998136}
# INFO:tensorflow:Step 2200 per-step time 0.420s
# I0308 01:07:16.236461 25596 model_lib_v2.py:705] Step 2200 per-step time 0.420s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.9536347,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15489626,
#  'Loss/RPNLoss/localization_loss': 0.7769569,
#  'Loss/RPNLoss/objectness_loss': 0.2523728,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1378608,
#  'learning_rate': 0.039992537}
# I0308 01:07:16.236461 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.9536347,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15489626,
#  'Loss/RPNLoss/localization_loss': 0.7769569,
#  'Loss/RPNLoss/objectness_loss': 0.2523728,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.1378608,
#  'learning_rate': 0.039992537}
# INFO:tensorflow:Step 2300 per-step time 0.423s
# I0308 01:07:58.524167 25596 model_lib_v2.py:705] Step 2300 per-step time 0.423s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.5891566,
#  'Loss/BoxClassifierLoss/localization_loss': 0.11620113,
#  'Loss/RPNLoss/localization_loss': 0.28141913,
#  'Loss/RPNLoss/objectness_loss': 0.8044455,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7912223,
#  'learning_rate': 0.03998321}
# I0308 01:07:58.524167 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.5891566,
#  'Loss/BoxClassifierLoss/localization_loss': 0.11620113,
#  'Loss/RPNLoss/localization_loss': 0.28141913,
#  'Loss/RPNLoss/objectness_loss': 0.8044455,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7912223,
#  'learning_rate': 0.03998321}
# INFO:tensorflow:Step 2400 per-step time 0.423s
# I0308 01:08:40.837388 25596 model_lib_v2.py:705] Step 2400 per-step time 0.423s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.1205641,
#  'Loss/BoxClassifierLoss/localization_loss': 0.14435865,
#  'Loss/RPNLoss/localization_loss': 0.29252818,
#  'Loss/RPNLoss/objectness_loss': 0.06833219,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6257832,
#  'learning_rate': 0.039970152}
# I0308 01:08:40.837388 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.1205641,
#  'Loss/BoxClassifierLoss/localization_loss': 0.14435865,
#  'Loss/RPNLoss/localization_loss': 0.29252818,
#  'Loss/RPNLoss/objectness_loss': 0.06833219,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6257832,
#  'learning_rate': 0.039970152}
# INFO:tensorflow:Step 2500 per-step time 0.423s
# I0308 01:09:23.181791 25596 model_lib_v2.py:705] Step 2500 per-step time 0.423s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.0533097,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5090561,
#  'Loss/RPNLoss/localization_loss': 0.012053682,
#  'Loss/RPNLoss/objectness_loss': 0.03729918,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6117187,
#  'learning_rate': 0.039953373}
# I0308 01:09:23.182790 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.0533097,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5090561,
#  'Loss/RPNLoss/localization_loss': 0.012053682,
#  'Loss/RPNLoss/objectness_loss': 0.03729918,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6117187,
#  'learning_rate': 0.039953373}
# INFO:tensorflow:Step 2600 per-step time 0.424s
# I0308 01:10:05.587329 25596 model_lib_v2.py:705] Step 2600 per-step time 0.424s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.0358057,
#  'Loss/BoxClassifierLoss/localization_loss': 0.14161807,
#  'Loss/RPNLoss/localization_loss': 0.36064532,
#  'Loss/RPNLoss/objectness_loss': 0.08836103,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6264302,
#  'learning_rate': 0.03993287}
# I0308 01:10:05.587329 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.0358057,
#  'Loss/BoxClassifierLoss/localization_loss': 0.14161807,
#  'Loss/RPNLoss/localization_loss': 0.36064532,
#  'Loss/RPNLoss/objectness_loss': 0.08836103,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6264302,
#  'learning_rate': 0.03993287}
# INFO:tensorflow:Step 2700 per-step time 0.425s
# I0308 01:10:48.062536 25596 model_lib_v2.py:705] Step 2700 per-step time 0.425s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.9698649,
#  'Loss/BoxClassifierLoss/localization_loss': 0.65346056,
#  'Loss/RPNLoss/localization_loss': 0.09926735,
#  'Loss/RPNLoss/objectness_loss': 0.102181725,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.8247745,
#  'learning_rate': 0.039908648}
# I0308 01:10:48.062536 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.9698649,
#  'Loss/BoxClassifierLoss/localization_loss': 0.65346056,
#  'Loss/RPNLoss/localization_loss': 0.09926735,
#  'Loss/RPNLoss/objectness_loss': 0.102181725,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.8247745,
#  'learning_rate': 0.039908648}
# INFO:tensorflow:Step 2800 per-step time 0.420s
# I0308 01:11:30.059588 25596 model_lib_v2.py:705] Step 2800 per-step time 0.420s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.091114156,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.027187336,
#  'Loss/RPNLoss/objectness_loss': 0.23420887,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.35251036,
#  'learning_rate': 0.039880715}
# I0308 01:11:30.059588 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.091114156,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.027187336,
#  'Loss/RPNLoss/objectness_loss': 0.23420887,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.35251036,
#  'learning_rate': 0.039880715}
# INFO:tensorflow:Step 2900 per-step time 0.422s
# I0308 01:12:12.263059 25596 model_lib_v2.py:705] Step 2900 per-step time 0.422s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.18296932,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5696423,
#  'Loss/RPNLoss/localization_loss': 0.014168732,
#  'Loss/RPNLoss/objectness_loss': 0.02239136,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.78917176,
#  'learning_rate': 0.039849065}
# I0308 01:12:12.263059 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.18296932,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5696423,
#  'Loss/RPNLoss/localization_loss': 0.014168732,
#  'Loss/RPNLoss/objectness_loss': 0.02239136,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.78917176,
#  'learning_rate': 0.039849065}
# INFO:tensorflow:Step 3000 per-step time 0.421s
# I0308 01:12:54.384375 25596 model_lib_v2.py:705] Step 3000 per-step time 0.421s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.97989076,
#  'Loss/BoxClassifierLoss/localization_loss': 0.20174761,
#  'Loss/RPNLoss/localization_loss': 0.36142412,
#  'Loss/RPNLoss/objectness_loss': 0.07207723,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6151397,
#  'learning_rate': 0.03981372}
# I0308 01:12:54.385379 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.97989076,
#  'Loss/BoxClassifierLoss/localization_loss': 0.20174761,
#  'Loss/RPNLoss/localization_loss': 0.36142412,
#  'Loss/RPNLoss/objectness_loss': 0.07207723,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.6151397,
#  'learning_rate': 0.03981372}
# INFO:tensorflow:Step 3100 per-step time 0.434s
# I0308 01:13:37.834132 25596 model_lib_v2.py:705] Step 3100 per-step time 0.434s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.97918147,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29557824,
#  'Loss/RPNLoss/localization_loss': 0.3730343,
#  'Loss/RPNLoss/objectness_loss': 0.07419181,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7219858,
#  'learning_rate': 0.03977467}
# I0308 01:13:37.834132 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.97918147,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29557824,
#  'Loss/RPNLoss/localization_loss': 0.3730343,
#  'Loss/RPNLoss/objectness_loss': 0.07419181,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7219858,
#  'learning_rate': 0.03977467}
# INFO:tensorflow:Step 3200 per-step time 0.426s
# I0308 01:14:20.442281 25596 model_lib_v2.py:705] Step 3200 per-step time 0.426s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.6758834,
#  'Loss/BoxClassifierLoss/localization_loss': 0.20328338,
#  'Loss/RPNLoss/localization_loss': 0.012121637,
#  'Loss/RPNLoss/objectness_loss': 0.0478424,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.93913084,
#  'learning_rate': 0.03973194}
# I0308 01:14:20.442281 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.6758834,
#  'Loss/BoxClassifierLoss/localization_loss': 0.20328338,
#  'Loss/RPNLoss/localization_loss': 0.012121637,
#  'Loss/RPNLoss/objectness_loss': 0.0478424,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.93913084,
#  'learning_rate': 0.03973194}
# INFO:tensorflow:Step 3300 per-step time 0.421s
# I0308 01:15:02.586570 25596 model_lib_v2.py:705] Step 3300 per-step time 0.421s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.9508733,
#  'Loss/BoxClassifierLoss/localization_loss': 0.21237658,
#  'Loss/RPNLoss/localization_loss': 0.32009846,
#  'Loss/RPNLoss/objectness_loss': 0.05961048,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5429589,
#  'learning_rate': 0.03968552}
# I0308 01:15:02.586570 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.9508733,
#  'Loss/BoxClassifierLoss/localization_loss': 0.21237658,
#  'Loss/RPNLoss/localization_loss': 0.32009846,
#  'Loss/RPNLoss/objectness_loss': 0.05961048,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5429589,
#  'learning_rate': 0.03968552}
# INFO:tensorflow:Step 3400 per-step time 0.418s
# I0308 01:15:44.369965 25596 model_lib_v2.py:705] Step 3400 per-step time 0.418s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.6355899,
#  'Loss/BoxClassifierLoss/localization_loss': 0.40935403,
#  'Loss/RPNLoss/localization_loss': 0.010483231,
#  'Loss/RPNLoss/objectness_loss': 0.039281294,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0947084,
#  'learning_rate': 0.039635435}
# I0308 01:15:44.369965 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.6355899,
#  'Loss/BoxClassifierLoss/localization_loss': 0.40935403,
#  'Loss/RPNLoss/localization_loss': 0.010483231,
#  'Loss/RPNLoss/objectness_loss': 0.039281294,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0947084,
#  'learning_rate': 0.039635435}
# INFO:tensorflow:Step 3500 per-step time 0.421s
# I0308 01:16:26.442046 25596 model_lib_v2.py:705] Step 3500 per-step time 0.421s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.1019837,
#  'Loss/BoxClassifierLoss/localization_loss': 0.30585998,
#  'Loss/RPNLoss/localization_loss': 0.3654592,
#  'Loss/RPNLoss/objectness_loss': 0.06966809,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.842971,
#  'learning_rate': 0.03958168}
# I0308 01:16:26.442046 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.1019837,
#  'Loss/BoxClassifierLoss/localization_loss': 0.30585998,
#  'Loss/RPNLoss/localization_loss': 0.3654592,
#  'Loss/RPNLoss/objectness_loss': 0.06966809,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.842971,
#  'learning_rate': 0.03958168}
# INFO:tensorflow:Step 3600 per-step time 0.418s
# I0308 01:17:08.242584 25596 model_lib_v2.py:705] Step 3600 per-step time 0.418s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.73730856,
#  'Loss/BoxClassifierLoss/localization_loss': 0.24698877,
#  'Loss/RPNLoss/localization_loss': 0.45120865,
#  'Loss/RPNLoss/objectness_loss': 0.10606607,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5415721,
#  'learning_rate': 0.039524276}
# I0308 01:17:08.242584 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.73730856,
#  'Loss/BoxClassifierLoss/localization_loss': 0.24698877,
#  'Loss/RPNLoss/localization_loss': 0.45120865,
#  'Loss/RPNLoss/objectness_loss': 0.10606607,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.5415721,
#  'learning_rate': 0.039524276}
# INFO:tensorflow:Step 3700 per-step time 0.423s
# I0308 01:17:50.588082 25596 model_lib_v2.py:705] Step 3700 per-step time 0.423s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 1.6043856,
#  'Loss/BoxClassifierLoss/localization_loss': 0.45052788,
#  'Loss/RPNLoss/localization_loss': 0.06164054,
#  'Loss/RPNLoss/objectness_loss': 0.2536163,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.3701704,
#  'learning_rate': 0.03946323}
# I0308 01:17:50.588082 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 1.6043856,
#  'Loss/BoxClassifierLoss/localization_loss': 0.45052788,
#  'Loss/RPNLoss/localization_loss': 0.06164054,
#  'Loss/RPNLoss/objectness_loss': 0.2536163,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.3701704,
#  'learning_rate': 0.03946323}
# INFO:tensorflow:Step 3800 per-step time 0.419s
# I0308 01:18:32.428984 25596 model_lib_v2.py:705] Step 3800 per-step time 0.419s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.64536196,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3913286,
#  'Loss/RPNLoss/localization_loss': 0.014486643,
#  'Loss/RPNLoss/objectness_loss': 0.012709582,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0638868,
#  'learning_rate': 0.039398547}
# I0308 01:18:32.428984 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.64536196,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3913286,
#  'Loss/RPNLoss/localization_loss': 0.014486643,
#  'Loss/RPNLoss/objectness_loss': 0.012709582,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0638868,
#  'learning_rate': 0.039398547}
# INFO:tensorflow:Step 3900 per-step time 0.413s
# I0308 01:19:13.754142 25596 model_lib_v2.py:705] Step 3900 per-step time 0.413s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.21306266,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06554967,
#  'Loss/RPNLoss/localization_loss': 0.37212795,
#  'Loss/RPNLoss/objectness_loss': 0.047689337,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.69842964,
#  'learning_rate': 0.039330248}
# I0308 01:19:13.754142 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.21306266,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06554967,
#  'Loss/RPNLoss/localization_loss': 0.37212795,
#  'Loss/RPNLoss/objectness_loss': 0.047689337,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.69842964,
#  'learning_rate': 0.039330248}
# INFO:tensorflow:Step 4000 per-step time 0.413s
# I0308 01:19:55.017313 25596 model_lib_v2.py:705] Step 4000 per-step time 0.413s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.060312495,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0126149515,
#  'Loss/RPNLoss/objectness_loss': 0.28723818,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.36016566,
#  'learning_rate': 0.039258346}
# I0308 01:19:55.017313 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.060312495,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0126149515,
#  'Loss/RPNLoss/objectness_loss': 0.28723818,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.36016566,
#  'learning_rate': 0.039258346}
# INFO:tensorflow:Step 4100 per-step time 0.422s
# I0308 01:20:37.230534 25596 model_lib_v2.py:705] Step 4100 per-step time 0.422s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.020962596,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.012413258,
#  'Loss/RPNLoss/objectness_loss': 0.20526177,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.23863763,
#  'learning_rate': 0.03918285}
# I0308 01:20:37.230534 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.020962596,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.012413258,
#  'Loss/RPNLoss/objectness_loss': 0.20526177,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.23863763,
#  'learning_rate': 0.03918285}
# INFO:tensorflow:Step 4200 per-step time 0.416s
# I0308 01:21:18.797725 25596 model_lib_v2.py:705] Step 4200 per-step time 0.416s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.008142163,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.024056088,
#  'Loss/RPNLoss/objectness_loss': 0.18546222,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.21766047,
#  'learning_rate': 0.03910377}
# I0308 01:21:18.797725 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.008142163,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.024056088,
#  'Loss/RPNLoss/objectness_loss': 0.18546222,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.21766047,
#  'learning_rate': 0.03910377}
# INFO:tensorflow:Step 4300 per-step time 0.426s
# ...
#  'Loss/BoxClassifierLoss/localization_loss': 0.01609651,
#  'Loss/RPNLoss/localization_loss': 0.010032337,
#  'Loss/RPNLoss/objectness_loss': 0.033330306,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.17685574,
#  'learning_rate': 0.0006697476}
# I0308 03:31:55.088716 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.117396586,
#  'Loss/BoxClassifierLoss/localization_loss': 0.01609651,
#  'Loss/RPNLoss/localization_loss': 0.010032337,
#  'Loss/RPNLoss/objectness_loss': 0.033330306,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.17685574,
#  'learning_rate': 0.0006697476}
# INFO:tensorflow:Step 23200 per-step time 0.398s
# I0308 03:32:34.925174 25596 model_lib_v2.py:705] Step 23200 per-step time 0.398s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.012017164,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.026742663,
#  'Loss/RPNLoss/objectness_loss': 0.038938116,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.07769795,
#  'learning_rate': 0.0006014514}
# I0308 03:32:34.925174 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.012017164,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.026742663,
#  'Loss/RPNLoss/objectness_loss': 0.038938116,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.07769795,
#  'learning_rate': 0.0006014514}
# INFO:tensorflow:Step 23300 per-step time 0.395s
# I0308 03:33:14.439337 25596 model_lib_v2.py:705] Step 23300 per-step time 0.395s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.5151903,
#  'Loss/BoxClassifierLoss/localization_loss': 0.054729626,
#  'Loss/RPNLoss/localization_loss': 0.074191414,
#  'Loss/RPNLoss/objectness_loss': 0.04290142,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6870128,
#  'learning_rate': 0.000536772}
# I0308 03:33:14.439337 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.5151903,
#  'Loss/BoxClassifierLoss/localization_loss': 0.054729626,
#  'Loss/RPNLoss/localization_loss': 0.074191414,
#  'Loss/RPNLoss/objectness_loss': 0.04290142,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6870128,
#  'learning_rate': 0.000536772}
# INFO:tensorflow:Step 23400 per-step time 0.398s
# I0308 03:33:54.209403 25596 model_lib_v2.py:705] Step 23400 per-step time 0.398s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0695649,
#  'Loss/BoxClassifierLoss/localization_loss': 0.026581826,
#  'Loss/RPNLoss/localization_loss': 0.058191773,
#  'Loss/RPNLoss/objectness_loss': 0.04764021,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.20197871,
#  'learning_rate': 0.00047572254}
# I0308 03:33:54.209403 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.0695649,
#  'Loss/BoxClassifierLoss/localization_loss': 0.026581826,
#  'Loss/RPNLoss/localization_loss': 0.058191773,
#  'Loss/RPNLoss/objectness_loss': 0.04764021,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.20197871,
#  'learning_rate': 0.00047572254}
# INFO:tensorflow:Step 23500 per-step time 0.402s
# I0308 03:34:34.375388 25596 model_lib_v2.py:705] Step 23500 per-step time 0.402s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.12794703,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07303579,
#  'Loss/RPNLoss/localization_loss': 0.009878219,
#  'Loss/RPNLoss/objectness_loss': 0.03733246,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2481935,
#  'learning_rate': 0.0004183185}
# I0308 03:34:34.375388 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.12794703,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07303579,
#  'Loss/RPNLoss/localization_loss': 0.009878219,
#  'Loss/RPNLoss/objectness_loss': 0.03733246,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2481935,
#  'learning_rate': 0.0004183185}
# INFO:tensorflow:Step 23600 per-step time 0.398s
# I0308 03:35:14.173912 25596 model_lib_v2.py:705] Step 23600 per-step time 0.398s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.59702605,
#  'Loss/BoxClassifierLoss/localization_loss': 0.042983048,
#  'Loss/RPNLoss/localization_loss': 0.9928224,
#  'Loss/RPNLoss/objectness_loss': 0.30297866,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.9358101,
#  'learning_rate': 0.00036456465}
# I0308 03:35:14.174933 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.59702605,
#  'Loss/BoxClassifierLoss/localization_loss': 0.042983048,
#  'Loss/RPNLoss/localization_loss': 0.9928224,
#  'Loss/RPNLoss/objectness_loss': 0.30297866,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.9358101,
#  'learning_rate': 0.00036456465}
# INFO:tensorflow:Step 23700 per-step time 0.397s
# I0308 03:35:53.866831 25596 model_lib_v2.py:705] Step 23700 per-step time 0.397s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.50609183,
#  'Loss/BoxClassifierLoss/localization_loss': 0.046106502,
#  'Loss/RPNLoss/localization_loss': 0.12539202,
#  'Loss/RPNLoss/objectness_loss': 0.033675365,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7112657,
#  'learning_rate': 0.0003144765}
# I0308 03:35:53.867831 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.50609183,
#  'Loss/BoxClassifierLoss/localization_loss': 0.046106502,
#  'Loss/RPNLoss/localization_loss': 0.12539202,
#  'Loss/RPNLoss/objectness_loss': 0.033675365,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7112657,
#  'learning_rate': 0.0003144765}
# INFO:tensorflow:Step 23800 per-step time 0.404s
# I0308 03:36:34.228864 25596 model_lib_v2.py:705] Step 23800 per-step time 0.404s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.039787546,
#  'Loss/BoxClassifierLoss/localization_loss': 0.032976475,
#  'Loss/RPNLoss/localization_loss': 0.015313275,
#  'Loss/RPNLoss/objectness_loss': 0.0061573302,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.09423463,
#  'learning_rate': 0.00026806234}
# I0308 03:36:34.228864 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.039787546,
#  'Loss/BoxClassifierLoss/localization_loss': 0.032976475,
#  'Loss/RPNLoss/localization_loss': 0.015313275,
#  'Loss/RPNLoss/objectness_loss': 0.0061573302,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.09423463,
#  'learning_rate': 0.00026806234}
# INFO:tensorflow:Step 23900 per-step time 0.399s
# I0308 03:37:14.165132 25596 model_lib_v2.py:705] Step 23900 per-step time 0.399s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.45532557,
#  'Loss/BoxClassifierLoss/localization_loss': 0.05287246,
#  'Loss/RPNLoss/localization_loss': 0.010152092,
#  'Loss/RPNLoss/objectness_loss': 0.0047111707,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5230613,
#  'learning_rate': 0.00022532581}
# I0308 03:37:14.165132 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.45532557,
#  'Loss/BoxClassifierLoss/localization_loss': 0.05287246,
#  'Loss/RPNLoss/localization_loss': 0.010152092,
#  'Loss/RPNLoss/objectness_loss': 0.0047111707,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5230613,
#  'learning_rate': 0.00022532581}
# INFO:tensorflow:Step 24000 per-step time 0.400s
# I0308 03:37:54.142522 25596 model_lib_v2.py:705] Step 24000 per-step time 0.400s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.41623917,
#  'Loss/BoxClassifierLoss/localization_loss': 0.085838005,
#  'Loss/RPNLoss/localization_loss': 0.39611936,
#  'Loss/RPNLoss/objectness_loss': 0.008904468,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.90710104,
#  'learning_rate': 0.0001862812}
# I0308 03:37:54.142522 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.41623917,
#  'Loss/BoxClassifierLoss/localization_loss': 0.085838005,
#  'Loss/RPNLoss/localization_loss': 0.39611936,
#  'Loss/RPNLoss/objectness_loss': 0.008904468,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.90710104,
#  'learning_rate': 0.0001862812}
# INFO:tensorflow:Step 24100 per-step time 0.409s
# I0308 03:38:35.017598 25596 model_lib_v2.py:705] Step 24100 per-step time 0.409s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.4786798,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03649743,
#  'Loss/RPNLoss/localization_loss': 0.22333539,
#  'Loss/RPNLoss/objectness_loss': 0.011971379,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.750484,
#  'learning_rate': 0.00015093207}
# I0308 03:38:35.017598 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.4786798,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03649743,
#  'Loss/RPNLoss/localization_loss': 0.22333539,
#  'Loss/RPNLoss/objectness_loss': 0.011971379,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.750484,
#  'learning_rate': 0.00015093207}
# INFO:tensorflow:Step 24200 per-step time 0.402s
# I0308 03:39:15.239879 25596 model_lib_v2.py:705] Step 24200 per-step time 0.402s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.20050424,
#  'Loss/BoxClassifierLoss/localization_loss': 0.036786053,
#  'Loss/RPNLoss/localization_loss': 0.50181437,
#  'Loss/RPNLoss/objectness_loss': 0.02183016,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7609348,
#  'learning_rate': 0.00011928677}
# I0308 03:39:15.239879 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.20050424,
#  'Loss/BoxClassifierLoss/localization_loss': 0.036786053,
#  'Loss/RPNLoss/localization_loss': 0.50181437,
#  'Loss/RPNLoss/objectness_loss': 0.02183016,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7609348,
#  'learning_rate': 0.00011928677}
# INFO:tensorflow:Step 24300 per-step time 0.398s
# I0308 03:39:55.046917 25596 model_lib_v2.py:705] Step 24300 per-step time 0.398s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.09539458,
#  'Loss/BoxClassifierLoss/localization_loss': 0.052966096,
#  'Loss/RPNLoss/localization_loss': 0.24979328,
#  'Loss/RPNLoss/objectness_loss': 0.0141376015,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.41229156,
#  'learning_rate': 9.135008e-05}
# I0308 03:39:55.046917 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.09539458,
#  'Loss/BoxClassifierLoss/localization_loss': 0.052966096,
#  'Loss/RPNLoss/localization_loss': 0.24979328,
#  'Loss/RPNLoss/objectness_loss': 0.0141376015,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.41229156,
#  'learning_rate': 9.135008e-05}
# INFO:tensorflow:Step 24400 per-step time 0.399s
# I0308 03:40:34.923840 25596 model_lib_v2.py:705] Step 24400 per-step time 0.399s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.3977455,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03226052,
#  'Loss/RPNLoss/localization_loss': 0.013535796,
#  'Loss/RPNLoss/objectness_loss': 0.013587246,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.45712906,
#  'learning_rate': 6.712794e-05}
# I0308 03:40:34.923840 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.3977455,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03226052,
#  'Loss/RPNLoss/localization_loss': 0.013535796,
#  'Loss/RPNLoss/objectness_loss': 0.013587246,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.45712906,
#  'learning_rate': 6.712794e-05}
# INFO:tensorflow:Step 24500 per-step time 0.397s
# I0308 03:41:14.670256 25596 model_lib_v2.py:705] Step 24500 per-step time 0.397s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.3470294,
#  'Loss/BoxClassifierLoss/localization_loss': 0.030882869,
#  'Loss/RPNLoss/localization_loss': 0.22433935,
#  'Loss/RPNLoss/objectness_loss': 0.005739481,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6079911,
#  'learning_rate': 4.6623943e-05}
# I0308 03:41:14.670256 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.3470294,
#  'Loss/BoxClassifierLoss/localization_loss': 0.030882869,
#  'Loss/RPNLoss/localization_loss': 0.22433935,
#  'Loss/RPNLoss/objectness_loss': 0.005739481,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6079911,
#  'learning_rate': 4.6623943e-05}
# INFO:tensorflow:Step 24600 per-step time 0.400s
# I0308 03:41:54.629417 25596 model_lib_v2.py:705] Step 24600 per-step time 0.400s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.37834707,
#  'Loss/BoxClassifierLoss/localization_loss': 0.014607399,
#  'Loss/RPNLoss/localization_loss': 0.17010373,
#  'Loss/RPNLoss/objectness_loss': 0.006789957,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5698482,
#  'learning_rate': 2.9844045e-05}
# I0308 03:41:54.630417 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.37834707,
#  'Loss/BoxClassifierLoss/localization_loss': 0.014607399,
#  'Loss/RPNLoss/localization_loss': 0.17010373,
#  'Loss/RPNLoss/objectness_loss': 0.006789957,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5698482,
#  'learning_rate': 2.9844045e-05}
# INFO:tensorflow:Step 24700 per-step time 0.396s
# I0308 03:42:34.239728 25596 model_lib_v2.py:705] Step 24700 per-step time 0.396s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.21221139,
#  'Loss/BoxClassifierLoss/localization_loss': 0.025709469,
#  'Loss/RPNLoss/localization_loss': 0.089406624,
#  'Loss/RPNLoss/objectness_loss': 0.051015675,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.37834316,
#  'learning_rate': 1.6789436e-05}
# I0308 03:42:34.240750 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.21221139,
#  'Loss/BoxClassifierLoss/localization_loss': 0.025709469,
#  'Loss/RPNLoss/localization_loss': 0.089406624,
#  'Loss/RPNLoss/objectness_loss': 0.051015675,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.37834316,
#  'learning_rate': 1.6789436e-05}
# INFO:tensorflow:Step 24800 per-step time 0.402s
# I0308 03:43:14.388349 25596 model_lib_v2.py:705] Step 24800 per-step time 0.402s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.5181902,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0160584,
#  'Loss/RPNLoss/localization_loss': 0.1584866,
#  'Loss/RPNLoss/objectness_loss': 0.005918582,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6986538,
#  'learning_rate': 7.4625013e-06}
# I0308 03:43:14.388349 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.5181902,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0160584,
#  'Loss/RPNLoss/localization_loss': 0.1584866,
#  'Loss/RPNLoss/objectness_loss': 0.005918582,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6986538,
#  'learning_rate': 7.4625013e-06}
# INFO:tensorflow:Step 24900 per-step time 0.400s
# I0308 03:43:54.386522 25596 model_lib_v2.py:705] Step 24900 per-step time 0.400s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.70641714,
#  'Loss/BoxClassifierLoss/localization_loss': 0.4380905,
#  'Loss/RPNLoss/localization_loss': 0.55852234,
#  'Loss/RPNLoss/objectness_loss': 0.06605933,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7690892,
#  'learning_rate': 1.8656253e-06}
# I0308 03:43:54.386522 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.70641714,
#  'Loss/BoxClassifierLoss/localization_loss': 0.4380905,
#  'Loss/RPNLoss/localization_loss': 0.55852234,
#  'Loss/RPNLoss/objectness_loss': 0.06605933,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.7690892,
#  'learning_rate': 1.8656253e-06}
# INFO:tensorflow:Step 25000 per-step time 0.399s
# I0308 03:44:34.317718 25596 model_lib_v2.py:705] Step 25000 per-step time 0.399s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.24808414,
#  'Loss/BoxClassifierLoss/localization_loss': 0.035877865,
#  'Loss/RPNLoss/localization_loss': 0.23479718,
#  'Loss/RPNLoss/objectness_loss': 0.006121611,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.52488077,
#  'learning_rate': 0.0}
# I0308 03:44:34.317718 25596 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.24808414,
#  'Loss/BoxClassifierLoss/localization_loss': 0.035877865,
#  'Loss/RPNLoss/localization_loss': 0.23479718,
#  'Loss/RPNLoss/objectness_loss': 0.006121611,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.52488077,
#  'learning_rate': 0.0}

# %%
# !python {SCRIPT_PATH + '/exporter_main_v2.py'} --input_type image_tensor --pipeline_config_path {CONFIG_PATH} --trained_checkpoint_dir {MODEL_PATH + '/' } --output_directory exported-models\my-model
# Out:
# 2024-03-08 03:44:54.152630: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-08 03:44:54.570377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0308 03:44:54.779562 22908 deprecation.py:623] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0308 03:44:58.643708 22908 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0308 03:45:04.779869 22908 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x0000020EC6CEE1F0>, because it is not built.
# W0308 03:45:30.601732 22908 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x0000020EC6CEE1F0>, because it is not built.
# W0308 03:45:39.444217 22908 save.py:233] Found untraced functions such as FirstStageBoxPredictor_layer_call_fn, FirstStageBoxPredictor_layer_call_and_return_conditional_losses, mask_rcnn_keras_box_predictor_layer_call_fn, mask_rcnn_keras_box_predictor_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op while saving (showing 5 of 84). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: exported-models\my-model\saved_model\assets
# I0308 03:45:43.945573 22908 builder_impl.py:779] Assets written to: exported-models\my-model\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to exported-models\my-model\pipeline.config
# I0308 03:45:44.519815 22908 config_util.py:253] Writing pipeline config file to exported-models\my-model\pipeline.config

# %% [markdown]
# Inferencing My Trained Models

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
# from google.colab.patches import cv2_imshow

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = 'D:/Traffic SignBoard Recognition using Deep Learning/Dataset/PASCAL VOC Format Dataset/valid/axle_load_limit-16_jpg.rf.489424850e51b4e130f2eb9ebd1f9aab.jpg'

# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = './exported-models/my-model'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = ANNOTATION_PATH + '/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

print('Running inference for {}... '.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
      image_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=1,
      min_score_thresh=0.3,
      agnostic_mode=False)

print('Done')
# DISPLAYS OUTPUT IMAGE
cv2.imshow('test', image_with_detections)
# CLOSES WINDOW ONCE KEY IS PRESSED
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Loading model...Done! Took 8.174150466918945 seconds
# Running inference for D:/Traffic SignBoard Recognition using Deep Learning/Dataset/PASCAL VOC Format Dataset/valid/axle_load_limit-16_jpg.rf.489424850e51b4e130f2eb9ebd1f9aab.jpg...
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[18], line 84
#      81 input_tensor = input_tensor[tf.newaxis, ...]
#      83 # input_tensor = np.expand_dims(image_np, 0)
# ---> 84 detections = detect_fn(input_tensor)
#      86 # All outputs are batches tensors.
#      87 # Convert to numpy arrays, and take index [0] to remove the batch dimension.
#      88 # We're only interested in the first num_detections.
#      89 num_detections = int(detections.pop('num_detections'))
#
# File d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\saved_model\load.py:686, in _call_attribute(instance, *args, **kwargs)
#     685 def _call_attribute(instance, *args, **kwargs):
# --> 686   return instance.__call__(*args, **kwargs)
#
# File d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[300,1024,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node StatefulPartitionedCall/MultiLevelMatMulCropAndResize/MultiLevelRoIAlign/AvgPool-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[StatefulPartitionedCall/SecondStagePostprocessor/BatchMultiClassNonMaxSuppression/MultiClassNonMaxSuppression/Reshape_34/_210]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[300,1024,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node StatefulPartitionedCall/MultiLevelMatMulCropAndResize/MultiLevelRoIAlign/AvgPool-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_restored_function_body_33446]

# %%
# !tensorboard --logdir D:"/Traffic SignBoard Recognition using Deep Learning"/"Faster R-CNN ResNet50 V1 640x640"/models/faster_r-cnn_resnet50_v1_640x640 --host localhost --port 6006

# %% [markdown]
# ## Evaluation Model:

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'} --checkpoint_dir={MODEL_PATH}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=6.30s).
# Accumulating evaluation results...
# DONE (t=2.63s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.244
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.608
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.638
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.640
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.668
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0313 12:03:39.763117 15396 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0313 12:03:39.763117 15396 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0313 12:03:39.763117 15396 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0313 12:03:39.763117 15396 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0313 12:03:39.763117 15396 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2024-03-13 12:03:39.820219: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 12:03:40.730501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2137 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# I0313 12:03:45.794599 15396 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# I0313 12:03:45.794599 15396 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0313 12:03:45.794599 15396 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0313 12:03:45.794599 15396 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0313 12:03:45.796597 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0313 12:03:45.819602 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0313 12:03:51.222646 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 12:03:53.047330 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at ./models/faster_r-cnn_resnet50_v1_640x640
# I0313 12:03:56.617902 15396 checkpoint_utils.py:136] Waiting for new checkpoint at ./models/faster_r-cnn_resnet50_v1_640x640
# INFO:tensorflow:Found new checkpoint at ./models/faster_r-cnn_resnet50_v1_640x640\ckpt-26
# I0313 12:03:56.623903 15396 checkpoint_utils.py:145] Found new checkpoint at ./models/faster_r-cnn_resnet50_v1_640x640\ckpt-26
# d:\Anaconda3\envs\traffic\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0313 12:04:04.219712 15396 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0313 12:04:13.503328 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0313 12:04:19.453065 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2024-03-13 12:04:54.623640: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-13 12:05:00.533307: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:00.533733: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:00.577890: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:00.578341: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:00.753609: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:00.754157: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:02.876086: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:02.876603: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:03.268463: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-13 12:05:03.269004: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0313 12:05:10.426594 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0313 12:05:10.457594 15396 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0313 12:05:10.578110 15396 deprecation.py:350] From d:\Anaconda3\envs\traffic\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Finished eval step 100
# I0313 12:07:15.016777 15396 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0313 12:08:26.045033 15396 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0313 12:08:59.254823 15396 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Finished eval step 400
# I0313 12:09:33.233764 15396 model_lib_v2.py:966] Finished eval step 400
# INFO:tensorflow:Finished eval step 500
# I0313 12:10:07.710933 15396 model_lib_v2.py:966] Finished eval step 500
# INFO:tensorflow:Finished eval step 600
# I0313 12:10:41.394308 15396 model_lib_v2.py:966] Finished eval step 600
# INFO:tensorflow:Performing evaluation on 665 images.
# I0313 12:11:02.548946 15396 coco_evaluation.py:293] Performing evaluation on 665 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0313 12:11:02.549946 15396 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.12s)
# I0313 12:11:02.670529 15396 coco_tools.py:138] DONE (t=0.12s)
# INFO:tensorflow:Eval metrics at step 25000
# I0313 12:11:11.919547 15396 model_lib_v2.py:1015] Eval metrics at step 25000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.243630
# I0313 12:11:11.946465 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.243630
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.341906
# I0313 12:11:11.948471 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.341906
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.298847
# I0313 12:11:11.950457 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.298847
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0313 12:11:11.952466 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.000676
# I0313 12:11:11.953462 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.000676
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.250644
# I0313 12:11:11.955463 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.250644
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.608464
# I0313 12:11:11.957452 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.608464
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.637959
# I0313 12:11:11.959458 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.637959
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.639956
# I0313 12:11:11.961450 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.639956
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0313 12:11:11.963449 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.050000
# I0313 12:11:11.964460 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.050000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.667877
# I0313 12:11:11.967465 15396 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.667877
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.277330
# I0313 12:11:11.969465 15396 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.277330
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.115871
# I0313 12:11:11.971464 15396 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.115871
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.072164
# I0313 12:11:11.972465 15396 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.072164
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.425748
# I0313 12:11:11.974450 15396 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.425748
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I0313 12:11:11.975462 15396 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.891113
# I0313 12:11:11.976456 15396 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.891113
# INFO:tensorflow:Exiting evaluation at step 25000
# I0313 12:11:12.328490 15396 model_lib_v2.py:1168] Exiting evaluation at step 25000
